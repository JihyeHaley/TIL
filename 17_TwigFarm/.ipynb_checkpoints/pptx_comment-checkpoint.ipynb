# %%
import xlsxwriter
import timeit
from itertools import zip_longest
from nltk.tokenize import sent_tokenize

# ppt인 파일 가져오기
from pptx import Presentation

from common_functions import *
from regex_functions import *

# %%
# 대소문자 구별하기 위한
def lower_or_upper():
    lower = [chr(l) for l in range(97, 123, 1)]
    upper = [chr(u) for u in range(65, 91, 1)]
    return lower, upper

# %%
string = "/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-DAY1_BSN_Bambang Purwanggono-한.pptx "
print(string[115:])
# Out:
# SO-한국표준협회-DAY1_BSN_Bambang Purwanggono-한.pptx

# %%
import glob
import subprocess
# -----------------------------------------------------------------------------------------
# file 다 가져오기
def get_filename_list(path, ext):
    print('Change encoding files.......\ \n')
    result = []
    for f in glob.glob(file_path + f"/*{ext}"):
        # run convmv shell script -> file normalization NFC -> NFD (한글자소분리해결)
        subprocess.run(['/usr/local/bin/convmv', '-f', 'utf-8', '-t', 'utf-8', '--nfc', '--notest', f])
        result.append(f)
    return result

root_path = '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)'
sub_dir = '/4.2019한국표준협회'
file_path = root_path + sub_dir

pptx_files_dict = get_filename_list(file_path, '.pptx')
print(pptx_files_dict)
# Out:
# Change encoding files.......\
#
# ['/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1)-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1)-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외)-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외)-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종-영.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2)-한.pptx', '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1)-영.pptx', '/Users/j ...

# %%
def pptx_parser_pre(pptx_file):
    # pptx 분석 하기위해 list 만들어주기
    pptx_results_pre = []
    prs = Presentation(pptx_file)
    
    # ---- pptx 추출 시작 ----
    for slide in prs.slides:
        
        # 1개의 pptx 분석시작
        for shape in slide.shapes:
            if not shape.has_text_frame:
                continue
                
            
            # 전처리 및 라인별 넣어주기
            for paragraph in shape.text_frame.paragraphs:
                paragraph.text = pptx_extra_regex(paragraph.text)

                if paragraph.text.strip() in ['.', '/', ',']:
                    continue
                pptx_results_pre.append(paragraph.text)

            # sent_tokenize 
            pptx_results = []
            for pptx_result_pre in pptx_results_pre:
                text_list = sent_tokenize(pptx_result_pre)
                for text in text_list:
                    if len(text) == 1 and text == 'E':
                        text = text + '→'
                    if text[:2] in 'ver':
                        text = '←' + text
                    pptx_results.append(text)
    pptx_results = list(filter(None, pptx_results))
    return pptx_results

# %%
start = timeit.default_timer()

completed_log = open(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/4_completed_log' + '.txt', "w+")

ko_files = []
en_files = []

for pptx_file in pptx_files_dict:
    if pptx_file[-6] == '한':
        ko_files.append(pptx_file)
    elif pptx_file[-6] == '영':
        en_files.append(pptx_file)

# %%
i = 0
# 짝이 맞는 순서대로 넣어주기
ko_file, en_file = '', ''
for ko_file in ko_files:
    for en_file in en_files:
        if ko_file[:-6] == en_file[:-6]:
            pptx_ko = pptx_parser_pre(ko_file)
            print(pptx_ko)
            pptx_en = pptx_parser_pre(en_file)
            print(pptx_en)
            
            i += 1       
            # ---- 파일명에 따라서 순서대로 한, 영 key에 filename을 value로 넣어주기 ----
            completed_log.write(str(i) + ko_file + ' \n')
            completed_log.write(str(i) + en_file + ' \n')
            print(i, ko_file[80:-5])
            print(i, en_file[80:-5])
    
  
            # excel 밖으로 빼내기
            # ------- 절대경로보다 상대경로 사용해주세요
            workbook = xlsxwriter.Workbook(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/Test_2/{ko_file[115:-6]}.xlsx')
            print(ko_file[115:-6])
            worksheet = workbook.add_worksheet()
            worksheet.write('A1', ' ')
            worksheet.write('B1', 'KOR')
            worksheet.write('C1', 'ENG')

            row_idx = 2

            # pptx을 excel로 
            worksheet.write('A' + str(row_idx), '>' * 10 + ko_file[115:-6])
            row_idx += 1
            for ko, en in zip_longest(pptx_ko, pptx_en, fillvalue=' '):
                worksheet.write('B' + str(row_idx), ko)
                worksheet.write('C' + str(row_idx), en)
                row_idx += 1

            workbook.close()
            

stop = timeit.default_timer()
print('Running Time: ', stop - start)

print(f'ko :{len(ko_files)}, en :{len(en_files)}')
# Out:
# ['새로운 (e) 이륙', '항공 산업의', '글: 앤 브래디Ann Brady', '로봇기술부터 러신머닝에까지 이르는 신기술이 급격한 변화와 개발 주기를 이끌고 있다.', '항공산업이 산업 자동화와 표준, 특히 ISO/TC 184/SC 4로 취한 이득으로 좋은 결과를 내기 노력하는 한편 부드러운 항공 경로를 확보하기 위한 중요한 역할을 하고 있다.', '물론, 이들이 따라올 수 있을 경우의 일이다.', '그리스 로마 신화의 이카로스Icarus가 나무로 날개를 만들어 밀랍으로 깃털을 붙여 하늘을 날았던 그 순간부터 인류는 중력을 거스르고 자유롭게 날기 위한 기계와 장치를 설계하고 만들어왔다.', '이카로스는 태양의 뜨거운 열기와 함께 휴브리스Hubris를 겪고 추락했지만, 오늘날은 스페이스 XSpace X의 고안자이자 테슬라Tesla의 창업자인 엘론 머스크Elon Musk와 아마존닷컴Amazon.com과 블루 오리진Blue Origin의 창립자인 제프 베조스Jeff Bezos처럼 자신의 비전과 모험심으로 움직이고 4차 산업혁명의 신기술로 동력을 얻는 사람들이 하늘에 새로운 길을 개척하고 있다.', '현대판 이카로스들은 크게 생각할 능력이 있고, 자신들의 성공과 새로운 길을 밝히려는 노력과 목표를 매체 전역 흩뿌리고 있다.', '물론, 항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', '년, 첫 번째 상용 비행기가 탄생한 때부터 항공 여행 수요는 기하급수적으로 늘었다.', '그 결과, 항공 업계는 더 안전하고, 빠르고, 가벼우며 연료 효율이 높은 항공기를 설계할 방법을 찾게 되었다세기에 들어 환경에 대한 인식이 최고조에 다다르자, 업계 또한 항공기의 탄소 배출을 줄이고 지속 가능한 탄소 발자국을 유지하기 위한 방법을 찾게 되었다.', "당시는 다른 무엇보다도 가격이 중요한 이지젯EasyJet 시대'였던 만큼, 굉장히 어려운 일이었다.", '빠르게, 유연하게', '이러한 난제를 해결하는 데는 비용 효율적이고도 빠르며 유연한 새로운 생산 공정이 필요하다.', '고급 로봇 공학, 인공 지능, 머신 러닝, 클라우드 컴퓨팅 및 사물 인터넷과 같은 기술은 이러한 공정에 큰 역할을 하며 우리 삶을 조용히 변화시키고 있으며, 특히 항공 산업에 큰 변화를 불러왔다.', '우리는 비행기에 올라 자리에 앉을 때마다 자동화에 우리 자신을 어느 정도 맡기는 셈이다.', 'ISO포커스_1315', '비행이 무서운 사람에게 그다지 반가운 예시는 아니지만, 우리는 비행기의 서로 다른 부품을 엮어주는 수천 개의 구멍과 그 구멍이 어떻게 뚫어졌는지에 대해 생각해 보지 않는다.', '고도의 정밀함과 시간이 필요한 작업임에도 말이다.', '셰필드 대학교Sheffield University 내 첨단 제조 연구센터Advanced Manufacturing Research Center의 통합 제조 그룹 책임자인 벤 모건Ben Morgan은 디 엔지니어The Engineer에 기고한 기사에서 자동화 제조는 사람보다 로봇에게 적합한 작업이라고 지적하며 "자동화 시스템은 정밀도를 더 높일 수 있고, 지루함이나 피곤함을 느끼지도 않는다.', '우주 항공 산업 재료 및 다양한 재료를 겹친 재료는 숙련된 직원이 다루기에도 부피가 크고 무겁고 어려움을 겪을 수 있다.', '"라고 말했다.', '비행기 이용자에게 좋은 소식인 셈이다.', '만 개의 부품이 반드시 모두 조립되어야만 하는 보잉 747을 생각해보자.', '자동화 제조가 새 항공기를 제작하는 데 큰 역할을 해낸다는 것이 분명해지지 않는가?', '그러나, 항공 산업에 난제가 없는 것은 아니다.', '급속도로 발전하는 신기술을 따라가야 할 뿐만 아니라 설계, 조달, 제조, 생산 및 배달, 지원, 유지보수, 제품의 폐기와 기타 관련 서비스 등 자동화 시스템 분야의 표준도 잘 알아두어야 한다.', '이러한 두 가지 과제에 독특한 시각을 가진 사람이 있다.', '보잉의 사업 역량 통합부서의 수석 관리자이자, 기술 위원회 ISO/TC 184, 항공 시스템과 통합, 분과위원회 SC4, 산업 자료의 의장인 케니 스워프Kenny Swope이다.', '스워프Swope는 고도로 복잡한 시스템을 통해 제조를 해야 하는 보잉과 같은 회사는 업계에서 전반적인 성공을 거두기 위해 표준이 매우 중요하며, 회사의 “제품, 공급 체인과 서비스 제안 등이 무수히 많은 갈래로” 엮여 있다고 말한다.', '표준의 주요 역할', '스워프Swope에 따르면, ISO 10303, 산업 자동화 시스템과 통합 – 상품 데이터 표현 및 교환, 즉 STEP은 디지털 상품 설계의 적용에 가장 성공적인 표준 중 하나이다.', 'ISO 10303은 산업 데이터에 대한 ISO/TC 184/SC 4에 속하는 표준이다.', 'STEP은 회사 내부는 물론, 글로벌 공급 체인 사이에서 컴퓨터 이용 설계(CAD) 시스템을 이용한 상품 설계 데이터 교환에서 가장 흔하게 쓰이는 표준으로 발달했다.', '그는 “설계와 공학에서 제조에 이르는 제품의 핵심으로, 제품 설계와 결합된 공학 요구사항과 제조 정보 등 3차원 표현은 디지털 트윈의 핵심을 이룬다.”라고 말한다.', '상세한 가상 표현을 위한 집합적 데이터에는 분명한 이점이 있다.', '스워프는 “보잉의 제품 설계는 구성 요소와 조립 수준에서 내외부 이해당사자에게 분배되며, 이 표준은 이러한 망에 대단히 중요하다.”고 덧붙였다.', '전반적인 설명, 교육 문서 작업에 대한 제품 디자인의 복합 디자인을 제공하는 것은 또 다른 과제이다.', '여기, 스워프는 ISO/TC 184/SC 4에서 다루는 또 다른 표준인 ISO 14306, 산업 자동화 시스템과 통합 – 3D 구상을 위한 JT 파일 형식 사양을 강조한다.', '그는 복잡한 데이터 구조의 “경량 버전”을 제공하는 이 표준이 매우 귀중한 것이라고 말한다.', '즉, 제조, 서비스 및 지원을 위한 제품의 구상이 “공학 문서와 온라인 서비스 매뉴얼 및 제조 공장에 유용”하다는 것이다.', '세 번째 표준은 ISO 32000, 문서 관리 – 휴대 가능한 문서 형식이다.', '스워프에 따르면 이는 “ISO 10303과 ISO 14306 모두의 강력한 파트너”이다.', '이 표준은 PDF 표준으로도 잘 알려져 있는데, 제품 설계에 필요한 범용 운송 수단과 관련 정보를 제공하기 때문에 디지털 미래의 매끄러운 운용에 필수적이다.', '마지막으로, ISO 8000, 데이터 품질과 ISO 22745, 산업 자동화 시스템과 통합 – 오픈 기술 사전과 마스터 데이터에 대한 사전의 적용은 스마트 제조를 가능하게 하는 중요한 요소이다.', '즉, ISO 9000은 제조 품질을, ISO 8000은 데이터를 담당하는 것이다.', '스마트 제조에는 결함이 없는 데이터가 필요하고, 상용 부품의 데이터 정의를 공개적으로 공유할 수 있어야 한다.', 'ISO 22745는 공급 체인 전역에 걸쳐 사용되는 상용 부품의 정의를 공유하기 위한 다중 산업 솔루션을 제공한다.', '항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', 'ISO포커스_131', 'ISO포커스_1317', '자동화와 효율', '스스로를 멀티 CAD 데이터 교환 최적화 플랫폼이라고 소개하는 소프트웨어 회사 엘리시움Elysium의 기술 업무부 책임자인 애너리즈 스즈키Annalise Suzuki 또한 표준의 이점과 산업 자동화의 확대 경향에 맞추어 표준이 수행하는 핵심 역할을 극찬했다.', '그녀는 “효율을 위해 자동화를 추구하는 조직은 반드시 새로운 기술을 적용하는 것과 표준을 통해 안정성을 올리는 것 사이에서 균형을 찾아야 한다.”라고 말했다.', '스즈키Suzuki는 스워프와 같이 표준의 영향력이 지나치게 복잡한 과정을 거치지 않고 조직의 수단과 방법을 빠르게 조화시킬 수 있도록 도와준다고 믿는다.', '그녀는 “이 표준은 어떻게’를 먼저 생각하지 않고 행동가들이 바로 행동에 돌입할 수 있도록 만들어준다.”고 말했다.', '그녀는 표준이 오늘날 사람들 간의 협업을 도와주는 동시에, 표준이 “머신 투 머신 의사소통에 대한 잠재력으로 자동화를 이끌 핵심 가능자가 될 것이고, 4차 산업혁명을 달성하는 기초가 될 것”이라고 주장한 ...
# ['New (e)takeoff', 'for aviation industry', 'by Ann Brady', 'New technologies, from robotics to machine learning, are ushering in a period of rapid change and development.', 'While the aviation industry is working to reap the benefits of this industrial automation, standards, especially those of ISO/TC 184/SC 4, will play a key role in ensuring a smooth flight path – but only if they can keep up.', '←ver since Icarus boldly strapped on his woodenframed wings made of feathers and wax and took to the skies,', ' human beings have been defying gravity, designing and creating all kinds of contraptions and devices to get themselves airborne.', 'Hubris, along with solar power, did it in for Icarus, but these days, the likes of Elon Musk, founder and chief designer of SpaceX and creator of Tesla, and Jeff Bezos, founder of Amazon.com and Blue Origin, are blazing new trails in the skies, driven by their vision and a sense of adventure, and propelled by the new technologies of the Fourth Industrial Revolution.', 'These modernday Icaruses can afford to think big, and their successes, trailblazing endeavours and projections are splashed across the media.', 'Of course, the aerospace and aviation industry has been pushing boundaries for years.', 'From the first commercial air flight in 1914, demand for air travel has grown exponentially.', 'As a result, the industry has had to seek new ways to design safer, faster, lighter, more fuelefficient aircraft.', 'And in the ever more environmentally aware 21st century, the industry also has to take action to reduce aircraft emissions and achieve a more sustainable carbon footprint – big challenges indeed in an era that has been described as "generation EasyJet”.', 'Fast and flexible', 'Finding solutions to these challenges calls for costeffective, fast and flexible new production processes.', 'Technologies such as advanced robotics, artificial intelligence, machine learning, cloud computing and the Internet of Things are playing a huge role in such processes and are quietly transforming our lives, particularly in the aviation industry.', 'Every time we step on a plane and buckle up, we are handing ourselves over to some degree of automation.', 'ISOfocus_1315', 'E→', 'For instance (nervous flyers should look away now), we never think about the thousands of holes that are holding the different parts of the plane together and how those holes were drilled, a timeconsuming task that also requires a lot of precision.', 'Ben Morgan, Head of the Integrated Manufacturing Group at the Advanced Manufacturing Research Centre at Sheffield University, points out in an article on automated manufacturing in The Engineer, this is a task better suited to robots than people.', '"Automated systems can achieve greater precision, and do not get bored or tired; drills capable of handling aerospace materials and layers of different materials are bulky, heavy and difficult even for skilled staff to use, "he says.', 'Good news for air travellers.', 'And when you consider that a Boeing 747, for example, consists of six million parts, which must all be assembled, it becomes clear that automated manufacturing has a key role to play in building new aircraft.', 'However, therein lies the challenge for the aviation industry – not only in staying abreast of the rapid development of new technologies but also ensuring standardization in the field of automation systems and their integration for design, sourcing, manufacturing, production and delivery, support, maintenance and disposal of products and their associated services.', 'One person with a unique perspective on both these challenges is Kenny Swope, Senior Manager, Business Capability Integration, at Boeing, and Chair of technical committee ISO/TC 184, Automation systems and integration, subcommittee SC 4, Industrial data.', 'For a company like Boeing, which is a manufacturer of highly complex systems at scale, Swope says standards are critical to its overall success in the in ...
# 1 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-한
# 1 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-영
# TE-한국표준협회-ISOfocus_131_en-
# ['인공지능의\x0b새로운 장', 'ISOfocus_13117', '기사작성자: 로버트 바트람(Robert Bartram)', '인공지능(AI)은 이제 더 이상 공상과학 영화의 테마가 아닌 우리 실생활의 일부다.', '공장에서, 지능형교통체계에서, 심지어 의료분야에서도 우리는 AI 활용 사례를 볼 수 있다.', '하지만 정확히 인공지능은 무엇인가?', '성큼 도래한 유비쿼터스 AI\xa0세상에서 국제표준은 왜 필요한가?', '또한 AI 표준화는 어떤 분야를 대상으로 하는가?', '맥킨지 글로벌 연구소1)가 발표한 최근 보고서에 의하면 인공지능에 대한 투자가 빠른 속도로 증가하고 있다.', '맥킨지는 구글과 같은 디지털 혁신 선도기업은 "2016 회계연도에 20~30억 달러를 AI에 투자했으며, 그 중 90%는 R&D 및 AI 배치에, 나머지 10%는 AI 구입에 사용한 것으로 분석한다.', 'ICT산업 전문 시장조사기관 IDC(International Data Corporation)2)에 따르면, 2019년까지 디지털 변혁 이니셔티브의 40%가 다양한 AI를 배치하고, 2021년까지 엔터프라이즈 응용프로그램의 75%가 AI를 사용할 계획이며 총 지출 규모는 522억 달러로 증가할 전망이다.', '개념에서 현실로', '하지만 정확히 AI가 무엇인가?', "ISO/IEC JTC 1, '정보기술(Information technology)'의 분과위원회인 SC 42, 인공지능(Artificial intelligence)의 와엘 윌리엄 디아브(Wael William Diab) 의장에 따르면, AI 분야는 매우 다양한 기술로 구성된다.", '이 신설 위원회는 AI의 개념과 용어(ISO/IEC 22989)를 규정하는 기본 표준의 개발에 착수했다.', '디아브 의장은 AI에 대한 관심이 고조되면서 데이터 과학자, 디지털 전문가, 규제기관 등 매우 다양한 종류의 이해관계자가 이 분야에 참여 중이라고 말한다.', '그는 또 오늘날 AI의 현황과 AI에 대한 인식 사이에 다소 괴리가 있다고 지적한다.', '“사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '내가 보기에 AI는 지능을 갖춘 기계를 효과적으로 구현하는 기술의 집합체다.”', '그는 또 흔히 사람들이 AI를 하나의 완전 자율 시스템 그룹, 즉 움직이는 로봇인 것처럼 생각하지만, 실제로는 많은 AI가 반자율 시스템에 속한다고 설명한다.', '일반적으로 AI 시스템에서 상당 부분의 데이터는 미리 준비가 완료되고, 그 후 특정 형태의 기계학습 능력이 있는 핵심부품에 탑재되며 결국 이런 부품이 우리에게 갖가지 통찰력을 제공한다.', '이처럼 기술 집합체를 구성하는 요소에는 빅데이터, 분석법이 포함되며 반드시 그에 국한하지는 않는다.', '기술의 우산', '현재 화웨이테크놀로지(Huawei Technologies)의 전무로 재직 중인 디아브씨가 ISO/IEC 분과위원회 의장으로 선출된 데는 그만한 이유가 있다.', '맥킨지 글로벌 연구소, 인공지능: 차세대 디지털 프론티어(Artificial Intelligence: The Next Digital Frontier )?', 'IDC, 20182021년 미국 정부기관용 인지컴퓨팅 및 인공지능 솔루션 시장 전망(US Government Cognitive and Artificial Intelligence Forecast 20182021)', 'ISOfocus_131', 'ISOfocus_13119', '스탠퍼드 대학교와 와튼 스쿨에서 전기공학, 경제 및 경영학 학위를 받은 디아브 의장은 경영, 기술전략 부문에서 직무경력을 쌓았다.', '다국적기업인 시스코와 브로드컴에서 근무한 바 있고 사물인터넷(IoT) 전문 컨설턴트로 활동했으며 최근에는 산업인터넷컨소시엄 운영위원회 간사를 역임했다.', '또한 850건 이상의 특허를 출원하여 그 중 400건 가까이 등록되었고 나머지는 심사 중에 있다.', '이는 테슬라가 생전에 출원했던 특허건수보다 더 많은 숫자다.', '더욱이 디아브 의장이 출원한 특허는 단 한 건도 거절결정을 받지 않았다.', '디아브 의장의 진정한 장점은 폭넓은 전문지식에 있는데, 그의 전공분야는 기술 아이디어의 초기 인큐베이션부터 전략적 사업추진에 이르기까지 다양한 영역을 망라한다.', '그가 표준화에 큰 관심을 갖는 것은 산업 전체의 건전한 성장을 위해서는 표준이 완벽한 도구라고 믿기 때문이다.', '디아브 의장은 오늘을 살아가는 우리는 여러 가지 이유로 AI 표준이 필요하다고 역설한다.', '첫째, 현대 사회의 IT는 그 복잡성이 갈수록 심화된다.', '따라서 일반적인 스마트폰 한 대의 용량이 아폴로 우주선의 미션을 모두 합친 용량보다 더 크다.', '둘째, IT가 모든 분야에 점점 더 깊숙이 스며들고 있다.', 'IT 기기들은 출시 초창기인 1970~80년대에는 다소 느린 발전을 보였다.', '하지만 이제 사람들은 단지 효율성 향상 차원에서 IT 시스템을 필요로 하는 것이 아니라 더 큰 효율을 발휘하고 운영적, 전략적 통찰력을 얻기 위해 이를 필요로 하기에 이르렀다.', '끝으로 IT는 어느덧 우리의 삶과 혼연일치가 되었다.', '재무에서부터 제조, 의료, 교통, 로봇에 이르기까지 IT에 의존하지 않는 분야가 없다.', '대책의 일환', '그것이 바로 국제표준이 작동하기 시작하는 지점이다.ISO와 국제전기기술위원회(IEC)간 공동기술위원회 JTC 1 산하의 분과위원회인 SC 42는 AI 생태계를 취급하는 유일한 기술위원회다.', '디아브 의장은 AI 기술이 널리 보급되려면 이 기술의 모든 측면을 종합적으로 고려할 필요가 있으며, 그것이야말로 자신과 SC 42가 지향하는 인식의 출발점이라고 강조한다.', '“우리는 사용자들이 AI가 어떻게 의사결정을 내리는지에 대해 우려 섞인 관심을 나타내고 있으며 따라서 AI의 투명성이 시스템에 포함되어야 한다는 사실을 잘 알고 있습니다.', '따라서 기술 채택을 위해서는 포괄적인 표준화가 필수적입니다,”라고 그는 강조한다.', '그간 AI 생태계는 기술, 사회 및 윤리적 고려사항이라는 몇 가지 핵심 분야로 세분화되었으며 이는 개괄적으로 다음과 같은 범주를 포함한다.', '사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '기본 표준', '매우 다양한 이해관계자로 구성된 SC 42는 일차적인 출발점을 기본 표준에 대한 작업으로 정했다.', '이 작업은 AI의 여러 측면 가운데 공통 용어, 분류체계 및 정의가 요구되는 분야를 검토한다.', '궁극적으로 기본 표준은 현장실무자나 규제담당자가 동일한 언어로 말하고 양 당사자 모두 기술전문가로서 한 목소리를 낼 수 있음을 의미한다.', 'ISOfocus_131', 'ISOfocus_13121', '연산 방법과 기법', 'AI의 핵심은 인공지능 시스템의 연산방법 및 특성의 평가다.', '여기에는 AI의 연산방법, 아키텍처 및 특성을 파악하기 위한 기존의 전문 AI 시스템에 대한 연구는 물론 AI 시스템이 사용하는 다양한 기술(예: ML 알고리즘, 추론, 등)과 특성에 대한 연구도 포함된다.', '이 연구그룹은 AI 분야에서 일어나고 있는 현황을 보고하면서 표준화가 요구되는 분야를 제안할 것이다.', '신뢰도', "산업계의 가장 어려운 주제 가운데 하나가 '신뢰도'이며, 이것이 AI 생태계의 핵심 고려사항 가운데 세 번째다.", '신뢰도는 AI를 둘러싼 여러 우려사항 가운데 중심 위치에 있다.', '이 연구그룹은 AI 시스템의 보안, 프라이버시에서부터 시스템 강건성, 투명성 및 편견에 이르기까지 모든 부분을 샅샅이 검토 중이다.', '이미 AI에는 의사결정을 내리거나 사람들에게 결정을 요하는 사안에 관한 정보를 제공하는 시스템이 있다.', '따라서 불필요한 편견이 없음을 확신하기 위해서는 투명성에 대한 인식과 합의가 가장 중요하다.이 연구그룹은 표준화 프로젝트에 관한 일련의 권고안을 마련할 것으로 보인다.', '상기 권고안은 AI 분야의 우려를 사전에 차단할 수 있는 도구를 제공할 것이다.', '“AI 생태계는 이러한 문제를 내포하고 있습니다.', '따라서 표준이 동 문제 해결에 ...
# ['The new frontier', 'for artificial intelligence', 'ISOfocus_13117', 'by Robert Bartram', 'No longer just a fictional theme for farfetched science fiction movies, artificial intelligence is now very much a daytoday part of our reality.', 'In factories, in intelligent transportation, even in the medical field, artificial intelligence (AI) is just about everywhere.', 'But what exactly is artificial intelligence?', 'As AI becomes more ubiquitous, why is there a need for International Standards?', 'And what are some of the topics surrounding its standardization?', 'A recent report by the McKinsey Global Institute1) suggests that investment in artificial intelligence (AI) is growing fast.', 'McKinsey estimates that digital leaders such as Google spent between “USD 20 billion to USD 30 billion on AI in 2016, with 90% of this allocated to R&D and deployment, and 10% to AI acquisitions”.', 'According to the International Data Corporation2) (IDC), by 2019, 40% of digital transformation initiatives will deploy some sort of variation of AI and by 2021, 75% of enterprise applications will use AI, with expenditure growing to an estimated USD 2 billion.', 'From perception to reality', 'But what exactly is AI?', 'According to Wael William Diab, Chair of the new technical committee ISO/IEC JTC 1, Information technology, subcommittee SC 42, Artificial intelligence, the field of AI includes a collection of technologies.', 'The newly formed committee has started with some foundational standards that include AI concepts and terminology (ISO/IEC 22989).', 'Diab stresses that the interest in AI is quite broad, bringing together a very wide range of diverse stakeholders such as data scientists, digital practitioners, and regulatory bodies.', 'He also points out that there’s something of a gap between what AI actually is today and what it is often perceived to be.', '“People tend to think of AI as autonomous robots or a computer capable of beating a chess master.', 'To me, AI is more of a collection of technologies that are enabling, effectively, a form of intelligence in machines.”', 'He also explains that AI is often seen as a group of fully autonomous systems – robots that move – but, in reality, much of AI goes into semiautonomous systems.', 'In many AI systems, a good deal of data will have been prepared before being fed into an engine that has some form of machine learning, which will then, in turn, produce a series of insights.', 'These technologies can include, but are by no means limited to, machine learning, big data and analytics.', 'Umbrella of technologies', 'Currently a Senior Director of Huawei Technologies, Diab is Chair of the ISO/IEC subcommittee for good reason.', 'Armed with several degrees in electrical engineering,', 'McKinsey Global Institute, Artificial Intelligence: The Next Digital Frontier ?', 'IDC, US Government Cognitive and Artificial Intelligence Forecast 20182021', 'ISOfocus_131', 'ISOfocus_13119', 'economics and business administration from both Stanford and Wharton, his professional life has focused closely on business and technology strategy.', 'Moreover, he has also worked for multinational conglomerates Cisco and Broadcom as well as been a consultant specializing in Internet of Things (IoT) technologies, most recently as the Secretary of the Steering Committee of the Industrial Internet Consortium.', 'He has also filed over 850 patents, of which close to 400 have been issued, with the rest under examination.', 'That’s more patents than those filed by Tesla – and not one of his applications has been rejected.', 'Diab’s true specialism lies in the breadth of his expertise – his range stretches from the early incubation of ideas to strategically driving the industry forward.', 'It’s also why he’s so keen on standardization, as he sees it as the perfect vehicle for the healthy expansion of the industry as a whole.', 'He argues that we need standards for AI for several reasons.', 'First, there’s the degree of sophisti ...
# 2 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-한
# 2 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-영
# TE-한국표준협회-ISOfocus_131_en (기사 2)-
# ['표준', '표준 작성자를 위한 유용한 정보', '표준 작성', '방법', '표준 작성', '방법', '지침서 이용 방법', '분명한 언어로 작성', '올바른 동사 사용', '제목', '목차', '서문', '소개', '적용 범위', '인용 표준', '용어와 정의', '절과 항', '비고와 보기', '표와 그림', '수학 공식', '부속서', '참고문헌', '그래픽 기호', '적합성 평가', '관리 시스템 표준(MSS)', '템플릿 및 선호하는 파일 형식', '목차', 'ISO표준 작성 방법 – 1', '이 지침서는 명확하고 간결하면서도 사용자 친화적인 국제 표준과 ISO 문서의 작성을 돕기 위한 자료이다.', '자세한 작성방법 및 서식은 ISO/IEC Directives, Part 2, 2016, Principles and rules for the structure and drafting of ISO and IEC documents를 참조한다.', '지침을 인용한 경우 관련 표제 옆의 소괄호 안에 표기한다.', '지침서 이용 방법', '분명한 언어로 작성', '항상 사용자를 염두에 두고 문서를 작성한다.', '분명한 언어 사용은 메시지를 명확히 전달하는 효과적인 방법이다.', '명확하고 간결하되 단순화하지 않는다면 작성자의 의도에 대한 오해의 여지를 방지할 수 있다.', '또한 번역 시 소요되는 시간과 비용도 절약할 수 있다.', '분명한 언어는 이해가 쉬우므로 초안 작성 시 토론에 필요한 시간도 아낄 수 있다.', '분명한 언어의 사용은 반드시 메시지의 길이를 줄여야 한다거나, 의미를 곡해한다거나 꼭 문장을 간소화해야 한다는 의미가 아니다.', '분명한 언어를 사용하는 방법:', '주된 메시지를 스스로 명확히 정하고 크게 소리 내어 읽어 본다.', '독자의 입장에서 생각한다.', '문장을 짧게 유지한다.', '하나의 개념을 한 문장으로 표현한다.', '불필요한단어를 제외한다.', '가능한 경우 목록을 사용한다.', '가능하면 능동태를 사용한다.', '문장을 간결하게 표현하고, 짧고 단순한 단어를 사용하며 동사를 명사화하지 않는다.', '구두점을 주의 깊게 사용한다.', '마침표를 더 많이 사용하고 쉼표와 괄호 수를 줄인다.', '요지를 긍정적으로 표현한다.', '가능하면 일상적인 언어를 사용하고 전문 용어를 줄인다.', '분명한 언어는 적용 범위에서 특히 중요하다.', '힌트', '같은 개념에 대한 사용 용어를 통일한다.', '동의어는 사용하지 않는다.', 'ISO표준 작성 방법 – 3', '시리얼과 펄스 – 시방서 및 시험 방법 – 1부: 쌀', '(소개 요소)(주 요소)\t(보충 요소)', '제목(11절)', '제목은 명확하고 간결해야 하며 최대 세 가지 요소를 포함해야 한다.', '소개 요소', '주 요소', '보충 요소', '목차', '목차는 자동으로 생성된다.', '서문(12절)', 'ISO 문서의 서문은 ISO 중앙 사무국이 편집 및 발행 시 삽입한 일반 텍스트를 포함한다.', '기존 표준을 개정하는 경우 이전 판과 비교한 주요 변경 내용 목록을 포함한다.', '올바른 동사 사용', '모든 절에서 요구 사항과 권고 사항 또는 다른 유형의 설명을 명확히 구분한다.', '사용자가 해야 할 일을 명확히 밝히기 위해 ISO 문서에는 다음과 같은 동사를 사용한다.', '요구사항 – shall(해야 한다), shall not(하지 않아야 한다)', '권고사항 – should(하는 것이 좋다), should not(하지 않는 것이 좋다)', '허용사항 – may(해도 된다), need not(하지 않아도 된다)', '가능성 및 능력 – can(할 수 있다), cannot(할 수 없다)', '힌트', '소개와 적용범위의 정보가 중복되지 않는지 확인한다.', ' – ISO표준 작성 방법', '소개', '이 문서는 국제적으로 거래되는 쌀에 대한 최소 시방서를 원하는 전 세계의 요구에 부응하여 작성되었다.', '체질과 키질을 하지 않은 대다수의 상용 곡물은 다른 곡물, 잡초 씨앗, 왕겨, 짚, 돌, 모래 등을 포함하고 있기 때문이다.', ' 적용범위', '이 문서는 쌀(Oryza sativa L.)에 대한 최소 요구 사항과 시험 방법을 지정한다', '이 표준은 사람이 직접 또는 재처리 후 소비하기에 적합한 현미, 앵미, 반도정미 및 반도정 찐쌀에 적용된다.', '조리한 쌀 제품에는 적용되지 않는다.', '적용범위(14절)', '적용범위는 필수이며 문서의 역할을 설명한다.', '예를 들어 이 문서는', '을(를) 지정한다.', '을(를) 설정한다.', '에 대한 지침을 제공한다.', '용어 을(를) 정의한다.', '적용범위는 일련의 사실 설명으로 작성한다.', '요구사항, 권고사항 또는 허용사항은 적용범위에 포함하지 않는다.', '소개(13절)', '소개는 선택 사항이지만 ISO는 포함하는 것을 권고한다.', '소개는 문서의 내용을 설명하고 해당 문서가 필요한 이유에 관한 정보를 제공한다.', 'ISO표준 작성 방법 – 5', ' 인용 표준', '다음 문서를 해당 내용의 일부 또는 전부가 이 문서의 요구 사항을 구성하는 방법으로 본문에 인용한다.', '일자가 표기된 인용은 인용한 판 만 적용된다.', '일자가 표기되지 않은 인용은 인용한 문서의 최신판(모든 개정판 포함)을 적용한다.', 'KS H ISO 712(2014 확인), 곡류 및 곡류제품－수분함량측정(상용 법)', 'ISO 24333:2009, 시리얼과 시리얼 제품 –표본화', '인용표준(15절 및 2항)', '인용 표준 절은 문서 내에 표준 인용이 없더라도 필수이다.', '이 절은 해당 내용의 일부 또는 전부가 문서의 요구 사항을 구성하는 방법으로 본문에 인용된 인용 문서를 열거한다.', '(보기: “표본화는 ISO 24333:2009,5절에 따라 수행한다”).', '해당 인용 문서의 특정 절, 항, 그림, 표 등을 가리키는 경우 인용 일시를 표기한다.', '인용은 다른 ISO 및 IEC 표준을 대상으로 한다.', '다른 기관의 문서도 특정 상황에서 인용할 수 있으며, 이 경우 인용은 공개적으로 사용할 수 있어야 한다.', '용어와 정의(16절)', '용어와 정의 절은 문서의 문맥 내에서 특정 단어의 의미를 구체화하는 필수 절이다.', '문서에 사용된 용어만 정의해야 한다.', '힌트', '용어 작성에 대한 지침은 ISO 102411을 참조한다.', ' – ISO표준 작성 방법', ' 용어와 정의', '이 문서의 목적을 위하여 다음의 용어와 정의를 적용한다.', 'ISO와 IEC는 표준화에 사용되는 용어 데이터베이스를 다음 주소에 게재한다.', 'ISO 온라인 검색 플랫폼: http://www.iso.org/obp에서 이용 가능', 'IEC Electropedia : http://www.electropedia.org에서 이용 가능', '특수 언어', '특별한 목적을 위한 언어', 'LSP', '영역(2)에 사용하고 특정 언어 표현 수단을 사용하는 특징이 있는 언어', '비고 1: 특정 언어 표현 수단은 항상 영역별 또는 주제별 용어와 다른 종류의 호칭 및 어법을 포함하며 문체 또는 구문 기능을 하는 경우도 있다.', 'ISO표준 작성 방법 – 7', '힌트', '약어화된 용어와 기호를 3절 바로 뒤의 별도 절에 열거할 수 있다.', 'ISO 문서의 용어와 정의는 ISO 온라인 검색 플랫폼(www.iso.org/ obp)에서 이용 가능하다.', '이미 정의된 용어를 찾으려면 위원회 및 표준별 OBP를 검색한다.', '정의는 사용 시 용어를 대체할 수 있는 단일 문구이다.', '정의는 관사(보기: “a”, “the”)로 시작하거나 마침표로 끝나지 않는다.', '또한 정의는 요구 사항이나 권고사항의 형태를 띠거나, 포함하지 않는다.', '추가 정보는 비고 또는 보기에 포함될 수 있다.', '아래 보기는 용어 작성에 포함할 수 있는 요소의 범위를 나타낸다.', '절과 항(22절)', '절과 항은 ISO 문서의 주요 부분을 이루며, 적용 시 해야 할 일을 문서 사용자에게 알려준다.', '독자가 문서의 핵심 부분을 인용하기 쉽도록 절과 항에는 번호를 매긴다.', 'ISO는 ISO  ...
# ['standards', 'Tips for standards writers', 'How to', 'Write standards', 'How to', 'Write standards', 'How this brochure can help you', 'Writing plain language3', 'Verbal forms', 'Title', 'Table of contents', 'Foreword4', 'Introduction5', 'Scope', 'Normative references', 'Terms and definitions', 'Clauses and subclauses8', 'Notes and Examples .', 'Tables and Figures10', 'Mathematical formulae', 'Annexes', 'Bibliography14', 'Graphical symbols', 'Conformity assessment', 'Management system standards (MSS)', 'Templates and preferred file formats', 'Contents', 'ISOHow to write standards – 1', 'This brochure is designed to help people write clear, concise and userfriendly International Standards and other ISO documents.', 'For more detailed drafting and editorial rules, see the ISO/IEC Directives, Part 2, 2016, Principles and rules for the structure and drafting of ISO and IEC documents.', 'References to the Directives are given in parentheses next to the relevant header.', 'How this brochure can help you', 'Writing plain language', 'Write your document with the user in mind.', 'Using plain language is an effective means of getting your message across.', 'By being clear and concise – but not simplistic – writers can avoid misinterpretation.', 'This reduces time and cost in translation.', 'Because plain language is easier to understand, it also reduces discussion during drafting.', 'Using plain language does not mean reducing the length of your message, changing its meaning or oversimplifying your text.', 'How to use plain language:', 'Be clear to yourself about your main message – try reading it to yourself out loud', 'Put yourself in the place of the reader', 'Keep your sentences short', 'Have one idea per sentence', 'Leave out words you don’t need', 'Use lists when you can', 'Use the active voice when you can', 'Be concise, use short, simple words and avoid turning verbs into nouns', 'Punctuate your writing carefully', 'Use more full stops, fewer commas and brackets', 'Phrase your points positively', 'Use everyday language whenever possible and reduce jargon', 'Plain language is particularly important in the Scope', 'HINT', 'Use the same term for the same concept everywhere.', 'Don’t use synonyms', 'ISOHow to write standards – 3', 'Cereals and pulses – Specification and test methods – Part 1: Rice', '(introductory)(main)\t(complementary)', 'Title (Clause 11)', 'The Title must be clear and concise, containing a maximum of three elements :', 'an introductory element', 'a main element', 'a complementary element', 'Table of contents', 'The Table of contents is automatically generated.', 'Foreword (Clause 12)', 'The Foreword of an ISO document contains generic text which is inserted by ISO Central Secretariat during editing and publishing.', 'When revising an existing standard, include a list of the major changes compared with the previous edition.', 'Verbal forms', 'In all clauses, be clear about what is a requirement and what is a recommendation or other type of statement.', 'In order to make clear what the user must do, the following verbal forms are used in ISO documents :', 'Requirements – shall, shall not', 'Recommendations – should, should not', 'Permission – may, need not', 'Possibility and capability – can, cannot', 'HINT', 'Check that information is not duplicated between the Introduction and the Scope', ' – ISOHow to write standards', 'Introduction', 'This document was developed in response to worldwide demand for minimum specifications for rice traded internationally, since most commercial bulks of grain, which have not been screened or aspirated, contain a proportion of other grains, weed seeds, chaff, straw, stones, sand, etc.', ' Scope', 'This document specifies minimum requirements and test methods for rice (Oryza sativa L.).', 'It is applicable to husked rice, husked parboiled rice, milled rice and milled parboiled rice, suitable for human consumption, directly or after reconditioning.', 'It is not applicable to cooked  ...
# 3 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-한
# 3 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-영
# TE-한국표준협회-how-to-write-standards-2018-
# ['한국의 R&D표준화 연계 제도', 'National System for Linking', 'R&D and Standardization in Korea', 'Version 0', '25', 'Mr. JongIn HONG', 'Korea Institute of Standards', 'And Conformity Assessment', '(KISCA)', 'R&D‒표준화 연계에 관한 국제적 동향', '한국의 R&D‒표준화 연계 정책 및 제도', '한국의 R&D‒표준화 연계 현황', 'R&D‒표준화 연계 필요성', '표준화 예산 확보를 위한 조언', '한국의 R&D‒표준화 연계 성과', 'EU의 BRIDGIT 프로젝트', 'R&D 표준화 연계 성공사례', '부록', ' R&D표준화 연계 필요성', 'Why Link R&D and Standardization?', 'R&D표준화 연계 필요성', '왜 “R&D”와 “표준화” 를', '연계하는가?', 'R&D표준화 연계 필요성', '개발 기술의 확산 및 시장 지배 여부를 결정하는 국제표준 선점이 글로벌 경쟁력의 필수 요소', '국제표준 선점을 위해서는 R&D 개발 기술의 표준화 연계가 반드시 필요', 'R&D표준화 연계 필요성', '국가기술개발사업(R&D)의 최종목표가 사업화이기 때문에', '시장진입의 필수요소인 개발 기술의 (국제)표준화는 필수사항', '기술성숙도(TRL, Technology Readiness Level) 9단계', 'R&D 프로세스에서의 표준 유형', 'R&D 프로세스에서 활용되거나 개발되어야 하는 표준의 유형은 다음과 같다.', 'R&D표준화 연계 목적', 'R&D 프로세스의 효율적 수행에 기여', '짧아지는 기술개발 주기 추세에 대응', 'R&D 결과의 확산 및 전파의 도구로 활용', '인터페이스/호환성 표준 등의 적용은\x0b시장 접근성을 높이고 기술 개발 방향 정립에 도움을 줌', 'R&D 후 표준화 추진으로는 융합/신기술 등 빠른 기술 변화 환경에 적기 대응이 어려움', '표준화는 개발 기술의 보편적 사용을 보장하므로\x0b개발 기술의 사업화를 촉진', '유럽 5차 프레임워크 프로그램 (5FP) 543명의 코디네이터 대상 조사', '대상', '연구개발과 표준화의 상관관계 및 표준화 활동 참여 동기 등', '조사내용', '연구개발 시 관련성이 높은 표준의 영역은 인터페이스 및 적합성 표준, 용어 및 분류표준, 측정 및 시험방법 표준, 품질 및 안전표준의 순으로 관심이 높음', '기초연구와 같은 연구개발 초기 단계보다 응용연구와\x0b같은 사업화 단계에서 표준이 보다 많은 관련성을 가짐', '기술적 문제의 해결, 연구결과의 확산, 네트워킹 등', 'R&D표준 연계 설문조사(1/2) : 국외 (유럽)', 'R&D표준 연계 설문조사(2/2) : 국내', '국내 전문가 161명 대상 조사', '대상', 'R&D표준화 연계가 필요한 표준유형 및 R&D 활동에서 표준화 활동 참여 목적', '조사내용', '품질/성능 〉 적합성/시험방법 〉 호환성 표준 순서', '표준화를 통한 연구개발 결과의 확산, 기술적 문제 해결, 네트워킹 등', ' R&D표준화 연계에 관한 국제적 동향', 'Global Trend of Linking R&D and Standardization', '주요국의 R&D표준 연계 전략', 'EU의 R&D표준화 연계 전략', 'EU의 연구혁신(R&I)과 표준화 연계 전략', 'EU는 신기술 부문의 연구개발과 표준화를 병행하는 것을 전략적 수단으로 인식하고, EU 공동개발 연구활동, 일명 프레임워크 프로그램’을 중심으로 연구개발 활동과 표준화 활동의 연계성 강화 정책을 추진하고 있다.', '유럽집행위원회(European Commission)의 Framework Program 및 Horizon 2020', '주요 대상 분야는 정보통신기술, 공업기술, 환경, 생명공학, 에너지수송 등이다.', '프레임워크 프로그램은 EC가 중심이 되어 4~5년을 주기로 전체 유럽에서 대응하는 연구기술계획을 책정하여 공모하고 있다.', '복수국가의 연구기관, 대학, 기업 등이 연계하는 연구개발에 대하여 EC가 기금을 지원한다.', '이러한 프레임워크 프로그램과 연계하여 CEN의 STAR (Standardization and Research) 프로젝트는 프레임워크 프로그램의 연구개발과제 우선 목록을 CEN이 EU에 제출하도록 하고 있다.', '이처럼 EU의 연구개발 프로젝트는 처음부터 성과를 표준화한다는 전제로 추진되고 있다.', 'EU는 CEN & CENELEC의 표준화 활동과 EU의 프레임워크 프로그램의 연계 정책을 확립하여 시행하고 있다.', 'EU의 R&D표준화 연계', 'CEN & CENELEC의 BRIDGIT 프로젝트', 'EU는 오래 전부터 연구와 표준화 연계의 중요성을 인식하고 EU의 연구혁신(R&I, Research & Innovation) 프로젝트에 표준화를 연계시켜 왔음에도 불구하고 R&I와 표준화의 연계 시너지가 높지 않다고 판단하고,', 'R&I와 표준화 간의 Gap을 연결하기 위한 “BRIDGIT(Bridging the Gap between Research and Standardization)"라는 프로젝트를 실시하였다.', '미국의 R&D표준화 연계 전략', '미국은 국가경쟁력 제고 전략으로 첨단기술프로그램(ATP)에 R&D 표준화 연계', 'R&D 표준화 연계는 국가경쟁력 제고 전략', '첨단기술개발 프로그램(ATP) 추진 시 표준화 연계', 'R&D 과제 평가 시 성과보급과 표준화를 고려', 'R&D 표준화 연계는 국가경쟁력 제고 전략', '미국은 국가경쟁력 제고 전략의 일환으로 연구개발과 표준화를 연계하고 있다.', '국립과학재단(NSF, National Science Foundation)에서 컴퓨터 네트워크 등 정보통신 분야 중심의 연구개발과 표준화 연계 추진 과제를 우선 지원하고 있다.', 'ITS(지능형교통시스템) 사업과 같은 대형 시스템 개발은 정부가 표준화 예산을 지원하였다.', '첨단기술프로그램(ATP) 추진 시 표준화 연계', '정부 주도의 첨단기술프로그램(ATP, Advanced Technology Program) 추진 시 산업경쟁력 강화를 위해 연구 결과의 시장 잠재력, 향후 상용화 계획 등의 표준화 연계 평가를 실시하고 있다.', 'ATP 프로그램 도입으로 설계․제조(CAD/CAM)의 데이터교환 표준(STEP)에 대한 국제표준을 선도하고, 제조업은 이 표준을 부품공급망관리(SCM)에 활용하여 설계제조 시간을 50% 단축시켰다.', 'R&D 과제 평가 시 성과보급과 표준화를 고려', '미국은 연구개발 과제를 공모하여 평가하는 과정에서 성과보급과 표준화를 동시에 고려하는 정책을 실시하고 있다.', '최근에는 정부의 표준 이용과 민간 표준화 활동에 대한 모니터링 등 정부의 역할을 제도적으로 강화하고 있다.', '정부기관인 국립기술표준원(NIST)은 장기적이고 시스템적인 표준화 연구를 수행하며, 민간 표준화기구인 ANSI와 MoU를 통해 정부와 민간의 표준화 교류를 확대하고 있다.', '국가표준화 정책을 강화하기 위해 2012년도 NIST의 예산을 약 10억 달러 수준으로 증액하여 배정하였다 (2010년 대비 8% 증액).', '일본의 R&D표준화 연계', '일본은 연구개발 활동과 국제표준화 활동을 일체적으로 추진하여 국가적 차원의 국제표준화 활동을 강화', '국제표준종합전략 (지적재산전략본부, 2006)', '신산업 창조전략 2005 (경제산업성, 2005)', '일본의 국제경쟁력을 강화하기 위한 연구개발표준화전략 (총무성 산하 정보통신심의위원회)', 'NEDO의 국가연구개발과 국제표준화 연계 전략', '신에너지 산업기술 종합개발기구(NEDO, New Energy and Industrial Technology Development Organization)', '국제표준종합전략 (지적재산전략본부, 2006)', '일본의 지적재산전략본부는 2006년 경제의 급격한 글로벌화 및 세계 시장의 일체화에 따른 표준의 중요성 증대, WTO/TBT협정 등 급변하는 표준관련 환경에 발맞추어 국제표준화에 적극적으로 대응하기 위해 ｢국제표준종합전략｣을 수립하였 ...
# ['National System for Linking R&D and Standardization in Korea', 'National System for Linking', 'R&D and Standardization in Korea', 'Version 0', 'August 25, 2019', 'Mr. JongIn HONG', 'Korea Institute of Standards', 'And Conformity Assessment', '(KISCA)', 'Global Trends on Linking R&D and Standardization', 'Strategies and Systems for Linking R&D and Standardization in Korea', 'Status of Linking R&D and Standardization in Korea', 'Why Link R&D and Standardization?', 'Advice on Securing Budget for Standardization', 'Results of Linking R&D and Standardization in Korea', 'EU’S BRIDGIT Project', 'Case Study: Successful Linkage between R&D and Standardization', 'Appendix', 'Why Link R&D and Standardization?', 'Why Link R&D and Standardization?', 'Why should we link', '“R&D” and “standardization?”', 'Why Link R&D and Standardization?', 'Efforts to disseminate technologies and attain market dominance rely on international standards.', 'Preemptively securing international standards is key to gaining global competitiveness.', 'Securing international standards requires linkage between R&D and standardization.', 'Why Link R&D and Standardization?', 'The ultimate goal of national R&D programs is to gain entry into the relevant market.', 'Gaining market access requires having the developed technologies adopted as (global) standards.', ' Technology Readiness Levels (TRLs)', 'R&D for Core Industrial Technology Development Program', 'Level 1', 'Level 2', 'Level 3', 'Level 5', 'Level 4', 'Level 6', 'Level 7', 'Level 8', 'Level 9', 'Basic Theory/Experiment', 'Technology formulation, including practical ideas and patents', 'Labscale basic performance evaluation', 'Labscale part/system performance evaluation', 'Part/system prototype', 'Prototype performance evaluation', 'Prototype reliance evaluation', 'Prototype certification and standardization', 'Commercialization', 'Basic Research', 'Experiment', 'Prototype', 'Application', 'Commercialization', 'Types of Standards Associated with R&D Processes', 'The following standards need to be applied or developed in R&D processes.', 'Purpose of Linkage between R&D and Standardization', 'Contribute to the efficient performance of R&D processes', 'Address evershortening cycles of technology development', 'Use standardization as a means to disseminate and diffuse R&D outcomes', 'Interface/compatibility standards improve market accessibility and assist with determining the directions of technology development.', 'Pursuing standardization “after” R&D efforts makes it difficult to respond to rapid changes in technology (convergent/new technologies).', 'Standardization ensures the universal use of developed technologies and, therefore, promotes the commercialization of the technologies.', 'Survey of 543 Coordinators Participating in European Commission’s Fifth Framework Programme (5FP)', 'Eligibility', 'Correlation between R&D and standardization, and reason for participating in standardization activities', 'Findings', 'The areas deemed the most relevant to R&D efforts were, in the order of percentages of respondents:interface and conformity standards,semantic and classification standards,measurement and testing standards, andquality and safety standards.', 'Standards are more relevant during the commercialization phase (applied research, etc.)', 'rather than the early phase (basic research, etc.', ').', 'Resolution of technical issues, dissemination of research findings, networking, etc.', 'R&DStandardization Linkage Survey (1/2): Europe', 'R&DStandardization Linkage Survey (2/2): Korea', 'Surveyed 161 Korean experts', 'Eligibility', 'Types of standards requiring linkage between R&D and standardization, and purpose of R&D personnel participating in standardization activities', 'Findings', 'In the order of percentages of respondents: quality/performance > conformity/testing > compatibility standards', 'Dissemination of R&D outcomes through standardization; solution of technical issues; networking', 'Global Trends ...
# 4 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-한
# 4 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-영
# TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-
# ['표준 혁신의 가교', '연구와 혁신 사업에서의표준화', '성공 일화: 친환경 기반 경제', 'Darden Hood,', '미국, 베타분석학 회장', 'http://www.kbbpps.eu', '표준: 시장 활용을 위한 해결안', '사업', 'KBBPPS:', 'KYTan _Shutterstock', '바이오 정제와 친환경 기반 경제의 실질적 성장에서 직면한 주요 도전과제 중 하나는 제품의 속성에 관한 명확하고도 조화를 이룬 일련의 표준을 들 수 있다.', '지식 기반의 친환경 제품 사전 표준화(Knowledge Based Biobased Products’ PreStandardization, KBBPPS) 사업은 이러한 제품에 대한 친환경 내용물 결정과 생분해성 시험체계를 다룬다.', '생분해성 또는 생물학적 유래 요소에 대한 실험실과 현장시험을 위한 실용적 솔루션을 조사 중이다.', '결과를 유럽 표준에 일대일로 복사하는 것을 목표로 한다.', 'CEN에의 참여와 전규범적 및 공동규범적 연구를 통해 KBBPPS는 유럽 이해관계자들이 실제 현장 행동과 실험실에서의 적용성에 상관되어 있는 견고하고 잘 정의된 시험 방법으로 진행하도록 허용한다.', 'KBBPPS는 친환경적 제품에 대해 전규범적 및 공동규범적 작업을 시작해왔다.', '사업에서는 14C 분석에만 의존하지 않고 생분해성과 생태독성 시험체계에도 의존하는 생물량 함량 방법인 바이오 기반 탄소 함유량 결정에 관한 연구와 시연을 다룬다.', '시험 방법론을 개발, 조화 및 검증하는 것을 목적으로 기능과 관련된 장애를 식별하고 해결한다.', '바이오 기반 탄소와 기타 바이오 기반 요소 결정을 다루기 위해 시료 준비, 분류 및 열처리 가능성을 연구하였다.', '사업에서는 생물학적 분해와 관련된 이해관계자, 실험실 및 현장시험에 대해 또는 생물학적으로 유도된 물질이나 요소의 양을 결정하기 위한 실용적인 솔루션을 개발한다.', '이를 위한 목표는 대부분 바이오 기반 제품’에 관한 CEN/TC 411에 의거하여 일대일로 유럽 표준에 복사 가능하다.', '사업은 2012년 9월부터 2015년 8월까지 진행된다.', '바이오 정제와 친환경 기반 경제의 실질적 성장에 직면한 주요 도전과제 중 하나로, 시장에서 바이오 기반’으로 입지가 잡힌 제품의 속성에 대한 조화를 이룬 일련의 명확한 표준을 들 수 있다.', '소비자가 정확한 제품 정보를 수신하도록 보장하기 위해, 여러 특징(예: 생물 분해성, 환경 안전성, 바이오 기반 내용, 성능)에 대해 잘 정의된 통과 기준을 아우르는 시방서 기준을 설정해야 한다.', 'KBBPPS는 이러한 주제에 관한 전규범적 연구를 지원한다.', 'KBBPPS 사업에서는 친환경 제품에 관한 기능 친환경 내용물과 기능 표준, 라벨 및 인증 시스템의 적용을 용이하게 하고 증가시키는 것을 목표로 합니다.', '다양한 친환경 제품에 적용 가능한 생물량 내용물을 올바로 파악하는 것은 유럽과 전 세계 생명공학과 바이오매스 산업 발전에 상당한 관련성이 있습니다.', '이메일: research@cencenelec.eu', '전화 + +32 2 550 08 11', 'Avenue Marnix, 17 B1000 Brussels, Belgium', '출판인: Andreea Gulacsi – CEN & CENELEC 2014년 9월', '모든 사업은 다릅니다.', 'CENCENELEC 연구 헬프데스크는 귀하의 사업에 표준화를 포함시키는 방법에 대해 자문을 제공합니다.', '여러분의 연락을 기다립니다!', 'www.cencenelec.eu/research', 'CEN/TC 411 회장이자 DSM 지속가능성 이사, Frederic Petit', '다른 원자를 포함해탄소 원자를 주시해야 하는 도전과제가 있습니다.', '여기서 질문은 제품 내 탄소를 재생 가능한 원재료에서 얻을 수 있는지 여부입니다.', '주어진 물질이 고고학에 어떻게 사용되는지 결정하는 것과 동일한 방식으로친환경적 내용물을 결정할 수 있습니다.', '성능이 좋은 친환경 제품에는 분명한 표준이 필요합니다.', '결국 OpenBio 사업에서 계속하게 될 KBBPPS 업무에서 도전과제는 각 바이오 제품의 기능을 설명하는 정확하고, 재생 가능하며, 신뢰할 수 있는 표준을 도출하는 데에 있다.', '이는 생산자가 시중에서 이용할 수 있는 일반적인 비 바이오 제품에 비해 자사 제품을 제시하도록 허용한다.', '이는 사용자, 소비자, 정책입안자에게 자신감을 주고, 고의로 사용을 피한 오래된 자원에 대한 아이디어를 제시하여 결과적으로 바이오 제품의 시장 수용에 기여할 것이다.', '표준을 어떻게 개발하였는가?', 'Steve Woods_Shutterstock', 'www.losfeld.be', 'KBBPPS 사업은 첫 연구 과제로 현행 생분해법과 생태독성 표준을 검토하였다.', '표준 개발에 진전은 있지만 여전히 유의한 괴리가 있다는 결론의 공공보고서를 도출할 수 있었다.', '연구와 실험실 경험을 바탕으로 CEN/ TS 16640 “바이오 기반 제품 방사성탄소 방법을 사용하는 제품의 바이오 기반 탄소 함유량 결정”이라는 유럽 사전표준이 제정되었다.', 'KBBPPS에서 일부 사업에 대해서만 기법을 평가하고 여러 실험실과의 상호검증조사를 완료하여 더 많은 작업을 예상하면서 TS가 제정되었으나, 머지않아 유럽 표준(EN)의 업그레이드 버전이 될 것으로 예상된다.', 'KBBPPS는 물질균형기법 또는 간접 결정에 대해 추가 연구를 실행할 것이며, 처리 체계 검사 또는 요소 분석으로 뒷받침될 것이다.', '또한 KBBPPS는 제품을 생물 및 비생물 요소로 나누고, 이론적 바이오매스 함유량을 계산할 수 있는 소프트웨어 프로그램을 개발해왔다.', '표준화와의 연계는 본 사업 정보를 CEN/TC 411의 정보와 동일한 웹사이트에 게시한다는 사실로 뒷받침된다: www.biobasedeconomy.eu', '표준화는 본 사업의 핵심 보급 활동으로, 사업 결과의 잠재적인 장기 사용과 영향에 있어 기반으로 간주된다.', 'KBBPPS 사업의 업무는 전규범적 및 공동규범적 작업으로 간주할 수 있다.', '기술시방서 CEN/TS 16640은 바이오 기반 생성물과 제품의 실험실, 생산자, 공급자 및 구매자를 위한 기준시험방법을 제공한다.', '당국과 검사기관에도 유용하다.', '개발된 방법론은 모든 바이오 기반 제품에 대한 개념을 형성하며, 특정 제품에만 해당되는 것이 아니다.', '바이오 내용물과 생분해 방법은 실제 장 거동(field behavior)과의 관계, 등급 및 품질 수준의 지표를 제시하기 위하여 반복성과 관련해 시험 될 것이다.', '관련 표준화 활동이 뒤따라야 한다.', '생분해법과 기능 격차에 대한 업무는 또 다른 FP7 사업인 OpenBio 사업에서 더욱 발전될 것이다.', '결과를 비롯해 개발된 시험 방법론 초안은 추후 표준화를 위해 CEN과 다른 표준화 기관으로 제출될 것이다.', '표준화와 연계 혜택', '장기적 예상 영향']
# ['Standards Your Innovation Bridge', 'Standardization\x0bin research and innovation projects', 'Success story: biobased economy', 'Darden Hood,', 'President of BetaAnalytics, USA', 'http://www.kbbpps.eu', 'STANDARDS: A SOLUTION FOR MARKET UPTAKE', 'THE PROJECT', 'KBBPPS:', 'KYTan _Shutterstock', 'One of the main challenges for the real takeoff of biorefineries andthe biobased economy is a clear,harmonized and unambiguousset of standards about theproperties of the products.The KBBPPS (KnowledgeBased Biobased Products’ PreStandardization) project coversbiobased content determinationand biodegradability test schemesfor these products.', 'Practicalsolutions for lab and field testson biodegradation or biologicalderived elements are investigated.The goal is copying the resultsonetoone into Europeanstandards.', 'By participating inCEN and by doing preand conormative research, KBBPPSallows European stakeholdersto progress with welldefined,sound test methods correlatedto actual field behaviour andapplicability in the lab.', 'KBBPPS has been initiated to execute preand conormative work for biobasedproducts.', 'The project covers researchand demonstration activities on biobased carbon content determination,biomass content methods not solelydependent on 14Canalysis, as well asbiodegradability and ecotoxicity testschemes.', 'Identification and resolutionof functionality related bottlenecks withthe view to developing, harmonizingand validating test methodologies areundertaken.', 'The possibilities for improvingsample preparation, fractionation andthermal treatments are studied in orderto cover biobased carbon and otherbiobased elements determination.The project develops practical solutionsfor stakeholders, lab and field tests onbiodegradation or determining the amountof biologically derived material or elements.The goal in the end is that the results canbe copied onetoone into Europeanstandards, mostly under CEN/TC 411 on“Biobased products”.', 'The project runsfrom September 2012 until August 20', 'One of the challenges for the takeoff ofbiorefineries and the biobased economyis a clear, harmonized and unambiguousset of standards about the properties ofthe products placed on the market as being’biobased’.', 'To ensure that consumersreceive accurate product information,standardized test methods should setthe benchmark for specifications, whichencompass welldefined pass criteria fordifferent characteristics (e.g.', 'biodegradation,environmental safety, biobased content,performance).', 'KBBPPS is supporting theprenormative research on these topics.', 'The KBBPPS project aims at facilitating and increasing the application of biocontent and functionalitystandards, labels and certification systems for biobased products.', 'A correct identification of the biomasscontent, applicable to a wide variety of biobased products is of great relevance for the further development of the biotechnology and biomass industry in Europe and worldwide.', 'Email: research@cencenelec.eu', 'Tel.', '+32 2 550 08 11', 'Avenue Marnix, 17 B1000 Brussels, Belgium', 'Publisher : Andreea Gulacsi – CEN & CENELEC September 2014', 'Every project is different.', 'The CENCENELEC Research Helpdesk', 'can provide you with advice on how to include standardization in your project.Please feel free to contact us!', 'www.cencenelec.eu/research', 'Frederic Petit, Sustainability Director of DSM and Chairman of CEN/TC 411', 'One of the challenges is to look to the carbon elementalso including other atoms.', 'Question is whether the carbon inproducts is derived from renewable raw materials.', 'Then you cansimply determine the biobased contentthe same way youdetermine how old a given substance is as used in archaeology.For biobased products performing well, clear standards arerequired.', 'The challenge is for the KBBPPS work eventually continued by the OpenBioproject to result in a correct, reproducibleand reliable set of standards that describethe functioning of each biobased product.This al ...
# 5 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-한
# 5 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-영
# TE-한국표준협회-BRIDGIT-(사례)바이오_1-
# ['유럽표준화위원회', '연구와 혁신 사업에서의표준화', '성공 일화: 정보기술', '에스트렐라', '법적 접근성을 확대하기 위한 표준화되고 투명한 대표를 위한 유럽 사업(에스트렐라)은 18개월간 진행된 FP6 (유럽연합의 제6차 연구 프레임워크 프로그램) 사업이었다.', '법적 지식체계 전문가와 유럽 기업을 한데 모아 법적 자료와 관련해 혁신적이고 개방적인 플랫폼의 개발, 입증 및 보급을 위하여 협력을 도모하였다.', '본 사업을 통해 법적/법률적 자원에 관한 오픈 XML 교환 포맷을 위한 유럽 사전표준을 개발하였다.', 'CEN 메타렉스(MetaLex)는 소스와 참조를 XML로 표현하는 방식을 표준화하는 포괄적인 구조 틀을 제공한다.', '이는 법적 조문에 신시장을 개척한다.', 'www.metalex.eu', '사업', '법적 자료를 대표하고 이를 지식 기반에 연계하는 일은 사소한 업무가 아니다.', '법적 자료는 여러 내적 구조와 여러 언어로 된 다양한 법률 제도를 이용하는 다양한 관할 당국으로부터 다양한 형태와 포맷으로 이용할 수 있다.', 'ICT는 증가하는 법체계를 다루는 데에 있어 정부와 시민을 지원할 수 있는 잠재력이 있지만, 구조화된 표준양식으로 법적 자료의 전자식 이용이 가능해야만 한다.', '에스트렐라는 이러한 요구에 대해 주도적인 유럽 전문가와 기업이 법적 지식 체계에 대한 혁신적이고 개방적인 플랫폼의 개발, 입증 및 보급에 협력하도록 화합하는 것으로 대응했다.', '표준: 시장 활용을 위한 해결안', '지난 10년간 입법자들은 그들이 관리하는 공식 법적 자료에 대해 XML표준을 채택하기 시작했다.', '하지만 관할 당국마다 상이한 법령 출판 방식을 개발해왔고, 상이한 검색 및 작업 도구를 개발해왔다.', '한 가지 잠재적 해결책은 법적 조문의 교환에 사용 가능한 동시 조작 및 검색 도구 개발을 위한 플랫폼으로 이용 가능한 개방형 교환 표준’의 개발이 있다.', '에스트렐라 사업과 에스트렐라 협력단 회원으로부터 기본적인 지지와 투입을 제공 받은 메타렉스 사업은 그러한 표준의 개발을 목표로 해왔다.', '해당 사업의 직접적인 결과로, 법령에 대해 새로운 XML 문서 스키마, CEN 메타렉스이 개발되었고, CEN 워크숍 협약(CWA)으로 유럽 수준에서 발행되었다.', '이러한 사전표준은 법령에 대한 국가 XML 표준을 보완 및 통합하고, 법적 조문의 검색, 교환 및 연계를 지원한다.', '광범위한 마크업 언어.', '주석 문서용 최신 시스템으로서, 텍스트를 표시하는 소프트웨어가 적절한 실행을 이행하도록 지시하는 구조적 마커가 있으면서 동시에 사용자에게 보이는 텍스트 버전에서 XML을 누락하는 시스템.', '메타렉스는 현재 저희가 이용 가능한 여러 유형의 자원을 관련시키는 데에 [] 성과를 보였다고 생각합니다.', '영국 국립 문서기록 관리청, John Sheridan', '표준을 어떻게 발전하였는가?', '직접적 혜택', '워크숍 과정은 에스트렐라 협력단이 광범위한 산업과 협력할 수 있도록 해주었다.', '법률 관련 출판업자, 행정관, 학계, 연구 집단, 사업을 포함해 20개 이상의 조직이 표준 개발에 참여하였다.', '이러한 협력은 표준 개발에 미래의 소비자를 관여시킬 뿐 아니라 미래 표준이 산업 요구에 일치하도록 보장하는 데에 중요한 역할을 했다.', '표준 개발 중에 해당 분야의 다른 사업에 모범 설계 실무를 고려하도록 확보하는 데에는 산업 참여가 매우 중요했다.', '사업과 워크숍 과정이 동시에 진행되었으므로, CWA 과정의 초기 결과물도 진행 중인 에스트렐라 작업에 중요한 자료가 되었다.', '장기적 영향', 'CWA는 법적 소프트웨어 개발자와 제공자에게 신시장을 열었고, 법령 기관 소비자에게는 상호운용성이라는 중요한 문제를 부각시켰는데, 상호운용성은 동일한 IT 기반시설 내에서 상당히 다른 문서 포맷을 취급하는 데에 유용하기 때문이다.', '그 결과, CEN 메타렉스 표준은 이미 네덜란드 세관, 벨기에 공공복지센터 BeValue 및 기타 기관에서 사용 중이다.', '가령 메타렉스 문서 서버는 현재 수만 개의 규정을 CEN 메타렉스 문서로 관리하면서 CEN 메타렉스 연계 자료로 모든 네덜란드 규정을 공고한다.', '영국에서도 자국 전체에 걸쳐 법적 자료로 접근할 수 있는 신규 웹사이트의 일부로 해당 표준을 사용 중이다.', 'CEN 메타렉스 표준에서 구축한 참고문헌 식별자를 구별하고 메타렉스 어휘를 이용해 여러 유형의 자원을 관련시키는 원시 XMl 데이터베이스가 기반으로 사용된다.', 'www.cencenelec.eu/research', '모든 사업은 다릅니다.', 'CENCENELEC 연구 헬프데스크는 귀하의 사업에 표준화를 포함시키는 방법에 대해 자문을 제공합니다.', '여러분의 연락을 기다립니다!', '이메일: research@cencenelec.eu', '전화 + 32 2 550 08 11', 'Avenue Marnix, 17B1000 Brussels, Belgium', '출판인: Andreea Gulacsi CEN & CENELEC 2013년 11월', '년부터 2단계 CEN 워크숍을 통해 새로운 메타렉스 표준을 합의하고 개발하였다.', '해당 워크숍은 에스트렐라 사업과 동시에 진행되었고, 협력단이 표준화 작업에 크게 기여하였다.', '첫 번째 문서는 2007년 발행되었지만 실행가능한 완전한 표준을 구성하지는 않았다.', '에스트렐라 협력단은 이후 구체적인 추가내용과 설명을 제시하였다.', '업데이트된 CWA 버전은 에스트렐라 사업에서 새로 얻은 결과를 이용할 것이다.', 'CEN 워크숍 협약(CWA)은 일종의 유럽 사전표준이다.']
# ['European Standardization Organizations', 'Standardization\x0bin research and innovation projects', 'Success story: information technology', 'ESTRELLA', 'The\tEuropean\tproject\tforStandardized Transparent Representations in order to ExtendLegal Accessibility (ESTRELLA) wasan 18month FP6 (6th EuropeanResearch Framework Programme) project.', 'It brought togetherEuropean companies and expertsin legal knowledge systems tocollaborate on the development,demonstration and disseminationof an innovative and open platformfor sources of law.', 'The project developed a Europeanprestandard for an open XMLinterchange format for legal andlegislative resources.', 'CEN MetaLexprovides a generic frameworkthat standardizes the manner inwhich sources and references arerepresented in XML.', 'It opens upnew markets for legal texts.', 'www.metalex.eu', 'THE PROJECT', 'Representing legal sources and linking themto a knowledge base is not a trivial task.Legal sources come in many forms andformats, from various jurisdictions using different legal systems, in different languages,with different internal structures.', 'ICT has the potential to support governmentand citizens in dealing with the increasingbody of law, but a necessary precondition isthe electronic availability of legal sources ina structured and standard format.', 'ESTRELLAresponded to this need by bringing togetherleading European experts and companies tocollaborate on the development, demonstration and dissemination of an innovativeand open platform for legal knowledgesystems.', 'STANDARDS: A SOLUTIONFOR MARKET UPTAKE', 'Over the last decade, legislators have begunto adopt XMLstandards for formal sourcesof law they manage.', 'However, differentjurisdictions have developed different waysof publishing legislation, as well as differenttools for searching and working with legalsources.', 'One potential solution would be todevelop an open interchange standard’ thatcould be used for exchanging legal texts,and also as a platform for development ofmanipulation and search tools.', 'This has been the aim of the MetaLexinitiative, which received essential supportand inputs from the ESTRELLA project andmembers of the ESTRELLA consortium.As a direct result of this initiative, a newXML document schema for legislation CEN MetaLex has been developed andpublished at European level as a CENWorkshop Agreement (CWA).', 'This prestandard complements and integratesnational XML standards for legislationand supports the searching, exchange andassociation of legal texts.', 'eXtensive Markup Language.', 'A modern system forannotating documents with structural markers that instructthe software displaying the text to carry out appropriateactions, while omitting the XML from the version of thetext that is displayed to users.', 'We think MetaLex has worked well [] for relating the different types of resourcethat we are making available.', 'John Sheridan, UK National Archives', 'HOW WAS THESTANDARD DEVELOPED?', 'IMMEDIATE BENEFIT', 'The workshop process enabled the ESTRELLAconsortium to work with the wider industry.', 'More than 20 organizations participated inthe development of the standard, includinglegal publishers, public administrations,academia, research groups, and businesses.This cooperation was important to involvefuture customers in the development ofthe standard and therefore to ensure thatthe future standard will correspond toindustry needs.', 'During the elaboration ofthe standard, industry participation wasvital in ensuring that good design practicesfrom other initiatives in the area were takeninto account.', 'As the project and workshop process ranin parallel, the early outputs of the CWAprocess also provided valuable inputs to theongoing work of ESTRELLA.', 'LONGTERM IMPACT', 'For developers and providers of legalsoftware the CWA opens up new markets,and for institutional consumers oflegislation it addresses the crucial issue ofinteroperability, as it helps to handle verydifferent document formats with ...
# 6 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-한
# 6 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-영
# TE-한국표준협회-BRIDGIT-(사례)ICT_2-
# ...
# 75 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_132_en (기사 2)-한
# 75 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_132_en (기사 2)-영
# TE-한국표준협회-ISOfocus_132_en (기사 2)-
# ['유럽표준화기구', '연구와 혁신 사업에서의', '표준화', '성공 일화: 첨단 제조', '엔카시트(ENCASIT)', '첨단 시스템 통합 기술의 조정을 위한 유럽 네트워크(엔카시트)는 유럽 전자제품 제조산업 발전 조정을 목표로 하여 반도체와 마이크로전자 조립체에 관한 정보를 수집하고 보급하는 데에 역점을 둔 2개년 FP6 사업(유럽연합의 제6차 연구 프레임워크 프로그램)이었다.', '본 사업은 2011년 완료되었고, 반도체 제품의 공동 설계, 조달 및 사용에 있어 제조업자, 설계자, 공급업자 간 소통을 개선시키는 국제표준 시리즈를 개발하였다.', 'bit.ly/1be8Aiv', '사업', '모바일 컴퓨팅, 핸드헬드 장치, 의료기술과 같은 영역에서 현대 혁신의 속도는 마이크로칩 설계자와 제조업자가 여러 개의 다기능 칩을 이례 없이 작은 규모의 패키지들 내부에 채우는 것을 의미했다.', '단일 일회용 패키지는 여러 설계자와 제조업자가 공급한 다수의 칩을 포함할 수 있으므로, 각 구성품의 기능과 성능을 명시하는 일반적 방식의 필요성이 생겨났다.', '엔카시트 사업은 지난 20년간 반도체 구성품을 더 쉽고 효율적으로 구매하고 통합하여 훨씬 더 경쟁적으로 운영하는 산업이 되도록 반도체 산업의 공동 개발에 힘써온 유럽 기금 사업 시리즈 중 최종 사업이었다.', '본 사업에는 대규모의 사용자 망이 관여하였고, 반도체, 마이크로일렉트로닉 제조, 조립, 포장 및 시험기술에 관한 정보를 수집하여 유럽 전자제품 제조산업으로 보급해왔다.', '표준: 시장 활용을 위한 해결안', '엔카시트 사업 시리즈 초기에 반도체 제품 정보와 관련된 표준의 필요성이 분명해졌다.', '이러한 표준은 더 포괄적인 솔루션을 제공하고, 반도체 장치의 설계, 조달 및 사용 요건을 더 잘 충족하여 공급망 소통을 지원할 것이다.', '엔카시트를 비롯해 이전 사업에서는 반도체 다이에 대한 데이터 요구사항을 명시한 유럽 표준 시리즈 개발을 통해(ES 59008 – 반도체 다이에 대한 데이터 요구사항’, 1999 – 2002년 발행), 이후에는 반도체 다이 제품의 조달과 사용과 관련된 요구사항에 관한 국제표준 시리즈를 통해 필요성을 강조하였다.', '이후 이러한 표준들이 2005년 발행되었으며, 산업 발전을 반영하기 위해 2010/2011년에 개정되었다(시리즈 IEC62258 반도체 다이 캐스트 제품: 조달과 사용에 관련된 요구사항’).', '엔카시트 사업 협력단은 반도체 산업 관련 기업을 위한 지침서와 모범사례를 제공하여, 반도체 다이 캐스트 제품의 생산, 공급 및 사용을 촉진하였다.', 'IEC는 국제전기기술위원회(International Electrotechnical Committee를 의미한다', '본 사업에서 개발한 표준은 산업에서 수용되었고, 현재 반도체 기업들과 전자 구성품 설계 및 제조 관계자들이 사용 중입니다.', '엔카시트 기술책임자, Ken Ball', '표준을 어떻게 개발하였는가?', '표준화 활동은 사업 제안 단계에서 예측되었다.', '표준화 작업은 유럽을 비롯한 전 세계의 제조업자, 설계자 및 공급자를 모았고, 엔카시트 사업에서 착수한 검토 작업과 해당 사업에서 소집한 2천 명 이상의 사용자 망을 활용하였다.', '전 세계에 걸쳐 모든 공급망 부분으로부터 행위자를 한데 모음으로써, 반도체 산업이 일련의 적절한 표준을 갖춰서 각 요구를 충족하면서 널리 적용되어 여러 시장 참여자들 간 상호운용성이 가능하게 한다는 사실을 표준화 작업이 확실히 보장했다.', '직접적 혜택', '표준화 과정은 CENELEC(유럽전기기술표준화위원회)와 IEC(국제전기기술위원회) 공동체를 적용 범위로 끌어들이면서 엔카시트 사업의 규모를 확대하였고 본 사업에 진정한 국제적 관점을 제공하였다.', '이러한 광범위한 참여는 표준에 열거된 솔루션이 널리 적용되고 수용되도록 보장하여 첨단 마이크로칩 제품에 잠재적 부적합성 문제를 피하고 극복하는 데 도움이 되었다.', '표준화는 또한 첨단 반도체 다이 제품을 최적으로 명시, 설계 및 제조하는 방법에 대해 유럽, 나아가 국제적 합의에 도달할 수 있는 플랫폼을 산업에 제공하였다.', '장기적 영향', '발행된 표준은 반도체 다이의 물리적 및 전기적 성질을 설명하는 국제적으로 인정 받는 방식을 제공한다.', '이는 반도체 다이 제품의 생산, 공급 및 사용을 용이하게 하므로 전체 반도체 공급 과정에 이익이 된다.', '본 사업들은 국제표준 시리즈 형태로 결과물을 발행함으로써 반도체 산업이 현대 유럽 산업의 경쟁력을 뒷받침하는 세계 주도적 제품의 개발과 납품을 위해 협력할 수 있다는 것을 계속 보장하게 될 지속적 레거시를 갖는다.', "엔카시트 협력단 구성원 중 일부는 사업을 진행하는 과정에서 표준화 '전문가’가 되었고, 계속 기술위원회에 참여하면서 새로운 표준을 개시하고 유럽 및 세계 마이크로일렉트로닉 산업의 경쟁력에 기여하고 있다.", '조율과 협력을 위해 사람들을 화합하는 것은 산업 전반적으로 이익이 됩니다', '표준화는 이를 장려하고 지원합니다.', '엔카시트 사업이 표준화에 관여하지 않았다면 이만큼 이뤄내지 못했을 것입니다.', '엔카시트 기술책임자, Ken Ball', 'www.cencenelec.eu/research', '모든 사업은 다릅니다.', 'CENCENELEC 연구 헬프데스크는 귀하의 사업에 표준화를 포함시키는 방법에 대해 자문을 제공합니다.', '여러분의 연락을 기다립니다!', '이메일: research@cencenelec.eu', '전화 + 32 2 550 08 11', 'Avenue Marnix, 17B1000 Brussels, Belgium', '출판인: Andreea GulacsiCEN & CENELEC2013년 11월']
# ['European Standardization Organizations', 'Standardization', 'in research and innovation projects', 'Success story: advanced manufacturing', 'ENCASIT', 'The\tEuropean\tNetwork\tfor Coordination of Advanced System Integration Technologies (ENCASIT) was a 2year FP6 project (6th European Research Framework Programme) focused on gathering and disseminating information on semiconductor and microelectronic assembly, with the aim of coordinating developments in the European electronics manufacturing industry.', 'The project finished in 2011, having developed a series of international standards that enable better communication between manufacturers, designers and suppliers in the codesign, procurement and use of semiconductor products.', 'bit.ly/1be8Aiv', 'THE PROJECT', 'The speed of modern innovation in areas such as mobile computing, handheld devices and medical technologies has meant that microchip designers and manufacturers increasingly stack several functional chips into eversmaller packages.', 'A single oneoff package might include numerous chips supplied by different designers and manufacturers, creating the need for common ways to specify the performance and functionality of individual components.', 'The ENCASIT project was the last in a series of interrelated Europeanfunded projects running over two decades that brought together and coordinated developments in the semiconductor industry, such that semiconductor components could be purchased and integrated more easily and efficiently, thus allowing the industry to operate on a far more competitive basis.', 'The projects involved a large network of users, and gathered and disseminated information on semiconductor and microelectronic manufacture, assembly, packaging and test technologies to the European electronic manufacturing industry.', 'STANDARDS: A SOLUTION FOR MARKET UPTAKE', 'Early in the series of ENCASIT projects, it became clear there was a need for standards relating to semiconductor product information.', 'These would provide more comprehensive solutions, better meet the requirements of those designing, procuring and using semiconductor devices, which would assist in supply chain communications.', 'These needs were addressed by the project and its predecessors through the development of a series of European standards that specified data requirements for semiconductor die (ES 59008 – data requirements for semiconductor die’ series, published 1999 2002), and then a series of international standards on the requirements for both the procurement and use of semiconductor die products.', 'These later standards were published in 2005 and revised in 2010/11 to reflect industry advances (series IEC62258 semiconductor die products: requirements for procurement and use’).', 'The ENCASIT project consortium provided guidelines and good practice for companies in the semiconductor industry, and facilitated the production, supply and use of semiconductor die products.', 'IEC is the International Electrotechnical Committee', 'The standards developed by the project were well received by industry and are being used by semiconductor companies, and those involved in the design and manufacture of electronic components.', 'Ken Ball, ENCASIT Technical Manager', 'HOW WAS THE STANDARD DEVELOPED?', 'Standardization activities were foreseen from the project proposal stage.', 'The standardization work brought together manufacturers, designers and suppliers, from both Europe and elsewhere, and took advantage of both the review work undertaken by the ENCASIT project, and the network of 2000+ users it had assembled.', 'By bringing together actors from all parts of the supply chain and from across the globe, the standardization work ensured that the semiconductor industry had an appropriate set of standards that could meet their respective needs and were widely applicable, therefore guaranteeing interoperability between the different market players.', 'IMMEDIATE BENEFIT', 'The standardization proce ...
# 76 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)제조_2-한
# 76 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)제조_2-영
# TE-한국표준협회-BRIDGIT-(사례)제조_2-
# ['저는 당신과는 생면부지의 사람이랍니다,', '하지만 제 말을 믿으세요', 'ISOfocus_135', 'ISOfocus_13537', '기사작성자: 버나비 루이스(Barnaby Lewis)', '어떠한 거래이든 우리에게 이런 조건을 받아들이라고 하면 대부분 손을 내저을 것이다.', '하지만 우리가 여행지의 숙소, 식당, 최상의 교통편에 대한 결정을 내릴 때 의존하는 온라인 리뷰의 인기, 그리고 우리가 생면부지의 사람에게 주는 신뢰의 결과가 실제로는 우리의 예상과 다른 경우가 많다.', '온라인 커뮤니티는 언제나 우리와 같은 사람들이 서로 공통관심사를 나누고 동료와 소통할 수 있는 장을 제공해왔다.', '어디서나 접근이 가능하고 그것도 무상으로 참여할 수 있다는 점에서 뉴스그룹, 포럼, 채팅방이 인터넷 초창기부터 발전을 거듭하여 2000년대 후반 소셜미디어 폭발의 기틀을 닦은 것은 전혀 이상한 일이 아니다.', '이제는 이러한 연결성이 없는 세상을 상상하기조차 어렵다.', '온라인 커뮤니티는 우리 일상생활의 일부가 되었고 우리가 친구와 사귀고 친구를 정의하는 방식을 변화시켰을 뿐 아니라 인간과 정보 사이의 관계, 우리가 의견을 형성하고 표현하는 방식마저 바꿔놓았다.', '그뿐만 아니라 바캉스를 가기 위한 의사결정 방식에도 영향을 미쳤다.', '즉, 스스로 상품을 조사하기보다 온라인 후기에 전적으로 의존하는 소비자가 적지 않다.', '지구촌이 여러분의 손가락 끝에 다 있는데 왜 여행을 할까?', '우리 주머니 속의 디지털 세상은 우리가 한가로운 명상을 위해 남겨둔 빈틈을 중독성 있고 몰입감 있는 경험으로 채워놓는다.', '일, 휴식, 뉴스, 의견, 학습 및 엔터테인먼트가 감각적인 정보의 쓰나미가 되어 우리에게 몰려온다.', '정보가 우리의 지평을 넓히고 새로운 아이디어를 불러일으키는 것은 분명하지만 동시에 그것은 휴식 없는 라이프스타일의 본질적 요소가 된 지 오래다.', '따라서 우리가 전문가들을 찾아가 과거 그 어느 때보다 지금이 더 스트레스가 많다고 하소연하는 것은 당연한 일이라 할 수 있다.', '가끔은 멈출 필요가 있다.', '요즘은 스스로 상품을 조사하기보다', '온라인 후기에 전적으로 의존하는 소비자가 적지 않다', '이렇게 범람하는 정보는 요즘 사람들이 이전 세대보다 더 많이 여행하는 이유가 될 수 있다.', '아마 그것은 우리가 왜 "모든 것으로부터 벗어나", "긴장에서 해방되어", "관점을 바꾸고", 심지어 "전기, 수도를 이용하지 않는" 이국적인 여행지를 찾는지도 설명할 수 있을 것이다.', '최근 제정된 ISO 표준은 사람들이 보다 더 확실한 선택을 하고 구매 프로세스를 잘 마무리하는 데 도움을 준다.', '하지만 우리가 어떤 결정을 내리기 위해서는 반드시 여러 선택지 중에서 하나를 골라야 한다.', '이 또한 곤혹스러운 단계이다.', '비행기 여행은 예산 선택의 싸움이고, 당신의 스마트폰은 외국어를 거의 완전히 번역할 수 있으며, 세계 최대 숙박 제공업체는 막상 단 하나의 호텔도 소유하고 있지 않은 세상에 당혹스러움을 느껴도 괜찮다.', '다행히 아직 여러분을 도와줄 수 있는 전문여행사가 존재한다.', '가격 비교와 온라인 예매 때문에 여행사가 모두 파산한 것은 아니다.', '정반대다.', '살아남은 여행사는 혁신과 전문화라는 대안이 있었기 때문이다.', '데이터 기반의 마케팅을 통해 고객 중심 패키지를 구성하여 과거에는 전혀 없었던 경험을 제공하는 새로운 유형의 여행사가 출현했다.', '소비자 리뷰와 설문조사 의견을 포함하여 이들이 우리에게서 수집하는 정보가 곧 비즈니스 모델의 핵심이다.', '경쟁이 치열한 모험 관광 시장에서 혁신업체들은 분석과 인사이트를 활용하여 고객에게 단순한 휴가가 아닌 그들이 진정으로 원하는 것, 즉 삶을 바꾸는 미지의 세계로의 여행을 제공한다.', '프랑스에서 가장 유명한 여행사 중에 노매드어드벤쳐(Nomade Adventure)라는 곳이 있다75년에 설립되었지만 이름 그대로 지금까지 한 번도 변화를 멈춘 적이 없으며, 현재는 업계 선두주자로 발돋움했다.', '기회 포착', '연간 12,000명의 고객에게 그들이 꿈꾸던 휴가를 책임지고 60명의 직원을 관리하면서 새로운 여행지 개발을 위해 세계 각지를 여행하는 등, 이 업체의 파브리스 델탈리아(Fabrice Deltaglia) 대표는 언제나 바쁘게 이동 중이다.', '프랑스 국적의 델탈리아 대표는 아프리카 영화배급, 유스 액티비티 할리데이(youth activity holidays), 그리고10여년 간의 여행사 운영 등 특이한 경력을 갖고 있다.', 'ISOfocus는 델탈리아 대표를 어렵사리 만나 그의 삶과 회사의 성공에서 표준이 어떤 역할을 했는지 물었다.', '“제가 표준을 접한 것은 우연한 기회였습니다.', '온라인 등급평가에 대한 표준 제정에 참여하게 되면서 표준이 우리 비즈니스에 얼마나 중요한지 알게 되었습니다."', '이어서 기자는 그에게 사업하는 과정에서 표준을 어떻게 알게 되었는지 물었다.', '“노매드는 2011년부터 온라인 리뷰를 도입했습니다.', '경쟁이 치열한 온라인 관광 업계에서 우리의 존재감을 제대로 드러내기 위해서였죠.', '우리는 자체적으로 매우 엄격한 시스템을 구축했습니다.', '예를 들어, 고객의 리뷰는 그것이 우호적이든 비우호적이든 불문하고 모두 최소 5년 동안 게시하고 당사 직원들도 고객 리뷰를 편집, 삭제할 수 없도록 했습니다.”', '델탈리아 대표의 입장에서는 유사한 지침을 개발하여 모든 온라인 사업에 두루 적용하는 것은 리뷰의 진실성이라는 관점에서 투명성을 강화하고 고객 신뢰도를 유지하는 첩경임이 분명했다.', 'ISO의 프랑스 회원인 AFNOR는 온라인 리뷰에 대한 표준 개발 아이디어의 산실이다.', 'AFNOR에서 표준화 작업을 시작하게 된 계기를 묻는 질문에 델탈리아 대표는, “제가 표준화 작업 참여를 수락한 것은 개인적인 호기심과 우리의 비즈니스 보호에 대한 인식이 합쳐진 결정이었습니다”라고 밝힌다.', '프랑스 혁신을 넘어 세계로', '년 ISO는 AFNOR의 주도하에 온라인 소비자 보고서를 다루는 기술위원회를 설립하고 리뷰 관리자의 온라인 소비자 리뷰 수집, 검토 및 게시를 위한 원칙과 방법에 대한 권고 및 요구사항을 제시하는 국제표준 개발에 착수했다18년에 발행된 ISO 20488은 AFNOR의 초기 작업을 모체로 한다.', 'AFNOR의 작업은 많은 프랑스 기업이 지침으로 채택하는 성과를 달성했다.', 'ISO 20488, 온라인 소비자 리뷰 수집, 검토 및 게시를 위한 원칙 및 요구사항(Online consumer reviews – Principles and requirements for their collection, moderation and publication)은 모든 형태의 사업 분야에 적용되며, 그중에서도 소비자 경험이 의사결정에 핵심 역할을 하는 관광과 같은 분야에서 특히 시장 적합성이 있다.', '온라인 평판을 다루는 ISO의 기술위원회(ISO/TC 290) 역시 AFNOR가 그 관리를 맡고 있다.', '이 기술위원회의 로랑 프티(Laurent Petit) 의장에 따르면, 스포츠용품과 같이 특정 성능을 발휘해야 하는 제품 구매에서는 온라인 리뷰가 지대한 영향을 미친다.', '수학과 마케팅을 공부한 프티 의장은 자신의 실질적 사업 경험을 ISO 활동에 적용 중이다.', '국영 복권회사에서부터 국영 TV 방송국, 다국적 스포츠용품 유통업체 데카트론(Decathlon)에 이르기까지 프랑스 굴지의 기업에서 다양한 경력을 쌓은 프티 의장의 최근 도전과제는 태국에서 가장 규모가 큰 소매업체다.', 'ISOfocus는 싱가포르의 번화가를 달리는 택시 속에서 그와 인터뷰하는 기회를 잡았다.', '유명 프로축구선수 출신으로서 파리, 상하이, 싱가포르, 그리고 방콕에서 뛴 바 있는 프티 의장은 최근 몸담은 프로축구 클럽에서 ISO 표준을 경험한 적이 있다.', '표준 개발자로 그의 첫 번째 기회는 2014년에 AFNOR의 제안을 받으면서 찾아왔다.', '프티 의장은 표준의 엄청난 잠재력을 알고 있는 동료들의 지원을 받아, 그의 말을 빌리자면, "표준 세계의 이면"을 살펴 ...
# ['Trust me, I’m a total stranger', 'ISOfocus_135', 'ISOfocus_13537', 'by Barnaby Lewis', 'Put in these terms, most of uswould run a mile, whatever theproposition.', 'But the popularityof online reviews, and the trustwe place in persons unknownwhen making major decisionsabout where to stay, what to eatand how to get the most from atrip, tells a different story.', 'Online communities have always been a place where people connect with peers : people like us, sharing something in common.Accessible anywhere and generally free to participate, it’s littlewonder thatnews groups, forums andchatrooms flourishedfromthe beginning of the internet and prepared the ground for the late2000’s social media explosion.', 'It’s hard to imagine a world without these connections.', 'They’vebecome part of the fabric of our daily lives.', 'They’ve changed notonly the way we socialize and define our friends, they’ve alteredour relationship to information and how we form, and express,our opinions.', 'They’ve also influenced the way we make ourvacationing decisions ; many of us now move from idea throughresearch to booking entirely on screen.', 'With the planet at your fingertips,why travel at all ?', 'The digital world in our pockets fills the gaps once reserved foridle contemplation with wonderfully addictive and immersiveexperience.', 'Work, relaxation, news, opinion, learning and entertainment bear down in a sensorial tsunami of information.', 'Itdefinitely broadens our horizons and can expose us to new ideas,yet it’s also an intrinsic part of the nonstop lifestyle.', 'It comes asno surprise that we tell researchers we’re more stressed than everbefore.', 'Sometimes, it’s good to stop.', 'Many of us now move from idea throughresearch to bookingentirely on screen.', 'Could this be one reason why we travel more than our grandparents did ?', 'Perhaps it also explains whywe seek increasingly exotic destinations where we can “ get away from it all ”, “ unwind ”, “ changeperspective ”, even go “ offthegrid ”.', 'A recent ISO standard should help make the process of choosingand booking more reassuring.', 'But before you get there, you’ll have to navigate the options.', 'These, too, have proliferated to the pointof bafflement.', 'It’s OK to be perplexed by aworld where air travel is the budget option, your smartphonecan almostbutnotquite translate unknown languages for you, and the world’s largest accommodationprovider doesn’t own a single building.', 'Fortunately, there are still professional travel agencies to helpyou.', 'They didn’t all go bust with price comparison and online booking.', 'Quite the opposite.', 'The onesthat survived did so by innovation and specialization.', 'A new breed of travel agency has emerged, offering experiences that simply weren’t available before,using datadriven marketing to create clientfocused packages.', 'The information that these companiescollect from us, including the reviews that are written and the opinions that are surveyed, are essentialto their business model.', 'In the highly competitive sector dedicated to adventure tourism, innovativecompanies use analysis and insights to give their customers what they really want : not just holidays,but lifechanging journeys into the unknown.', 'In France, one of the bestknown operators is NomadeAventure.', 'It was founded in 1975 but, true to its name, it has never stopped moving and is now anestablished leader.', 'Grasping an opportunity', 'In between sending 12000 people per year on their dream holiday, managing a team of 60 people andtravelling to discover new destinations, Nomade’s General Manager, Fabrice Deltaglia, is constantlyon the go.', 'A French national, Deltagliaʼs career has carried him on an unusual journey through filmdistribution in Africa, youth activity holidays and, for almost a decade, to head up a leading travel company.', 'ISOfocus managed to pin him down to ask him about the roleof standards in his life and in his company’s success.', '“ I came to standar ...
# 77 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en 2019(기사 2)-한
# 77 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en 2019(기사 2)-영
# TE-한국표준협회-ISOfocus_135_en 2019(기사 2)-
# Running Time:  2607.5668572980003
# ko :78, en :78

# %%
def pptx_parser_pre(pptx_file):
    # pptx 분석 하기위해 list 만들어주기
    pptx_results_pre = []
    prs = Presentation(pptx_file)
    
    # ---- pptx 추출 시작 ----
    for slide in prs.slides:
        
        # 1개의 pptx 분석시작
        for shape in slide.shapes:
            if not shape.has_text_frame:
                continue
                
            
            # 전처리 및 라인별 넣어주기
            for paragraph in shape.text_frame.paragraphs:
                paragraph.text = pptx_extra_regex(paragraph.text)

                if paragraph.text.strip() in ['.', '/', ',']:
                    continue
                pptx_results_pre.append(paragraph.text)

            # sent_tokenize 
            pptx_results = []
            for pptx_result_pre in pptx_results_pre:
                text_list = sent_tokenize(pptx_result_pre)
                for text in text_list:
                    if len(text) == 1 and text == 'E':
                        text = text + '→'
                    if text[:2] in 'ver':
                        text = '←' + text
                    pptx_results.append(text)
    pptx_results = list(filter(None, pptx_results))
    return pptx_results


def pptx_to_excel(pptx_files_dict):

    start = timeit.default_timer()
    
    completed_log = open(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/4_completed_log' + '.txt', "w+")
    error_log = open(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/4_error_log' + '.txt', "w+")
    i = 0
    ko_files = []
    en_files = []

    for pptx_file in pptx_files_dict:
        if pptx_file[-6] == '한':
            ko_files.append(pptx_file)
        elif pptx_file[-6] == '영':
            en_files.append(pptx_file)
    
    try:
        # 짝이 맞는 순서대로 넣어주기
        ko_file, en_file = '', ''
        # 한, 영 짝수 맞추기
        for ko_file in ko_files:
            for en_file in en_files:
                if ko_file[:-6] == en_file[:-6]:
                    # ---- pptx 추출 시작 ----
                    pptx_ko = pptx_parser_pre(ko_file)
                    print(pptx_ko)
                    pptx_en = pptx_parser_pre(en_file)
                    print(pptx_en)

                    i += 1       
                    # ---- 파일명에 따라서 순서대로 한, 영 key에 filename을 value로 넣어주기 ----
                    completed_log.write(str(i) + ko_file + ' \n')
                    completed_log.write(str(i) + en_file + ' \n')
                    print(i, ko_file[115:-5])
                    print(i, en_file[115:-5])


                    # excel 밖으로 빼내기
                    # ------- 절대경로보다 상대경로 사용해주세요
                    workbook = xlsxwriter.Workbook(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/Test_2/{ko_file[115:-6]}.xlsx')
                    print(ko_file[115:-6])
                    worksheet = workbook.add_worksheet()
                    worksheet.write('A1', ' ')
                    worksheet.write('B1', 'KOR')
                    worksheet.write('C1', 'ENG')

                    row_idx = 2

                    # pptx을 excel로 
                    worksheet.write('A' + str(row_idx), '>' * 10 + ko_file[115:-6])
                    row_idx += 1
                    for ko, en in zip_longest(pptx_ko, pptx_en, fillvalue=' '):
                        worksheet.write('B' + str(row_idx), ko)
                        worksheet.write('C' + str(row_idx), en)
                        row_idx += 1

                    workbook.close()

    except Exception as e:
        error_log.write(str(i) + ko_file + ' \n')

    stop = timeit.default_timer()
    print('Running Time: ', stop - start)

    print(f'ko :{len(ko_files)}, en :{len(en_files)}')

# %%
pptx_to_excel(pptx_files_dict)
# Out:
# ['새로운 (e) 이륙', '항공 산업의', '글: 앤 브래디Ann Brady', '로봇기술부터 러신머닝에까지 이르는 신기술이 급격한 변화와 개발 주기를 이끌고 있다.', '항공산업이 산업 자동화와 표준, 특히 ISO/TC 184/SC 4로 취한 이득으로 좋은 결과를 내기 노력하는 한편 부드러운 항공 경로를 확보하기 위한 중요한 역할을 하고 있다.', '물론, 이들이 따라올 수 있을 경우의 일이다.', '그리스 로마 신화의 이카로스Icarus가 나무로 날개를 만들어 밀랍으로 깃털을 붙여 하늘을 날았던 그 순간부터 인류는 중력을 거스르고 자유롭게 날기 위한 기계와 장치를 설계하고 만들어왔다.', '이카로스는 태양의 뜨거운 열기와 함께 휴브리스Hubris를 겪고 추락했지만, 오늘날은 스페이스 XSpace X의 고안자이자 테슬라Tesla의 창업자인 엘론 머스크Elon Musk와 아마존닷컴Amazon.com과 블루 오리진Blue Origin의 창립자인 제프 베조스Jeff Bezos처럼 자신의 비전과 모험심으로 움직이고 4차 산업혁명의 신기술로 동력을 얻는 사람들이 하늘에 새로운 길을 개척하고 있다.', '현대판 이카로스들은 크게 생각할 능력이 있고, 자신들의 성공과 새로운 길을 밝히려는 노력과 목표를 매체 전역 흩뿌리고 있다.', '물론, 항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', '년, 첫 번째 상용 비행기가 탄생한 때부터 항공 여행 수요는 기하급수적으로 늘었다.', '그 결과, 항공 업계는 더 안전하고, 빠르고, 가벼우며 연료 효율이 높은 항공기를 설계할 방법을 찾게 되었다세기에 들어 환경에 대한 인식이 최고조에 다다르자, 업계 또한 항공기의 탄소 배출을 줄이고 지속 가능한 탄소 발자국을 유지하기 위한 방법을 찾게 되었다.', "당시는 다른 무엇보다도 가격이 중요한 이지젯EasyJet 시대'였던 만큼, 굉장히 어려운 일이었다.", '빠르게, 유연하게', '이러한 난제를 해결하는 데는 비용 효율적이고도 빠르며 유연한 새로운 생산 공정이 필요하다.', '고급 로봇 공학, 인공 지능, 머신 러닝, 클라우드 컴퓨팅 및 사물 인터넷과 같은 기술은 이러한 공정에 큰 역할을 하며 우리 삶을 조용히 변화시키고 있으며, 특히 항공 산업에 큰 변화를 불러왔다.', '우리는 비행기에 올라 자리에 앉을 때마다 자동화에 우리 자신을 어느 정도 맡기는 셈이다.', 'ISO포커스_1315', '비행이 무서운 사람에게 그다지 반가운 예시는 아니지만, 우리는 비행기의 서로 다른 부품을 엮어주는 수천 개의 구멍과 그 구멍이 어떻게 뚫어졌는지에 대해 생각해 보지 않는다.', '고도의 정밀함과 시간이 필요한 작업임에도 말이다.', '셰필드 대학교Sheffield University 내 첨단 제조 연구센터Advanced Manufacturing Research Center의 통합 제조 그룹 책임자인 벤 모건Ben Morgan은 디 엔지니어The Engineer에 기고한 기사에서 자동화 제조는 사람보다 로봇에게 적합한 작업이라고 지적하며 "자동화 시스템은 정밀도를 더 높일 수 있고, 지루함이나 피곤함을 느끼지도 않는다.', '우주 항공 산업 재료 및 다양한 재료를 겹친 재료는 숙련된 직원이 다루기에도 부피가 크고 무겁고 어려움을 겪을 수 있다.', '"라고 말했다.', '비행기 이용자에게 좋은 소식인 셈이다.', '만 개의 부품이 반드시 모두 조립되어야만 하는 보잉 747을 생각해보자.', '자동화 제조가 새 항공기를 제작하는 데 큰 역할을 해낸다는 것이 분명해지지 않는가?', '그러나, 항공 산업에 난제가 없는 것은 아니다.', '급속도로 발전하는 신기술을 따라가야 할 뿐만 아니라 설계, 조달, 제조, 생산 및 배달, 지원, 유지보수, 제품의 폐기와 기타 관련 서비스 등 자동화 시스템 분야의 표준도 잘 알아두어야 한다.', '이러한 두 가지 과제에 독특한 시각을 가진 사람이 있다.', '보잉의 사업 역량 통합부서의 수석 관리자이자, 기술 위원회 ISO/TC 184, 항공 시스템과 통합, 분과위원회 SC4, 산업 자료의 의장인 케니 스워프Kenny Swope이다.', '스워프Swope는 고도로 복잡한 시스템을 통해 제조를 해야 하는 보잉과 같은 회사는 업계에서 전반적인 성공을 거두기 위해 표준이 매우 중요하며, 회사의 “제품, 공급 체인과 서비스 제안 등이 무수히 많은 갈래로” 엮여 있다고 말한다.', '표준의 주요 역할', '스워프Swope에 따르면, ISO 10303, 산업 자동화 시스템과 통합 – 상품 데이터 표현 및 교환, 즉 STEP은 디지털 상품 설계의 적용에 가장 성공적인 표준 중 하나이다.', 'ISO 10303은 산업 데이터에 대한 ISO/TC 184/SC 4에 속하는 표준이다.', 'STEP은 회사 내부는 물론, 글로벌 공급 체인 사이에서 컴퓨터 이용 설계(CAD) 시스템을 이용한 상품 설계 데이터 교환에서 가장 흔하게 쓰이는 표준으로 발달했다.', '그는 “설계와 공학에서 제조에 이르는 제품의 핵심으로, 제품 설계와 결합된 공학 요구사항과 제조 정보 등 3차원 표현은 디지털 트윈의 핵심을 이룬다.”라고 말한다.', '상세한 가상 표현을 위한 집합적 데이터에는 분명한 이점이 있다.', '스워프는 “보잉의 제품 설계는 구성 요소와 조립 수준에서 내외부 이해당사자에게 분배되며, 이 표준은 이러한 망에 대단히 중요하다.”고 덧붙였다.', '전반적인 설명, 교육 문서 작업에 대한 제품 디자인의 복합 디자인을 제공하는 것은 또 다른 과제이다.', '여기, 스워프는 ISO/TC 184/SC 4에서 다루는 또 다른 표준인 ISO 14306, 산업 자동화 시스템과 통합 – 3D 구상을 위한 JT 파일 형식 사양을 강조한다.', '그는 복잡한 데이터 구조의 “경량 버전”을 제공하는 이 표준이 매우 귀중한 것이라고 말한다.', '즉, 제조, 서비스 및 지원을 위한 제품의 구상이 “공학 문서와 온라인 서비스 매뉴얼 및 제조 공장에 유용”하다는 것이다.', '세 번째 표준은 ISO 32000, 문서 관리 – 휴대 가능한 문서 형식이다.', '스워프에 따르면 이는 “ISO 10303과 ISO 14306 모두의 강력한 파트너”이다.', '이 표준은 PDF 표준으로도 잘 알려져 있는데, 제품 설계에 필요한 범용 운송 수단과 관련 정보를 제공하기 때문에 디지털 미래의 매끄러운 운용에 필수적이다.', '마지막으로, ISO 8000, 데이터 품질과 ISO 22745, 산업 자동화 시스템과 통합 – 오픈 기술 사전과 마스터 데이터에 대한 사전의 적용은 스마트 제조를 가능하게 하는 중요한 요소이다.', '즉, ISO 9000은 제조 품질을, ISO 8000은 데이터를 담당하는 것이다.', '스마트 제조에는 결함이 없는 데이터가 필요하고, 상용 부품의 데이터 정의를 공개적으로 공유할 수 있어야 한다.', 'ISO 22745는 공급 체인 전역에 걸쳐 사용되는 상용 부품의 정의를 공유하기 위한 다중 산업 솔루션을 제공한다.', '항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', 'ISO포커스_131', 'ISO포커스_1317', '자동화와 효율', '스스로를 멀티 CAD 데이터 교환 최적화 플랫폼이라고 소개하는 소프트웨어 회사 엘리시움Elysium의 기술 업무부 책임자인 애너리즈 스즈키Annalise Suzuki 또한 표준의 이점과 산업 자동화의 확대 경향에 맞추어 표준이 수행하는 핵심 역할을 극찬했다.', '그녀는 “효율을 위해 자동화를 추구하는 조직은 반드시 새로운 기술을 적용하는 것과 표준을 통해 안정성을 올리는 것 사이에서 균형을 찾아야 한다.”라고 말했다.', '스즈키Suzuki는 스워프와 같이 표준의 영향력이 지나치게 복잡한 과정을 거치지 않고 조직의 수단과 방법을 빠르게 조화시킬 수 있도록 도와준다고 믿는다.', '그녀는 “이 표준은 어떻게’를 먼저 생각하지 않고 행동가들이 바로 행동에 돌입할 수 있도록 만들어준다.”고 말했다.', '그녀는 표준이 오늘날 사람들 간의 협업을 도와주는 동시에, 표준이 “머신 투 머신 의사소통에 대한 잠재력으로 자동화를 이끌 핵심 가능자가 될 것이고, 4차 산업혁명을 달성하는 기초가 될 것”이라고 주장한 ...
# ['New (e)takeoff', 'for aviation industry', 'by Ann Brady', 'New technologies, from robotics to machine learning, are ushering in a period of rapid change and development.', 'While the aviation industry is working to reap the benefits of this industrial automation, standards, especially those of ISO/TC 184/SC 4, will play a key role in ensuring a smooth flight path – but only if they can keep up.', '←ver since Icarus boldly strapped on his woodenframed wings made of feathers and wax and took to the skies,', ' human beings have been defying gravity, designing and creating all kinds of contraptions and devices to get themselves airborne.', 'Hubris, along with solar power, did it in for Icarus, but these days, the likes of Elon Musk, founder and chief designer of SpaceX and creator of Tesla, and Jeff Bezos, founder of Amazon.com and Blue Origin, are blazing new trails in the skies, driven by their vision and a sense of adventure, and propelled by the new technologies of the Fourth Industrial Revolution.', 'These modernday Icaruses can afford to think big, and their successes, trailblazing endeavours and projections are splashed across the media.', 'Of course, the aerospace and aviation industry has been pushing boundaries for years.', 'From the first commercial air flight in 1914, demand for air travel has grown exponentially.', 'As a result, the industry has had to seek new ways to design safer, faster, lighter, more fuelefficient aircraft.', 'And in the ever more environmentally aware 21st century, the industry also has to take action to reduce aircraft emissions and achieve a more sustainable carbon footprint – big challenges indeed in an era that has been described as "generation EasyJet”.', 'Fast and flexible', 'Finding solutions to these challenges calls for costeffective, fast and flexible new production processes.', 'Technologies such as advanced robotics, artificial intelligence, machine learning, cloud computing and the Internet of Things are playing a huge role in such processes and are quietly transforming our lives, particularly in the aviation industry.', 'Every time we step on a plane and buckle up, we are handing ourselves over to some degree of automation.', 'ISOfocus_1315', 'E→', 'For instance (nervous flyers should look away now), we never think about the thousands of holes that are holding the different parts of the plane together and how those holes were drilled, a timeconsuming task that also requires a lot of precision.', 'Ben Morgan, Head of the Integrated Manufacturing Group at the Advanced Manufacturing Research Centre at Sheffield University, points out in an article on automated manufacturing in The Engineer, this is a task better suited to robots than people.', '"Automated systems can achieve greater precision, and do not get bored or tired; drills capable of handling aerospace materials and layers of different materials are bulky, heavy and difficult even for skilled staff to use, "he says.', 'Good news for air travellers.', 'And when you consider that a Boeing 747, for example, consists of six million parts, which must all be assembled, it becomes clear that automated manufacturing has a key role to play in building new aircraft.', 'However, therein lies the challenge for the aviation industry – not only in staying abreast of the rapid development of new technologies but also ensuring standardization in the field of automation systems and their integration for design, sourcing, manufacturing, production and delivery, support, maintenance and disposal of products and their associated services.', 'One person with a unique perspective on both these challenges is Kenny Swope, Senior Manager, Business Capability Integration, at Boeing, and Chair of technical committee ISO/TC 184, Automation systems and integration, subcommittee SC 4, Industrial data.', 'For a company like Boeing, which is a manufacturer of highly complex systems at scale, Swope says standards are critical to its overall success in the in ...
# 1 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-한
# 1 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-영
# TE-한국표준협회-ISOfocus_131_en-
# ['인공지능의\x0b새로운 장', 'ISOfocus_13117', '기사작성자: 로버트 바트람(Robert Bartram)', '인공지능(AI)은 이제 더 이상 공상과학 영화의 테마가 아닌 우리 실생활의 일부다.', '공장에서, 지능형교통체계에서, 심지어 의료분야에서도 우리는 AI 활용 사례를 볼 수 있다.', '하지만 정확히 인공지능은 무엇인가?', '성큼 도래한 유비쿼터스 AI\xa0세상에서 국제표준은 왜 필요한가?', '또한 AI 표준화는 어떤 분야를 대상으로 하는가?', '맥킨지 글로벌 연구소1)가 발표한 최근 보고서에 의하면 인공지능에 대한 투자가 빠른 속도로 증가하고 있다.', '맥킨지는 구글과 같은 디지털 혁신 선도기업은 "2016 회계연도에 20~30억 달러를 AI에 투자했으며, 그 중 90%는 R&D 및 AI 배치에, 나머지 10%는 AI 구입에 사용한 것으로 분석한다.', 'ICT산업 전문 시장조사기관 IDC(International Data Corporation)2)에 따르면, 2019년까지 디지털 변혁 이니셔티브의 40%가 다양한 AI를 배치하고, 2021년까지 엔터프라이즈 응용프로그램의 75%가 AI를 사용할 계획이며 총 지출 규모는 522억 달러로 증가할 전망이다.', '개념에서 현실로', '하지만 정확히 AI가 무엇인가?', "ISO/IEC JTC 1, '정보기술(Information technology)'의 분과위원회인 SC 42, 인공지능(Artificial intelligence)의 와엘 윌리엄 디아브(Wael William Diab) 의장에 따르면, AI 분야는 매우 다양한 기술로 구성된다.", '이 신설 위원회는 AI의 개념과 용어(ISO/IEC 22989)를 규정하는 기본 표준의 개발에 착수했다.', '디아브 의장은 AI에 대한 관심이 고조되면서 데이터 과학자, 디지털 전문가, 규제기관 등 매우 다양한 종류의 이해관계자가 이 분야에 참여 중이라고 말한다.', '그는 또 오늘날 AI의 현황과 AI에 대한 인식 사이에 다소 괴리가 있다고 지적한다.', '“사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '내가 보기에 AI는 지능을 갖춘 기계를 효과적으로 구현하는 기술의 집합체다.”', '그는 또 흔히 사람들이 AI를 하나의 완전 자율 시스템 그룹, 즉 움직이는 로봇인 것처럼 생각하지만, 실제로는 많은 AI가 반자율 시스템에 속한다고 설명한다.', '일반적으로 AI 시스템에서 상당 부분의 데이터는 미리 준비가 완료되고, 그 후 특정 형태의 기계학습 능력이 있는 핵심부품에 탑재되며 결국 이런 부품이 우리에게 갖가지 통찰력을 제공한다.', '이처럼 기술 집합체를 구성하는 요소에는 빅데이터, 분석법이 포함되며 반드시 그에 국한하지는 않는다.', '기술의 우산', '현재 화웨이테크놀로지(Huawei Technologies)의 전무로 재직 중인 디아브씨가 ISO/IEC 분과위원회 의장으로 선출된 데는 그만한 이유가 있다.', '맥킨지 글로벌 연구소, 인공지능: 차세대 디지털 프론티어(Artificial Intelligence: The Next Digital Frontier )?', 'IDC, 20182021년 미국 정부기관용 인지컴퓨팅 및 인공지능 솔루션 시장 전망(US Government Cognitive and Artificial Intelligence Forecast 20182021)', 'ISOfocus_131', 'ISOfocus_13119', '스탠퍼드 대학교와 와튼 스쿨에서 전기공학, 경제 및 경영학 학위를 받은 디아브 의장은 경영, 기술전략 부문에서 직무경력을 쌓았다.', '다국적기업인 시스코와 브로드컴에서 근무한 바 있고 사물인터넷(IoT) 전문 컨설턴트로 활동했으며 최근에는 산업인터넷컨소시엄 운영위원회 간사를 역임했다.', '또한 850건 이상의 특허를 출원하여 그 중 400건 가까이 등록되었고 나머지는 심사 중에 있다.', '이는 테슬라가 생전에 출원했던 특허건수보다 더 많은 숫자다.', '더욱이 디아브 의장이 출원한 특허는 단 한 건도 거절결정을 받지 않았다.', '디아브 의장의 진정한 장점은 폭넓은 전문지식에 있는데, 그의 전공분야는 기술 아이디어의 초기 인큐베이션부터 전략적 사업추진에 이르기까지 다양한 영역을 망라한다.', '그가 표준화에 큰 관심을 갖는 것은 산업 전체의 건전한 성장을 위해서는 표준이 완벽한 도구라고 믿기 때문이다.', '디아브 의장은 오늘을 살아가는 우리는 여러 가지 이유로 AI 표준이 필요하다고 역설한다.', '첫째, 현대 사회의 IT는 그 복잡성이 갈수록 심화된다.', '따라서 일반적인 스마트폰 한 대의 용량이 아폴로 우주선의 미션을 모두 합친 용량보다 더 크다.', '둘째, IT가 모든 분야에 점점 더 깊숙이 스며들고 있다.', 'IT 기기들은 출시 초창기인 1970~80년대에는 다소 느린 발전을 보였다.', '하지만 이제 사람들은 단지 효율성 향상 차원에서 IT 시스템을 필요로 하는 것이 아니라 더 큰 효율을 발휘하고 운영적, 전략적 통찰력을 얻기 위해 이를 필요로 하기에 이르렀다.', '끝으로 IT는 어느덧 우리의 삶과 혼연일치가 되었다.', '재무에서부터 제조, 의료, 교통, 로봇에 이르기까지 IT에 의존하지 않는 분야가 없다.', '대책의 일환', '그것이 바로 국제표준이 작동하기 시작하는 지점이다.ISO와 국제전기기술위원회(IEC)간 공동기술위원회 JTC 1 산하의 분과위원회인 SC 42는 AI 생태계를 취급하는 유일한 기술위원회다.', '디아브 의장은 AI 기술이 널리 보급되려면 이 기술의 모든 측면을 종합적으로 고려할 필요가 있으며, 그것이야말로 자신과 SC 42가 지향하는 인식의 출발점이라고 강조한다.', '“우리는 사용자들이 AI가 어떻게 의사결정을 내리는지에 대해 우려 섞인 관심을 나타내고 있으며 따라서 AI의 투명성이 시스템에 포함되어야 한다는 사실을 잘 알고 있습니다.', '따라서 기술 채택을 위해서는 포괄적인 표준화가 필수적입니다,”라고 그는 강조한다.', '그간 AI 생태계는 기술, 사회 및 윤리적 고려사항이라는 몇 가지 핵심 분야로 세분화되었으며 이는 개괄적으로 다음과 같은 범주를 포함한다.', '사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '기본 표준', '매우 다양한 이해관계자로 구성된 SC 42는 일차적인 출발점을 기본 표준에 대한 작업으로 정했다.', '이 작업은 AI의 여러 측면 가운데 공통 용어, 분류체계 및 정의가 요구되는 분야를 검토한다.', '궁극적으로 기본 표준은 현장실무자나 규제담당자가 동일한 언어로 말하고 양 당사자 모두 기술전문가로서 한 목소리를 낼 수 있음을 의미한다.', 'ISOfocus_131', 'ISOfocus_13121', '연산 방법과 기법', 'AI의 핵심은 인공지능 시스템의 연산방법 및 특성의 평가다.', '여기에는 AI의 연산방법, 아키텍처 및 특성을 파악하기 위한 기존의 전문 AI 시스템에 대한 연구는 물론 AI 시스템이 사용하는 다양한 기술(예: ML 알고리즘, 추론, 등)과 특성에 대한 연구도 포함된다.', '이 연구그룹은 AI 분야에서 일어나고 있는 현황을 보고하면서 표준화가 요구되는 분야를 제안할 것이다.', '신뢰도', "산업계의 가장 어려운 주제 가운데 하나가 '신뢰도'이며, 이것이 AI 생태계의 핵심 고려사항 가운데 세 번째다.", '신뢰도는 AI를 둘러싼 여러 우려사항 가운데 중심 위치에 있다.', '이 연구그룹은 AI 시스템의 보안, 프라이버시에서부터 시스템 강건성, 투명성 및 편견에 이르기까지 모든 부분을 샅샅이 검토 중이다.', '이미 AI에는 의사결정을 내리거나 사람들에게 결정을 요하는 사안에 관한 정보를 제공하는 시스템이 있다.', '따라서 불필요한 편견이 없음을 확신하기 위해서는 투명성에 대한 인식과 합의가 가장 중요하다.이 연구그룹은 표준화 프로젝트에 관한 일련의 권고안을 마련할 것으로 보인다.', '상기 권고안은 AI 분야의 우려를 사전에 차단할 수 있는 도구를 제공할 것이다.', '“AI 생태계는 이러한 문제를 내포하고 있습니다.', '따라서 표준이 동 문제 해결에 ...
# ['The new frontier', 'for artificial intelligence', 'ISOfocus_13117', 'by Robert Bartram', 'No longer just a fictional theme for farfetched science fiction movies, artificial intelligence is now very much a daytoday part of our reality.', 'In factories, in intelligent transportation, even in the medical field, artificial intelligence (AI) is just about everywhere.', 'But what exactly is artificial intelligence?', 'As AI becomes more ubiquitous, why is there a need for International Standards?', 'And what are some of the topics surrounding its standardization?', 'A recent report by the McKinsey Global Institute1) suggests that investment in artificial intelligence (AI) is growing fast.', 'McKinsey estimates that digital leaders such as Google spent between “USD 20 billion to USD 30 billion on AI in 2016, with 90% of this allocated to R&D and deployment, and 10% to AI acquisitions”.', 'According to the International Data Corporation2) (IDC), by 2019, 40% of digital transformation initiatives will deploy some sort of variation of AI and by 2021, 75% of enterprise applications will use AI, with expenditure growing to an estimated USD 2 billion.', 'From perception to reality', 'But what exactly is AI?', 'According to Wael William Diab, Chair of the new technical committee ISO/IEC JTC 1, Information technology, subcommittee SC 42, Artificial intelligence, the field of AI includes a collection of technologies.', 'The newly formed committee has started with some foundational standards that include AI concepts and terminology (ISO/IEC 22989).', 'Diab stresses that the interest in AI is quite broad, bringing together a very wide range of diverse stakeholders such as data scientists, digital practitioners, and regulatory bodies.', 'He also points out that there’s something of a gap between what AI actually is today and what it is often perceived to be.', '“People tend to think of AI as autonomous robots or a computer capable of beating a chess master.', 'To me, AI is more of a collection of technologies that are enabling, effectively, a form of intelligence in machines.”', 'He also explains that AI is often seen as a group of fully autonomous systems – robots that move – but, in reality, much of AI goes into semiautonomous systems.', 'In many AI systems, a good deal of data will have been prepared before being fed into an engine that has some form of machine learning, which will then, in turn, produce a series of insights.', 'These technologies can include, but are by no means limited to, machine learning, big data and analytics.', 'Umbrella of technologies', 'Currently a Senior Director of Huawei Technologies, Diab is Chair of the ISO/IEC subcommittee for good reason.', 'Armed with several degrees in electrical engineering,', 'McKinsey Global Institute, Artificial Intelligence: The Next Digital Frontier ?', 'IDC, US Government Cognitive and Artificial Intelligence Forecast 20182021', 'ISOfocus_131', 'ISOfocus_13119', 'economics and business administration from both Stanford and Wharton, his professional life has focused closely on business and technology strategy.', 'Moreover, he has also worked for multinational conglomerates Cisco and Broadcom as well as been a consultant specializing in Internet of Things (IoT) technologies, most recently as the Secretary of the Steering Committee of the Industrial Internet Consortium.', 'He has also filed over 850 patents, of which close to 400 have been issued, with the rest under examination.', 'That’s more patents than those filed by Tesla – and not one of his applications has been rejected.', 'Diab’s true specialism lies in the breadth of his expertise – his range stretches from the early incubation of ideas to strategically driving the industry forward.', 'It’s also why he’s so keen on standardization, as he sees it as the perfect vehicle for the healthy expansion of the industry as a whole.', 'He argues that we need standards for AI for several reasons.', 'First, there’s the degree of sophisti ...
# 2 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-한
# 2 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-영
# TE-한국표준협회-ISOfocus_131_en (기사 2)-
# ['표준', '표준 작성자를 위한 유용한 정보', '표준 작성', '방법', '표준 작성', '방법', '지침서 이용 방법', '분명한 언어로 작성', '올바른 동사 사용', '제목', '목차', '서문', '소개', '적용 범위', '인용 표준', '용어와 정의', '절과 항', '비고와 보기', '표와 그림', '수학 공식', '부속서', '참고문헌', '그래픽 기호', '적합성 평가', '관리 시스템 표준(MSS)', '템플릿 및 선호하는 파일 형식', '목차', 'ISO표준 작성 방법 – 1', '이 지침서는 명확하고 간결하면서도 사용자 친화적인 국제 표준과 ISO 문서의 작성을 돕기 위한 자료이다.', '자세한 작성방법 및 서식은 ISO/IEC Directives, Part 2, 2016, Principles and rules for the structure and drafting of ISO and IEC documents를 참조한다.', '지침을 인용한 경우 관련 표제 옆의 소괄호 안에 표기한다.', '지침서 이용 방법', '분명한 언어로 작성', '항상 사용자를 염두에 두고 문서를 작성한다.', '분명한 언어 사용은 메시지를 명확히 전달하는 효과적인 방법이다.', '명확하고 간결하되 단순화하지 않는다면 작성자의 의도에 대한 오해의 여지를 방지할 수 있다.', '또한 번역 시 소요되는 시간과 비용도 절약할 수 있다.', '분명한 언어는 이해가 쉬우므로 초안 작성 시 토론에 필요한 시간도 아낄 수 있다.', '분명한 언어의 사용은 반드시 메시지의 길이를 줄여야 한다거나, 의미를 곡해한다거나 꼭 문장을 간소화해야 한다는 의미가 아니다.', '분명한 언어를 사용하는 방법:', '주된 메시지를 스스로 명확히 정하고 크게 소리 내어 읽어 본다.', '독자의 입장에서 생각한다.', '문장을 짧게 유지한다.', '하나의 개념을 한 문장으로 표현한다.', '불필요한단어를 제외한다.', '가능한 경우 목록을 사용한다.', '가능하면 능동태를 사용한다.', '문장을 간결하게 표현하고, 짧고 단순한 단어를 사용하며 동사를 명사화하지 않는다.', '구두점을 주의 깊게 사용한다.', '마침표를 더 많이 사용하고 쉼표와 괄호 수를 줄인다.', '요지를 긍정적으로 표현한다.', '가능하면 일상적인 언어를 사용하고 전문 용어를 줄인다.', '분명한 언어는 적용 범위에서 특히 중요하다.', '힌트', '같은 개념에 대한 사용 용어를 통일한다.', '동의어는 사용하지 않는다.', 'ISO표준 작성 방법 – 3', '시리얼과 펄스 – 시방서 및 시험 방법 – 1부: 쌀', '(소개 요소)(주 요소)\t(보충 요소)', '제목(11절)', '제목은 명확하고 간결해야 하며 최대 세 가지 요소를 포함해야 한다.', '소개 요소', '주 요소', '보충 요소', '목차', '목차는 자동으로 생성된다.', '서문(12절)', 'ISO 문서의 서문은 ISO 중앙 사무국이 편집 및 발행 시 삽입한 일반 텍스트를 포함한다.', '기존 표준을 개정하는 경우 이전 판과 비교한 주요 변경 내용 목록을 포함한다.', '올바른 동사 사용', '모든 절에서 요구 사항과 권고 사항 또는 다른 유형의 설명을 명확히 구분한다.', '사용자가 해야 할 일을 명확히 밝히기 위해 ISO 문서에는 다음과 같은 동사를 사용한다.', '요구사항 – shall(해야 한다), shall not(하지 않아야 한다)', '권고사항 – should(하는 것이 좋다), should not(하지 않는 것이 좋다)', '허용사항 – may(해도 된다), need not(하지 않아도 된다)', '가능성 및 능력 – can(할 수 있다), cannot(할 수 없다)', '힌트', '소개와 적용범위의 정보가 중복되지 않는지 확인한다.', ' – ISO표준 작성 방법', '소개', '이 문서는 국제적으로 거래되는 쌀에 대한 최소 시방서를 원하는 전 세계의 요구에 부응하여 작성되었다.', '체질과 키질을 하지 않은 대다수의 상용 곡물은 다른 곡물, 잡초 씨앗, 왕겨, 짚, 돌, 모래 등을 포함하고 있기 때문이다.', ' 적용범위', '이 문서는 쌀(Oryza sativa L.)에 대한 최소 요구 사항과 시험 방법을 지정한다', '이 표준은 사람이 직접 또는 재처리 후 소비하기에 적합한 현미, 앵미, 반도정미 및 반도정 찐쌀에 적용된다.', '조리한 쌀 제품에는 적용되지 않는다.', '적용범위(14절)', '적용범위는 필수이며 문서의 역할을 설명한다.', '예를 들어 이 문서는', '을(를) 지정한다.', '을(를) 설정한다.', '에 대한 지침을 제공한다.', '용어 을(를) 정의한다.', '적용범위는 일련의 사실 설명으로 작성한다.', '요구사항, 권고사항 또는 허용사항은 적용범위에 포함하지 않는다.', '소개(13절)', '소개는 선택 사항이지만 ISO는 포함하는 것을 권고한다.', '소개는 문서의 내용을 설명하고 해당 문서가 필요한 이유에 관한 정보를 제공한다.', 'ISO표준 작성 방법 – 5', ' 인용 표준', '다음 문서를 해당 내용의 일부 또는 전부가 이 문서의 요구 사항을 구성하는 방법으로 본문에 인용한다.', '일자가 표기된 인용은 인용한 판 만 적용된다.', '일자가 표기되지 않은 인용은 인용한 문서의 최신판(모든 개정판 포함)을 적용한다.', 'KS H ISO 712(2014 확인), 곡류 및 곡류제품－수분함량측정(상용 법)', 'ISO 24333:2009, 시리얼과 시리얼 제품 –표본화', '인용표준(15절 및 2항)', '인용 표준 절은 문서 내에 표준 인용이 없더라도 필수이다.', '이 절은 해당 내용의 일부 또는 전부가 문서의 요구 사항을 구성하는 방법으로 본문에 인용된 인용 문서를 열거한다.', '(보기: “표본화는 ISO 24333:2009,5절에 따라 수행한다”).', '해당 인용 문서의 특정 절, 항, 그림, 표 등을 가리키는 경우 인용 일시를 표기한다.', '인용은 다른 ISO 및 IEC 표준을 대상으로 한다.', '다른 기관의 문서도 특정 상황에서 인용할 수 있으며, 이 경우 인용은 공개적으로 사용할 수 있어야 한다.', '용어와 정의(16절)', '용어와 정의 절은 문서의 문맥 내에서 특정 단어의 의미를 구체화하는 필수 절이다.', '문서에 사용된 용어만 정의해야 한다.', '힌트', '용어 작성에 대한 지침은 ISO 102411을 참조한다.', ' – ISO표준 작성 방법', ' 용어와 정의', '이 문서의 목적을 위하여 다음의 용어와 정의를 적용한다.', 'ISO와 IEC는 표준화에 사용되는 용어 데이터베이스를 다음 주소에 게재한다.', 'ISO 온라인 검색 플랫폼: http://www.iso.org/obp에서 이용 가능', 'IEC Electropedia : http://www.electropedia.org에서 이용 가능', '특수 언어', '특별한 목적을 위한 언어', 'LSP', '영역(2)에 사용하고 특정 언어 표현 수단을 사용하는 특징이 있는 언어', '비고 1: 특정 언어 표현 수단은 항상 영역별 또는 주제별 용어와 다른 종류의 호칭 및 어법을 포함하며 문체 또는 구문 기능을 하는 경우도 있다.', 'ISO표준 작성 방법 – 7', '힌트', '약어화된 용어와 기호를 3절 바로 뒤의 별도 절에 열거할 수 있다.', 'ISO 문서의 용어와 정의는 ISO 온라인 검색 플랫폼(www.iso.org/ obp)에서 이용 가능하다.', '이미 정의된 용어를 찾으려면 위원회 및 표준별 OBP를 검색한다.', '정의는 사용 시 용어를 대체할 수 있는 단일 문구이다.', '정의는 관사(보기: “a”, “the”)로 시작하거나 마침표로 끝나지 않는다.', '또한 정의는 요구 사항이나 권고사항의 형태를 띠거나, 포함하지 않는다.', '추가 정보는 비고 또는 보기에 포함될 수 있다.', '아래 보기는 용어 작성에 포함할 수 있는 요소의 범위를 나타낸다.', '절과 항(22절)', '절과 항은 ISO 문서의 주요 부분을 이루며, 적용 시 해야 할 일을 문서 사용자에게 알려준다.', '독자가 문서의 핵심 부분을 인용하기 쉽도록 절과 항에는 번호를 매긴다.', 'ISO는 ISO  ...
# ['standards', 'Tips for standards writers', 'How to', 'Write standards', 'How to', 'Write standards', 'How this brochure can help you', 'Writing plain language3', 'Verbal forms', 'Title', 'Table of contents', 'Foreword4', 'Introduction5', 'Scope', 'Normative references', 'Terms and definitions', 'Clauses and subclauses8', 'Notes and Examples .', 'Tables and Figures10', 'Mathematical formulae', 'Annexes', 'Bibliography14', 'Graphical symbols', 'Conformity assessment', 'Management system standards (MSS)', 'Templates and preferred file formats', 'Contents', 'ISOHow to write standards – 1', 'This brochure is designed to help people write clear, concise and userfriendly International Standards and other ISO documents.', 'For more detailed drafting and editorial rules, see the ISO/IEC Directives, Part 2, 2016, Principles and rules for the structure and drafting of ISO and IEC documents.', 'References to the Directives are given in parentheses next to the relevant header.', 'How this brochure can help you', 'Writing plain language', 'Write your document with the user in mind.', 'Using plain language is an effective means of getting your message across.', 'By being clear and concise – but not simplistic – writers can avoid misinterpretation.', 'This reduces time and cost in translation.', 'Because plain language is easier to understand, it also reduces discussion during drafting.', 'Using plain language does not mean reducing the length of your message, changing its meaning or oversimplifying your text.', 'How to use plain language:', 'Be clear to yourself about your main message – try reading it to yourself out loud', 'Put yourself in the place of the reader', 'Keep your sentences short', 'Have one idea per sentence', 'Leave out words you don’t need', 'Use lists when you can', 'Use the active voice when you can', 'Be concise, use short, simple words and avoid turning verbs into nouns', 'Punctuate your writing carefully', 'Use more full stops, fewer commas and brackets', 'Phrase your points positively', 'Use everyday language whenever possible and reduce jargon', 'Plain language is particularly important in the Scope', 'HINT', 'Use the same term for the same concept everywhere.', 'Don’t use synonyms', 'ISOHow to write standards – 3', 'Cereals and pulses – Specification and test methods – Part 1: Rice', '(introductory)(main)\t(complementary)', 'Title (Clause 11)', 'The Title must be clear and concise, containing a maximum of three elements :', 'an introductory element', 'a main element', 'a complementary element', 'Table of contents', 'The Table of contents is automatically generated.', 'Foreword (Clause 12)', 'The Foreword of an ISO document contains generic text which is inserted by ISO Central Secretariat during editing and publishing.', 'When revising an existing standard, include a list of the major changes compared with the previous edition.', 'Verbal forms', 'In all clauses, be clear about what is a requirement and what is a recommendation or other type of statement.', 'In order to make clear what the user must do, the following verbal forms are used in ISO documents :', 'Requirements – shall, shall not', 'Recommendations – should, should not', 'Permission – may, need not', 'Possibility and capability – can, cannot', 'HINT', 'Check that information is not duplicated between the Introduction and the Scope', ' – ISOHow to write standards', 'Introduction', 'This document was developed in response to worldwide demand for minimum specifications for rice traded internationally, since most commercial bulks of grain, which have not been screened or aspirated, contain a proportion of other grains, weed seeds, chaff, straw, stones, sand, etc.', ' Scope', 'This document specifies minimum requirements and test methods for rice (Oryza sativa L.).', 'It is applicable to husked rice, husked parboiled rice, milled rice and milled parboiled rice, suitable for human consumption, directly or after reconditioning.', 'It is not applicable to cooked  ...
# 3 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-한
# 3 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-영
# TE-한국표준협회-how-to-write-standards-2018-
# ['한국의 R&D표준화 연계 제도', 'National System for Linking', 'R&D and Standardization in Korea', 'Version 0', '25', 'Mr. JongIn HONG', 'Korea Institute of Standards', 'And Conformity Assessment', '(KISCA)', 'R&D‒표준화 연계에 관한 국제적 동향', '한국의 R&D‒표준화 연계 정책 및 제도', '한국의 R&D‒표준화 연계 현황', 'R&D‒표준화 연계 필요성', '표준화 예산 확보를 위한 조언', '한국의 R&D‒표준화 연계 성과', 'EU의 BRIDGIT 프로젝트', 'R&D 표준화 연계 성공사례', '부록', ' R&D표준화 연계 필요성', 'Why Link R&D and Standardization?', 'R&D표준화 연계 필요성', '왜 “R&D”와 “표준화” 를', '연계하는가?', 'R&D표준화 연계 필요성', '개발 기술의 확산 및 시장 지배 여부를 결정하는 국제표준 선점이 글로벌 경쟁력의 필수 요소', '국제표준 선점을 위해서는 R&D 개발 기술의 표준화 연계가 반드시 필요', 'R&D표준화 연계 필요성', '국가기술개발사업(R&D)의 최종목표가 사업화이기 때문에', '시장진입의 필수요소인 개발 기술의 (국제)표준화는 필수사항', '기술성숙도(TRL, Technology Readiness Level) 9단계', 'R&D 프로세스에서의 표준 유형', 'R&D 프로세스에서 활용되거나 개발되어야 하는 표준의 유형은 다음과 같다.', 'R&D표준화 연계 목적', 'R&D 프로세스의 효율적 수행에 기여', '짧아지는 기술개발 주기 추세에 대응', 'R&D 결과의 확산 및 전파의 도구로 활용', '인터페이스/호환성 표준 등의 적용은\x0b시장 접근성을 높이고 기술 개발 방향 정립에 도움을 줌', 'R&D 후 표준화 추진으로는 융합/신기술 등 빠른 기술 변화 환경에 적기 대응이 어려움', '표준화는 개발 기술의 보편적 사용을 보장하므로\x0b개발 기술의 사업화를 촉진', '유럽 5차 프레임워크 프로그램 (5FP) 543명의 코디네이터 대상 조사', '대상', '연구개발과 표준화의 상관관계 및 표준화 활동 참여 동기 등', '조사내용', '연구개발 시 관련성이 높은 표준의 영역은 인터페이스 및 적합성 표준, 용어 및 분류표준, 측정 및 시험방법 표준, 품질 및 안전표준의 순으로 관심이 높음', '기초연구와 같은 연구개발 초기 단계보다 응용연구와\x0b같은 사업화 단계에서 표준이 보다 많은 관련성을 가짐', '기술적 문제의 해결, 연구결과의 확산, 네트워킹 등', 'R&D표준 연계 설문조사(1/2) : 국외 (유럽)', 'R&D표준 연계 설문조사(2/2) : 국내', '국내 전문가 161명 대상 조사', '대상', 'R&D표준화 연계가 필요한 표준유형 및 R&D 활동에서 표준화 활동 참여 목적', '조사내용', '품질/성능 〉 적합성/시험방법 〉 호환성 표준 순서', '표준화를 통한 연구개발 결과의 확산, 기술적 문제 해결, 네트워킹 등', ' R&D표준화 연계에 관한 국제적 동향', 'Global Trend of Linking R&D and Standardization', '주요국의 R&D표준 연계 전략', 'EU의 R&D표준화 연계 전략', 'EU의 연구혁신(R&I)과 표준화 연계 전략', 'EU는 신기술 부문의 연구개발과 표준화를 병행하는 것을 전략적 수단으로 인식하고, EU 공동개발 연구활동, 일명 프레임워크 프로그램’을 중심으로 연구개발 활동과 표준화 활동의 연계성 강화 정책을 추진하고 있다.', '유럽집행위원회(European Commission)의 Framework Program 및 Horizon 2020', '주요 대상 분야는 정보통신기술, 공업기술, 환경, 생명공학, 에너지수송 등이다.', '프레임워크 프로그램은 EC가 중심이 되어 4~5년을 주기로 전체 유럽에서 대응하는 연구기술계획을 책정하여 공모하고 있다.', '복수국가의 연구기관, 대학, 기업 등이 연계하는 연구개발에 대하여 EC가 기금을 지원한다.', '이러한 프레임워크 프로그램과 연계하여 CEN의 STAR (Standardization and Research) 프로젝트는 프레임워크 프로그램의 연구개발과제 우선 목록을 CEN이 EU에 제출하도록 하고 있다.', '이처럼 EU의 연구개발 프로젝트는 처음부터 성과를 표준화한다는 전제로 추진되고 있다.', 'EU는 CEN & CENELEC의 표준화 활동과 EU의 프레임워크 프로그램의 연계 정책을 확립하여 시행하고 있다.', 'EU의 R&D표준화 연계', 'CEN & CENELEC의 BRIDGIT 프로젝트', 'EU는 오래 전부터 연구와 표준화 연계의 중요성을 인식하고 EU의 연구혁신(R&I, Research & Innovation) 프로젝트에 표준화를 연계시켜 왔음에도 불구하고 R&I와 표준화의 연계 시너지가 높지 않다고 판단하고,', 'R&I와 표준화 간의 Gap을 연결하기 위한 “BRIDGIT(Bridging the Gap between Research and Standardization)"라는 프로젝트를 실시하였다.', '미국의 R&D표준화 연계 전략', '미국은 국가경쟁력 제고 전략으로 첨단기술프로그램(ATP)에 R&D 표준화 연계', 'R&D 표준화 연계는 국가경쟁력 제고 전략', '첨단기술개발 프로그램(ATP) 추진 시 표준화 연계', 'R&D 과제 평가 시 성과보급과 표준화를 고려', 'R&D 표준화 연계는 국가경쟁력 제고 전략', '미국은 국가경쟁력 제고 전략의 일환으로 연구개발과 표준화를 연계하고 있다.', '국립과학재단(NSF, National Science Foundation)에서 컴퓨터 네트워크 등 정보통신 분야 중심의 연구개발과 표준화 연계 추진 과제를 우선 지원하고 있다.', 'ITS(지능형교통시스템) 사업과 같은 대형 시스템 개발은 정부가 표준화 예산을 지원하였다.', '첨단기술프로그램(ATP) 추진 시 표준화 연계', '정부 주도의 첨단기술프로그램(ATP, Advanced Technology Program) 추진 시 산업경쟁력 강화를 위해 연구 결과의 시장 잠재력, 향후 상용화 계획 등의 표준화 연계 평가를 실시하고 있다.', 'ATP 프로그램 도입으로 설계․제조(CAD/CAM)의 데이터교환 표준(STEP)에 대한 국제표준을 선도하고, 제조업은 이 표준을 부품공급망관리(SCM)에 활용하여 설계제조 시간을 50% 단축시켰다.', 'R&D 과제 평가 시 성과보급과 표준화를 고려', '미국은 연구개발 과제를 공모하여 평가하는 과정에서 성과보급과 표준화를 동시에 고려하는 정책을 실시하고 있다.', '최근에는 정부의 표준 이용과 민간 표준화 활동에 대한 모니터링 등 정부의 역할을 제도적으로 강화하고 있다.', '정부기관인 국립기술표준원(NIST)은 장기적이고 시스템적인 표준화 연구를 수행하며, 민간 표준화기구인 ANSI와 MoU를 통해 정부와 민간의 표준화 교류를 확대하고 있다.', '국가표준화 정책을 강화하기 위해 2012년도 NIST의 예산을 약 10억 달러 수준으로 증액하여 배정하였다 (2010년 대비 8% 증액).', '일본의 R&D표준화 연계', '일본은 연구개발 활동과 국제표준화 활동을 일체적으로 추진하여 국가적 차원의 국제표준화 활동을 강화', '국제표준종합전략 (지적재산전략본부, 2006)', '신산업 창조전략 2005 (경제산업성, 2005)', '일본의 국제경쟁력을 강화하기 위한 연구개발표준화전략 (총무성 산하 정보통신심의위원회)', 'NEDO의 국가연구개발과 국제표준화 연계 전략', '신에너지 산업기술 종합개발기구(NEDO, New Energy and Industrial Technology Development Organization)', '국제표준종합전략 (지적재산전략본부, 2006)', '일본의 지적재산전략본부는 2006년 경제의 급격한 글로벌화 및 세계 시장의 일체화에 따른 표준의 중요성 증대, WTO/TBT협정 등 급변하는 표준관련 환경에 발맞추어 국제표준화에 적극적으로 대응하기 위해 ｢국제표준종합전략｣을 수립하였 ...
# ['National System for Linking R&D and Standardization in Korea', 'National System for Linking', 'R&D and Standardization in Korea', 'Version 0', 'August 25, 2019', 'Mr. JongIn HONG', 'Korea Institute of Standards', 'And Conformity Assessment', '(KISCA)', 'Global Trends on Linking R&D and Standardization', 'Strategies and Systems for Linking R&D and Standardization in Korea', 'Status of Linking R&D and Standardization in Korea', 'Why Link R&D and Standardization?', 'Advice on Securing Budget for Standardization', 'Results of Linking R&D and Standardization in Korea', 'EU’S BRIDGIT Project', 'Case Study: Successful Linkage between R&D and Standardization', 'Appendix', 'Why Link R&D and Standardization?', 'Why Link R&D and Standardization?', 'Why should we link', '“R&D” and “standardization?”', 'Why Link R&D and Standardization?', 'Efforts to disseminate technologies and attain market dominance rely on international standards.', 'Preemptively securing international standards is key to gaining global competitiveness.', 'Securing international standards requires linkage between R&D and standardization.', 'Why Link R&D and Standardization?', 'The ultimate goal of national R&D programs is to gain entry into the relevant market.', 'Gaining market access requires having the developed technologies adopted as (global) standards.', ' Technology Readiness Levels (TRLs)', 'R&D for Core Industrial Technology Development Program', 'Level 1', 'Level 2', 'Level 3', 'Level 5', 'Level 4', 'Level 6', 'Level 7', 'Level 8', 'Level 9', 'Basic Theory/Experiment', 'Technology formulation, including practical ideas and patents', 'Labscale basic performance evaluation', 'Labscale part/system performance evaluation', 'Part/system prototype', 'Prototype performance evaluation', 'Prototype reliance evaluation', 'Prototype certification and standardization', 'Commercialization', 'Basic Research', 'Experiment', 'Prototype', 'Application', 'Commercialization', 'Types of Standards Associated with R&D Processes', 'The following standards need to be applied or developed in R&D processes.', 'Purpose of Linkage between R&D and Standardization', 'Contribute to the efficient performance of R&D processes', 'Address evershortening cycles of technology development', 'Use standardization as a means to disseminate and diffuse R&D outcomes', 'Interface/compatibility standards improve market accessibility and assist with determining the directions of technology development.', 'Pursuing standardization “after” R&D efforts makes it difficult to respond to rapid changes in technology (convergent/new technologies).', 'Standardization ensures the universal use of developed technologies and, therefore, promotes the commercialization of the technologies.', 'Survey of 543 Coordinators Participating in European Commission’s Fifth Framework Programme (5FP)', 'Eligibility', 'Correlation between R&D and standardization, and reason for participating in standardization activities', 'Findings', 'The areas deemed the most relevant to R&D efforts were, in the order of percentages of respondents:interface and conformity standards,semantic and classification standards,measurement and testing standards, andquality and safety standards.', 'Standards are more relevant during the commercialization phase (applied research, etc.)', 'rather than the early phase (basic research, etc.', ').', 'Resolution of technical issues, dissemination of research findings, networking, etc.', 'R&DStandardization Linkage Survey (1/2): Europe', 'R&DStandardization Linkage Survey (2/2): Korea', 'Surveyed 161 Korean experts', 'Eligibility', 'Types of standards requiring linkage between R&D and standardization, and purpose of R&D personnel participating in standardization activities', 'Findings', 'In the order of percentages of respondents: quality/performance > conformity/testing > compatibility standards', 'Dissemination of R&D outcomes through standardization; solution of technical issues; networking', 'Global Trends ...
# 4 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-한
# 4 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-영
# TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-
# ['표준 혁신의 가교', '연구와 혁신 사업에서의표준화', '성공 일화: 친환경 기반 경제', 'Darden Hood,', '미국, 베타분석학 회장', 'http://www.kbbpps.eu', '표준: 시장 활용을 위한 해결안', '사업', 'KBBPPS:', 'KYTan _Shutterstock', '바이오 정제와 친환경 기반 경제의 실질적 성장에서 직면한 주요 도전과제 중 하나는 제품의 속성에 관한 명확하고도 조화를 이룬 일련의 표준을 들 수 있다.', '지식 기반의 친환경 제품 사전 표준화(Knowledge Based Biobased Products’ PreStandardization, KBBPPS) 사업은 이러한 제품에 대한 친환경 내용물 결정과 생분해성 시험체계를 다룬다.', '생분해성 또는 생물학적 유래 요소에 대한 실험실과 현장시험을 위한 실용적 솔루션을 조사 중이다.', '결과를 유럽 표준에 일대일로 복사하는 것을 목표로 한다.', 'CEN에의 참여와 전규범적 및 공동규범적 연구를 통해 KBBPPS는 유럽 이해관계자들이 실제 현장 행동과 실험실에서의 적용성에 상관되어 있는 견고하고 잘 정의된 시험 방법으로 진행하도록 허용한다.', 'KBBPPS는 친환경적 제품에 대해 전규범적 및 공동규범적 작업을 시작해왔다.', '사업에서는 14C 분석에만 의존하지 않고 생분해성과 생태독성 시험체계에도 의존하는 생물량 함량 방법인 바이오 기반 탄소 함유량 결정에 관한 연구와 시연을 다룬다.', '시험 방법론을 개발, 조화 및 검증하는 것을 목적으로 기능과 관련된 장애를 식별하고 해결한다.', '바이오 기반 탄소와 기타 바이오 기반 요소 결정을 다루기 위해 시료 준비, 분류 및 열처리 가능성을 연구하였다.', '사업에서는 생물학적 분해와 관련된 이해관계자, 실험실 및 현장시험에 대해 또는 생물학적으로 유도된 물질이나 요소의 양을 결정하기 위한 실용적인 솔루션을 개발한다.', '이를 위한 목표는 대부분 바이오 기반 제품’에 관한 CEN/TC 411에 의거하여 일대일로 유럽 표준에 복사 가능하다.', '사업은 2012년 9월부터 2015년 8월까지 진행된다.', '바이오 정제와 친환경 기반 경제의 실질적 성장에 직면한 주요 도전과제 중 하나로, 시장에서 바이오 기반’으로 입지가 잡힌 제품의 속성에 대한 조화를 이룬 일련의 명확한 표준을 들 수 있다.', '소비자가 정확한 제품 정보를 수신하도록 보장하기 위해, 여러 특징(예: 생물 분해성, 환경 안전성, 바이오 기반 내용, 성능)에 대해 잘 정의된 통과 기준을 아우르는 시방서 기준을 설정해야 한다.', 'KBBPPS는 이러한 주제에 관한 전규범적 연구를 지원한다.', 'KBBPPS 사업에서는 친환경 제품에 관한 기능 친환경 내용물과 기능 표준, 라벨 및 인증 시스템의 적용을 용이하게 하고 증가시키는 것을 목표로 합니다.', '다양한 친환경 제품에 적용 가능한 생물량 내용물을 올바로 파악하는 것은 유럽과 전 세계 생명공학과 바이오매스 산업 발전에 상당한 관련성이 있습니다.', '이메일: research@cencenelec.eu', '전화 + +32 2 550 08 11', 'Avenue Marnix, 17 B1000 Brussels, Belgium', '출판인: Andreea Gulacsi – CEN & CENELEC 2014년 9월', '모든 사업은 다릅니다.', 'CENCENELEC 연구 헬프데스크는 귀하의 사업에 표준화를 포함시키는 방법에 대해 자문을 제공합니다.', '여러분의 연락을 기다립니다!', 'www.cencenelec.eu/research', 'CEN/TC 411 회장이자 DSM 지속가능성 이사, Frederic Petit', '다른 원자를 포함해탄소 원자를 주시해야 하는 도전과제가 있습니다.', '여기서 질문은 제품 내 탄소를 재생 가능한 원재료에서 얻을 수 있는지 여부입니다.', '주어진 물질이 고고학에 어떻게 사용되는지 결정하는 것과 동일한 방식으로친환경적 내용물을 결정할 수 있습니다.', '성능이 좋은 친환경 제품에는 분명한 표준이 필요합니다.', '결국 OpenBio 사업에서 계속하게 될 KBBPPS 업무에서 도전과제는 각 바이오 제품의 기능을 설명하는 정확하고, 재생 가능하며, 신뢰할 수 있는 표준을 도출하는 데에 있다.', '이는 생산자가 시중에서 이용할 수 있는 일반적인 비 바이오 제품에 비해 자사 제품을 제시하도록 허용한다.', '이는 사용자, 소비자, 정책입안자에게 자신감을 주고, 고의로 사용을 피한 오래된 자원에 대한 아이디어를 제시하여 결과적으로 바이오 제품의 시장 수용에 기여할 것이다.', '표준을 어떻게 개발하였는가?', 'Steve Woods_Shutterstock', 'www.losfeld.be', 'KBBPPS 사업은 첫 연구 과제로 현행 생분해법과 생태독성 표준을 검토하였다.', '표준 개발에 진전은 있지만 여전히 유의한 괴리가 있다는 결론의 공공보고서를 도출할 수 있었다.', '연구와 실험실 경험을 바탕으로 CEN/ TS 16640 “바이오 기반 제품 방사성탄소 방법을 사용하는 제품의 바이오 기반 탄소 함유량 결정”이라는 유럽 사전표준이 제정되었다.', 'KBBPPS에서 일부 사업에 대해서만 기법을 평가하고 여러 실험실과의 상호검증조사를 완료하여 더 많은 작업을 예상하면서 TS가 제정되었으나, 머지않아 유럽 표준(EN)의 업그레이드 버전이 될 것으로 예상된다.', 'KBBPPS는 물질균형기법 또는 간접 결정에 대해 추가 연구를 실행할 것이며, 처리 체계 검사 또는 요소 분석으로 뒷받침될 것이다.', '또한 KBBPPS는 제품을 생물 및 비생물 요소로 나누고, 이론적 바이오매스 함유량을 계산할 수 있는 소프트웨어 프로그램을 개발해왔다.', '표준화와의 연계는 본 사업 정보를 CEN/TC 411의 정보와 동일한 웹사이트에 게시한다는 사실로 뒷받침된다: www.biobasedeconomy.eu', '표준화는 본 사업의 핵심 보급 활동으로, 사업 결과의 잠재적인 장기 사용과 영향에 있어 기반으로 간주된다.', 'KBBPPS 사업의 업무는 전규범적 및 공동규범적 작업으로 간주할 수 있다.', '기술시방서 CEN/TS 16640은 바이오 기반 생성물과 제품의 실험실, 생산자, 공급자 및 구매자를 위한 기준시험방법을 제공한다.', '당국과 검사기관에도 유용하다.', '개발된 방법론은 모든 바이오 기반 제품에 대한 개념을 형성하며, 특정 제품에만 해당되는 것이 아니다.', '바이오 내용물과 생분해 방법은 실제 장 거동(field behavior)과의 관계, 등급 및 품질 수준의 지표를 제시하기 위하여 반복성과 관련해 시험 될 것이다.', '관련 표준화 활동이 뒤따라야 한다.', '생분해법과 기능 격차에 대한 업무는 또 다른 FP7 사업인 OpenBio 사업에서 더욱 발전될 것이다.', '결과를 비롯해 개발된 시험 방법론 초안은 추후 표준화를 위해 CEN과 다른 표준화 기관으로 제출될 것이다.', '표준화와 연계 혜택', '장기적 예상 영향']
# ['Standards Your Innovation Bridge', 'Standardization\x0bin research and innovation projects', 'Success story: biobased economy', 'Darden Hood,', 'President of BetaAnalytics, USA', 'http://www.kbbpps.eu', 'STANDARDS: A SOLUTION FOR MARKET UPTAKE', 'THE PROJECT', 'KBBPPS:', 'KYTan _Shutterstock', 'One of the main challenges for the real takeoff of biorefineries andthe biobased economy is a clear,harmonized and unambiguousset of standards about theproperties of the products.The KBBPPS (KnowledgeBased Biobased Products’ PreStandardization) project coversbiobased content determinationand biodegradability test schemesfor these products.', 'Practicalsolutions for lab and field testson biodegradation or biologicalderived elements are investigated.The goal is copying the resultsonetoone into Europeanstandards.', 'By participating inCEN and by doing preand conormative research, KBBPPSallows European stakeholdersto progress with welldefined,sound test methods correlatedto actual field behaviour andapplicability in the lab.', 'KBBPPS has been initiated to execute preand conormative work for biobasedproducts.', 'The project covers researchand demonstration activities on biobased carbon content determination,biomass content methods not solelydependent on 14Canalysis, as well asbiodegradability and ecotoxicity testschemes.', 'Identification and resolutionof functionality related bottlenecks withthe view to developing, harmonizingand validating test methodologies areundertaken.', 'The possibilities for improvingsample preparation, fractionation andthermal treatments are studied in orderto cover biobased carbon and otherbiobased elements determination.The project develops practical solutionsfor stakeholders, lab and field tests onbiodegradation or determining the amountof biologically derived material or elements.The goal in the end is that the results canbe copied onetoone into Europeanstandards, mostly under CEN/TC 411 on“Biobased products”.', 'The project runsfrom September 2012 until August 20', 'One of the challenges for the takeoff ofbiorefineries and the biobased economyis a clear, harmonized and unambiguousset of standards about the properties ofthe products placed on the market as being’biobased’.', 'To ensure that consumersreceive accurate product information,standardized test methods should setthe benchmark for specifications, whichencompass welldefined pass criteria fordifferent characteristics (e.g.', 'biodegradation,environmental safety, biobased content,performance).', 'KBBPPS is supporting theprenormative research on these topics.', 'The KBBPPS project aims at facilitating and increasing the application of biocontent and functionalitystandards, labels and certification systems for biobased products.', 'A correct identification of the biomasscontent, applicable to a wide variety of biobased products is of great relevance for the further development of the biotechnology and biomass industry in Europe and worldwide.', 'Email: research@cencenelec.eu', 'Tel.', '+32 2 550 08 11', 'Avenue Marnix, 17 B1000 Brussels, Belgium', 'Publisher : Andreea Gulacsi – CEN & CENELEC September 2014', 'Every project is different.', 'The CENCENELEC Research Helpdesk', 'can provide you with advice on how to include standardization in your project.Please feel free to contact us!', 'www.cencenelec.eu/research', 'Frederic Petit, Sustainability Director of DSM and Chairman of CEN/TC 411', 'One of the challenges is to look to the carbon elementalso including other atoms.', 'Question is whether the carbon inproducts is derived from renewable raw materials.', 'Then you cansimply determine the biobased contentthe same way youdetermine how old a given substance is as used in archaeology.For biobased products performing well, clear standards arerequired.', 'The challenge is for the KBBPPS work eventually continued by the OpenBioproject to result in a correct, reproducibleand reliable set of standards that describethe functioning of each biobased product.This al ...
# 5 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-한
# 5 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-영
# TE-한국표준협회-BRIDGIT-(사례)바이오_1-
# ['유럽표준화위원회', '연구와 혁신 사업에서의표준화', '성공 일화: 정보기술', '에스트렐라', '법적 접근성을 확대하기 위한 표준화되고 투명한 대표를 위한 유럽 사업(에스트렐라)은 18개월간 진행된 FP6 (유럽연합의 제6차 연구 프레임워크 프로그램) 사업이었다.', '법적 지식체계 전문가와 유럽 기업을 한데 모아 법적 자료와 관련해 혁신적이고 개방적인 플랫폼의 개발, 입증 및 보급을 위하여 협력을 도모하였다.', '본 사업을 통해 법적/법률적 자원에 관한 오픈 XML 교환 포맷을 위한 유럽 사전표준을 개발하였다.', 'CEN 메타렉스(MetaLex)는 소스와 참조를 XML로 표현하는 방식을 표준화하는 포괄적인 구조 틀을 제공한다.', '이는 법적 조문에 신시장을 개척한다.', 'www.metalex.eu', '사업', '법적 자료를 대표하고 이를 지식 기반에 연계하는 일은 사소한 업무가 아니다.', '법적 자료는 여러 내적 구조와 여러 언어로 된 다양한 법률 제도를 이용하는 다양한 관할 당국으로부터 다양한 형태와 포맷으로 이용할 수 있다.', 'ICT는 증가하는 법체계를 다루는 데에 있어 정부와 시민을 지원할 수 있는 잠재력이 있지만, 구조화된 표준양식으로 법적 자료의 전자식 이용이 가능해야만 한다.', '에스트렐라는 이러한 요구에 대해 주도적인 유럽 전문가와 기업이 법적 지식 체계에 대한 혁신적이고 개방적인 플랫폼의 개발, 입증 및 보급에 협력하도록 화합하는 것으로 대응했다.', '표준: 시장 활용을 위한 해결안', '지난 10년간 입법자들은 그들이 관리하는 공식 법적 자료에 대해 XML표준을 채택하기 시작했다.', '하지만 관할 당국마다 상이한 법령 출판 방식을 개발해왔고, 상이한 검색 및 작업 도구를 개발해왔다.', '한 가지 잠재적 해결책은 법적 조문의 교환에 사용 가능한 동시 조작 및 검색 도구 개발을 위한 플랫폼으로 이용 가능한 개방형 교환 표준’의 개발이 있다.', '에스트렐라 사업과 에스트렐라 협력단 회원으로부터 기본적인 지지와 투입을 제공 받은 메타렉스 사업은 그러한 표준의 개발을 목표로 해왔다.', '해당 사업의 직접적인 결과로, 법령에 대해 새로운 XML 문서 스키마, CEN 메타렉스이 개발되었고, CEN 워크숍 협약(CWA)으로 유럽 수준에서 발행되었다.', '이러한 사전표준은 법령에 대한 국가 XML 표준을 보완 및 통합하고, 법적 조문의 검색, 교환 및 연계를 지원한다.', '광범위한 마크업 언어.', '주석 문서용 최신 시스템으로서, 텍스트를 표시하는 소프트웨어가 적절한 실행을 이행하도록 지시하는 구조적 마커가 있으면서 동시에 사용자에게 보이는 텍스트 버전에서 XML을 누락하는 시스템.', '메타렉스는 현재 저희가 이용 가능한 여러 유형의 자원을 관련시키는 데에 [] 성과를 보였다고 생각합니다.', '영국 국립 문서기록 관리청, John Sheridan', '표준을 어떻게 발전하였는가?', '직접적 혜택', '워크숍 과정은 에스트렐라 협력단이 광범위한 산업과 협력할 수 있도록 해주었다.', '법률 관련 출판업자, 행정관, 학계, 연구 집단, 사업을 포함해 20개 이상의 조직이 표준 개발에 참여하였다.', '이러한 협력은 표준 개발에 미래의 소비자를 관여시킬 뿐 아니라 미래 표준이 산업 요구에 일치하도록 보장하는 데에 중요한 역할을 했다.', '표준 개발 중에 해당 분야의 다른 사업에 모범 설계 실무를 고려하도록 확보하는 데에는 산업 참여가 매우 중요했다.', '사업과 워크숍 과정이 동시에 진행되었으므로, CWA 과정의 초기 결과물도 진행 중인 에스트렐라 작업에 중요한 자료가 되었다.', '장기적 영향', 'CWA는 법적 소프트웨어 개발자와 제공자에게 신시장을 열었고, 법령 기관 소비자에게는 상호운용성이라는 중요한 문제를 부각시켰는데, 상호운용성은 동일한 IT 기반시설 내에서 상당히 다른 문서 포맷을 취급하는 데에 유용하기 때문이다.', '그 결과, CEN 메타렉스 표준은 이미 네덜란드 세관, 벨기에 공공복지센터 BeValue 및 기타 기관에서 사용 중이다.', '가령 메타렉스 문서 서버는 현재 수만 개의 규정을 CEN 메타렉스 문서로 관리하면서 CEN 메타렉스 연계 자료로 모든 네덜란드 규정을 공고한다.', '영국에서도 자국 전체에 걸쳐 법적 자료로 접근할 수 있는 신규 웹사이트의 일부로 해당 표준을 사용 중이다.', 'CEN 메타렉스 표준에서 구축한 참고문헌 식별자를 구별하고 메타렉스 어휘를 이용해 여러 유형의 자원을 관련시키는 원시 XMl 데이터베이스가 기반으로 사용된다.', 'www.cencenelec.eu/research', '모든 사업은 다릅니다.', 'CENCENELEC 연구 헬프데스크는 귀하의 사업에 표준화를 포함시키는 방법에 대해 자문을 제공합니다.', '여러분의 연락을 기다립니다!', '이메일: research@cencenelec.eu', '전화 + 32 2 550 08 11', 'Avenue Marnix, 17B1000 Brussels, Belgium', '출판인: Andreea Gulacsi CEN & CENELEC 2013년 11월', '년부터 2단계 CEN 워크숍을 통해 새로운 메타렉스 표준을 합의하고 개발하였다.', '해당 워크숍은 에스트렐라 사업과 동시에 진행되었고, 협력단이 표준화 작업에 크게 기여하였다.', '첫 번째 문서는 2007년 발행되었지만 실행가능한 완전한 표준을 구성하지는 않았다.', '에스트렐라 협력단은 이후 구체적인 추가내용과 설명을 제시하였다.', '업데이트된 CWA 버전은 에스트렐라 사업에서 새로 얻은 결과를 이용할 것이다.', 'CEN 워크숍 협약(CWA)은 일종의 유럽 사전표준이다.']
# ['European Standardization Organizations', 'Standardization\x0bin research and innovation projects', 'Success story: information technology', 'ESTRELLA', 'The\tEuropean\tproject\tforStandardized Transparent Representations in order to ExtendLegal Accessibility (ESTRELLA) wasan 18month FP6 (6th EuropeanResearch Framework Programme) project.', 'It brought togetherEuropean companies and expertsin legal knowledge systems tocollaborate on the development,demonstration and disseminationof an innovative and open platformfor sources of law.', 'The project developed a Europeanprestandard for an open XMLinterchange format for legal andlegislative resources.', 'CEN MetaLexprovides a generic frameworkthat standardizes the manner inwhich sources and references arerepresented in XML.', 'It opens upnew markets for legal texts.', 'www.metalex.eu', 'THE PROJECT', 'Representing legal sources and linking themto a knowledge base is not a trivial task.Legal sources come in many forms andformats, from various jurisdictions using different legal systems, in different languages,with different internal structures.', 'ICT has the potential to support governmentand citizens in dealing with the increasingbody of law, but a necessary precondition isthe electronic availability of legal sources ina structured and standard format.', 'ESTRELLAresponded to this need by bringing togetherleading European experts and companies tocollaborate on the development, demonstration and dissemination of an innovativeand open platform for legal knowledgesystems.', 'STANDARDS: A SOLUTIONFOR MARKET UPTAKE', 'Over the last decade, legislators have begunto adopt XMLstandards for formal sourcesof law they manage.', 'However, differentjurisdictions have developed different waysof publishing legislation, as well as differenttools for searching and working with legalsources.', 'One potential solution would be todevelop an open interchange standard’ thatcould be used for exchanging legal texts,and also as a platform for development ofmanipulation and search tools.', 'This has been the aim of the MetaLexinitiative, which received essential supportand inputs from the ESTRELLA project andmembers of the ESTRELLA consortium.As a direct result of this initiative, a newXML document schema for legislation CEN MetaLex has been developed andpublished at European level as a CENWorkshop Agreement (CWA).', 'This prestandard complements and integratesnational XML standards for legislationand supports the searching, exchange andassociation of legal texts.', 'eXtensive Markup Language.', 'A modern system forannotating documents with structural markers that instructthe software displaying the text to carry out appropriateactions, while omitting the XML from the version of thetext that is displayed to users.', 'We think MetaLex has worked well [] for relating the different types of resourcethat we are making available.', 'John Sheridan, UK National Archives', 'HOW WAS THESTANDARD DEVELOPED?', 'IMMEDIATE BENEFIT', 'The workshop process enabled the ESTRELLAconsortium to work with the wider industry.', 'More than 20 organizations participated inthe development of the standard, includinglegal publishers, public administrations,academia, research groups, and businesses.This cooperation was important to involvefuture customers in the development ofthe standard and therefore to ensure thatthe future standard will correspond toindustry needs.', 'During the elaboration ofthe standard, industry participation wasvital in ensuring that good design practicesfrom other initiatives in the area were takeninto account.', 'As the project and workshop process ranin parallel, the early outputs of the CWAprocess also provided valuable inputs to theongoing work of ESTRELLA.', 'LONGTERM IMPACT', 'For developers and providers of legalsoftware the CWA opens up new markets,and for institutional consumers oflegislation it addresses the crucial issue ofinteroperability, as it helps to handle verydifferent document formats with ...
# 6 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-한
# 6 (렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-영
# TE-한국표준협회-BRIDGIT-(사례)ICT_2-
