# %%
# -----------------------------------------------------------------------------------------
# library import!!!
import mammoth
import glob
import re
import os
import xlsxwriter
import timeit
import sys
from itertools import zip_longest
from pptx import Presentation
from nltk.tokenize import sent_tokenize
import subprocess
import nltk
# ppt인 파일 가져오기
from pptx import Presentation

# %%
# -----------------------------------------------------------------------------------------
# pattern의 regex를 text에서 찾아 지움
def remove_regex(pattern, text):
    if re.search(pattern, text):
        return re.sub(pattern, '', text)
    return text

# %%
# -----------------------------------------------------------------------------------------
# excel numbering
def get_excel_index(lang, row_idx):
    if lang == 'ko':
        return f'B{str(row_idx)}'
    else:
        return f'C{str(row_idx)}'

# %%
# -----------------------------------------------------------------------------------------
# file 다 가져오기
def get_filename_list(path, ext):
    print('Change encoding files.......\ \n')
    result = []
    for f in glob.glob(file_path + f"/*{ext}"):
        # run convmv shell script -> file normalization NFC -> NFD (한글자소분리해결)
        subprocess.run(['/usr/local/bin/convmv', '-f', 'utf-8', '-t', 'utf-8', '--nfc', '--notest', f])
        result.append(f)
    return result

root_path = '/Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)'
sub_dir = '/4.2019한국표준협회'
file_path = root_path + sub_dir

# %%
# -----------------------------------------------------------------------------------------
# 대소문자 구별하기 위한 
def lower_or_upper():
    lower = [chr(l) for l in range(97, 123, 1)]
    upper = [chr(u) for u in range(65, 91, 1)]
    return lower, upper

# %%
# -----------------------------------------------------------------------------------------
#  작업할 모든 파일 불러오기
def file_import():
    start = timeit.default_timer()
    # -----------------------------------------------------------------------
    # file 다 져오기

    # file_name_lists = [f for f in glob.glob(f'./4.2019한국표준협회/*.*')]
    pptx_files_list = get_filename_list(file_path, '.pptx')
    docx_files_list = get_filename_list(file_path, '.docx')
    # doc_files_list = get_filename_list(file_path, '.doc')
    # ppt_files_list = get_filename_list(file_path, '.ppt')
    # rtf_files_list = get_filename_list(file_path, '.rtf')
    # etc_files_list = []


    # print(file_path + f'\ndocx: {len(docx_name_lists)}, pptx: {len(pptx_name_lists)}, ppt: {len(ppt_name_lists)}, doc: {len(doc_name_lists)}, rtf: {len(rtf_name_lists)}')
    print(file_path + f'pptx: {len(pptx_files_list)}, docx: {len(docx_files_list)}' )
    
    return pptx_files_list, docx_files_list

    stop = timeit.default_timer()
    print('Running Time: ', stop - start)

pptx_files_list, docx_files_list= file_import()
# Out:
# Change encoding files.......\
#
# Change encoding files.......\
#
# /Users/jihyeoh/Lexcode/팀 채널 - 인공지능 학습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회pptx: 156, docx: 121

# %%
# -----------------------------------------------------------------------------------------
#  정규식 작업
def reg_raw_text(raws):
    
    raw_results = []
    
    # 웹사이트 주소 지우기 - http:// www.ansancitytour.com -> 띄어쓰기가 되어있으면 안잡힘
    # web_regex = re.compile(r'(http|ftp)s?:\/\/?(www\.)[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,4}([-a-zA-Z0-9@:%_\+.~#?&//=]*)|(www\.)?(?!ww)[-a-z0-9@:%._\+~#=]{2,256}\.[a-z]{2,4}([-a-zA-Z0-9@:%_\+.~#?&//=])/)?', re.IGNORECASE)

    # 전화번호 지우기 - 021231234(5), (02(2)-123(3)-1234), (02)988-9873, 1234-1234 
    phone_regex = re.compile(r'[\[<{\(]{0,1}(([\[<{\(]{0,1}[\☎\☏]{0,1}[\s]{0,1}[0-9]{0,3}[}>\)\]]{0,1}\-{0,1}[0-9]{3,4}\-{0,1}[0-9]{3,4})|([0-9]{9,10}))[}>\)\]]{0,1}')

    # 시간 지우기 - (10:00, 11:00, 14:00, 15:00, 16:00) / 1:00 ~ 12:00
    time_regex = r'[\[<{\(]{0,1}([0-9]|0[0-9]|1[0-9]|2[0-3]):[0-5][0-9][,\-~\s]{0,2}[}>\)\]]{0,1}'

    # 날짜 지우기 - yyyy.mm.dd | mm.dd.yyyy | dd.mm.yyyy
    date_regex = r'((\d{4})([\s./-]{0,3})(0[1-9]|1[012]|[1-9])([\s./-]{0,3})(0[1-9]|[12][0-9]|3[0-1]|[1-9])([\s./-]{0,3}))'\
                '|((0[1-9]|1[012]|[1-9])([\s./-]{0,3})(0[1-9]|[12][0-9]|3[0-1]|[1-9])([\s./-]{0,3})(\d{4})([\s./-]{0,3}))'\
                '|((0[1-9]|[12][0-9]|3[0-1]|[1-9])([\s./-]{0,3})(0[1-9]|1[012]|[1-9])([\s./-]{0,3})(\d{4})([\s./-]{0,3}))'

    # [숫자 + . + 공백 + 단어] -> [숫자 + . + 단어]: 공백제거
    order_regex = r'(\d)\.\s(\w.*)'

    for raw in raws:
        # too interrupt한 아이들 제거
        # pptx_result_pre = re.sub(r'(\s?■\s?)|(❍)|(▶\s*)|(▸\s*)|(»\s*)|(•\s*)', '', pptx_result_pre)
        raw = re.sub(r"(\s?■\s?)|(‘|※|「|」|`|･|ㅇ|□|❍|▶|▸|»|•|©|—|○|\(\)|-|\*|α|β)\s*", "", raw)
        raw = re.sub(r"\d{1,2}\.\s?", "", raw)
        raw = re.sub(r"\s?\|\s?", "", raw)
        raw = re.sub(r"제\d{1,2}장", "", raw)
        raw = re.sub(r"(C|c)h(\.\s)?apter\s?\d{1,3}", "", raw)
        # space bar 너무 많으면 버리기
        raw = re.sub(r"\s{2,}", "", raw)
        #'.'뒤에 스페이스 주기 (혹시 2개 있을수도 있어서 *로 처리)
        raw = re.sub(r"\.\s{1,2}", ". ", raw)
        # 날짜 제거
        raw = re.sub(r"(\d{2,4}(년|\.|/)\s*)\d{1,2}(월|\.|/)\s*\d{1,2}(일|\s*)", ". ", raw)
        # 상표 지우기
        raw = re.sub(r"(^㉿{1})|(^©{1})\w+", ". ", raw)
        # 숫자만 제일 앞에 있으면 버리기
        raw = re.sub(r"^\d{1,3}\.?", "", raw)
        # 문장과 문장사이에 . 있을때 띄어쓰기가 없다면 띄어쓰기 해줌
        raw = re.sub(r"([ㄱ-ㅣ가-힣|a-zA-Z|0-9])\.([ㄱ-ㅣ가-힣|a-zA-Z|0-9])", r"\1. \2", raw)
        
        raw_results.append(raw)
        
    return raw_results

# %%
# -----------------------------------------------------------------------------------------
# pptx 대문자 예외 상황 처리하기 (잠시 보류)
def pptx_upper_lower_to_a_sentence(pptx_results_pre):
    pptx_results = []
    
    # 대문자 예외처리를 위해서
    lower, upper = lower_or_upper()
    
    # 대, 소문자 구분해서 문장으로 만을어주기
    for idx in range(len(pptx_results_pre)):
        stop_lower_idx = 0
        found_upper_idx = 0
        finally_sentenced = ''
        print(pptx_results_pre[idx])
        if pptx_results_pre[idx][:3] == 'ver':
            stop_lower_idx = idx
            for jdx in range(idx, len(pptx_results_pre)):
                if pptx_results_pre[jdx][0] == 'E':
                    found_upper_idx = jdx
                    finally_sentenced =  pptx_results_pre[found_upper_idx] + pptx_results_pre[stop_lower_idx]

        # del text_list[found_upper_idx]
        if idx == stop_lower_idx:
            pptx_results.append(finally_sentenced)
            # print(finally_sentenced)
        elif idx == found_upper_idx:
            continue 
        elif len(pptx_results_pre[idx]) == 1 and pptx_results_pre[idx][0] == 'E':
            continue
        else:
            pptx_results.append(pptx_results_pre[idx])
    
    return pptx_results

# %%
# -----------------------------------------------------------------------------------------
#  pptx 작업
def raw_pptx_to_dict(pptx_files_list):
    # ------------------------------------------------------------------------------------
    # pptx dict 선언 => 얘를 결국 리턴
    pptx_contents_dict = {}
    i = 0
    # dict에 잘 들어갔는지 test
    pptx_test_print_1 = ''
    pptx_test_print_2 = ''
    
    
    # ---- pptx 추출 시작 ----
    for pptx_file_list in pptx_files_list:
        print(f'{i}번, pptx 추출 시작했습니다.')
        # a single pptx file을 a list에 넣어줄려고
        pptx_results_pre = []

        # pptx 분석 하기위해 list 만들어주기
        prs = Presentation(pptx_file_list)
        
        # 1개의 pptx 분석시작
        for slide in prs.slides:
            for shape in slide.shapes:
                if not shape.has_text_frame:
                    continue
                # 전처리 및 라인별 넣어주기
                for paragraph in shape.text_frame.paragraphs:
                    text_list = sent_tokenize(paragraph.text)
                    for text in text_list:
                        text = re.sub(r"(\s?■\s?)|(‘|※|「|」|`|･|ㅇ|□|❍|▶|▸|»|•|©|—|○|\(\)|-|\*|α|β)\s*", "", text)
                        text = re.sub(r"\d{1,2}\.\s?", "", text)
                        text = re.sub(r'…+\.?\s?\d{1,2}', '', text)
                        text = re.sub(r"\s?\|\s?", "", text)
                        text = re.sub(r"제\d{1,2}장", "", text)
                        text = re.sub(r"(C|c)h(\.\s)?apter\s?\d{1,3}", "", text)
                        # space bar 너무 많으면 버리기
                        text = re.sub(r"\s{2,}", "", text)
                        #'.'뒤에 스페이스 주기 (혹시 2개 있을수도 있어서 *로 처리)
                        text = re.sub(r"\.\s{1,2}", ". ", text)
                        # 날짜 제거
                        text = re.sub(r"(\d{2,4}(년|\.|/)\s*)\d{1,2}(월|\.|/)\s*\d{1,2}(일|\s*)", ". ", text)
                        # 상표 지우기
                        text = re.sub(r"(^㉿{1})|(^©{1})\w+", ". ", text)
                        # 숫자만 제일 앞에 있으면 버리기
                        text = re.sub(r"^\d{1,3}\.?", "", text)
                        # 문장과 문장사이에 . 있을때 띄어쓰기가 없다면 띄어쓰기 해줌
                        text = re.sub(r"([ㄱ-ㅣ가-힣|a-zA-Z|0-9])\.([ㄱ-ㅣ가-힣|a-zA-Z|0-9])", r"\1. \2", text)
                        if text == "":
                            continue
                        pptx_results_pre.append(text)
                    

                        
        # i = 잘 동작하는지 확인하기 위해서
        i += 1
        print(f'{i}번, sent_tokenize했습니다.')
        
        #대문자 예외처리 (유실되는 것들이 있어서 잠시 보류합니다.)
#         pptx_results_pre = pptx_upper_lower_to_a_sentence(pptx_results_pre)
        print(f'{i}번, 대문자 예외를 처리했습니다.')
#         pptx_results = reg_raw_text(pptx_results)
        pptx_results = list(filter(None, pptx_results_pre))
        
        if i == 1:
            pptx_test_print_1 = pptx_file_list[50:-5]
        elif i == 2:
            pptx_test_print_2 = pptx_file_list[50:-5]
        
            
        pptx_contents_dict[pptx_file_list[50:-5]] = pptx_results
    
    # test case 1번째 
    print(pptx_contents_dict.get(pptx_test_print_1))
    # test case 2번째
    print(pptx_contents_dict.get(pptx_test_print_2))
    # 둘 개수 맞는지 확인하기(잘 가져왔는지도)
    print(f'done, pptx_contents_dict : is {len(pptx_contents_dict)}')
    print(f'pptx는 {i}개 가져왔어요')
    
    # pptx_content_dict를 아예 반환
    return pptx_contents_dict

# %%
# -----------------------------------------------------------------------------------------
#  docx 작업
def raw_docx_to_dict(docx_files_list):
    # ------------------------------------------------------------------------------------
    # docx dict 선언 => 얘를 결국 리턴
    docx_contents_dict = {}
    i = 0
    # dict에 잘 들어갔는지 test
    docx_test_print_1 = ''
    docx_test_print_2 = ''

    
    # ---- docx 추출 시작 ----
    for docx_file_list in docx_files_list:
        print(f'{i}번, docx 추출 시작했습니다.')
        # a single pptx file을 a list에 넣어줄려고
        docx_results_pre = []
        
        # docx 한 개씩 가져오는 중
        with open(docx_file_list, "rb") as docx_file:
            result = mammoth.extract_raw_text(docx_file)
            value = result.value  # The raw text
            # sent_tokenize
            text_list= sent_tokenize(value)
            for text in text_list:
                if text == "":
                    continue
                docx_results_pre.append(text)
        
        # i = 잘 동작하는지 확인하기 위해서
        i += 1
        print(f'{i}번, sent_tokenize했습니다.')

        docx_results = reg_raw_text(docx_results_pre)
        docx_results = list(filter(None, docx_results))

        if i == 1:
            docx_test_print_1 = docx_file_list[50:-5]
        elif i == 2:
            docx_test_print_2 = docx_file_list[50:-5]
        

        docx_contents_dict[docx_file_list[50:-5]] = docx_results

    # test case 1번째 
    print(docx_contents_dict.get(docx_test_print_1))
    # test case 2번째
    print(docx_contents_dict.get(docx_test_print_2))
    # 둘 개수 맞는지 확인하기(잘 가져왔는지도)
    print(f'done, docx_contents_dict : is {len(docx_contents_dict)}')
    print(f'docx는 {i}개 가져왔어요')

    # pptx_content_dict를 아예 반환
    return docx_contents_dict

# %%
# -----------------------------------------------------------------------------------------
#  파일들 불러온 후, 형식에 맞게 파싱 후 각 파일의 dict에 넣고 한 개의 dict로 update
def all_contents_dict():
    
    # ------------------------------------------------------------------------------------
    # pptx dict 만들기
    pptx_contents_dict = raw_pptx_to_dict(pptx_files_list)
    
    # ------------------------------------------------------------------------------------
    # docx dict 만들기
    docx_contents_dict = raw_docx_to_dict(docx_files_list)
    
    # ------------------------------------------------------------------------------------
    # docx와, pptx merging
    all_contents_dict = {}
    all_contents_dict.update(pptx_contents_dict)
    all_contents_dict.update(docx_contents_dict)
    print(f'total length is : {len(all_contents_dict)}')
    print(list(all_contents_dict.keys()))
    # ------------------------------------------------------------------------------------
    # 한글, 영어 구분해서 각각의 dict에 넣어주기
    
    
    ko_files = {}
    en_files = {}
    
    # ------------------------------------------------------------------------------------
    # log 출력 (파일명 확인하기 위해서)
    completed_log = open(f'/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/log_stabdard_41' + '.txt', "w+")
    
    
    # -----------------------------------------------------------------------------------------
    #  language 처리하기
    i = 0
    j = 1
    for key, value in all_contents_dict.items():
        i += 1
        print(key) 
        language = key[-1]
        key_name = key[:-2]
        print(key_name)
        
        if language == '한':
            ko_files.update({key_name : value})
            print(f'{key[:-2]}, {key_name}, {language}')
            completed_log.write(str(i) + '_[한. DONE READING]' + key_name + ' \n')
        elif language == '영':
            en_files.update({key_name : value})
            print(f'{key[:-2]}, {key_name}, {language}')
            completed_log.write(str(i) + '_[영. DONE READING]' + key_name + ' \n')
        elif language == '병':
            completed_log.write(str(i) + '_[병. DONE READING]' + key_name + ' \n')
        else:
            print('지금 잘 안되고 있어요. 코드 수정필요')
            print(f'{key[:-2]}, {key_name}, {language}')
    
    
    print(list(ko_files.keys()))
    print(list(en_files.keys()))
    

    completed_log.write(f'[DONE READING Total] 한:{str(len(en_files))} 영:{str(len(ko_files))}')
    completed_log.close()
    
    return ko_files, en_files

# %%
# -----------------------------------------------------------------------------------------
#  excel로 output!!!!!

def dict_to_excel():
    start = timeit.default_timer()
    ko_files, en_files = all_contents_dict()
    # ------------------------------------------------------------------------------------
    # excel 밖으로 빼내기
    workbook = xlsxwriter.Workbook('/Users/jihyeoh/Desktop/Farm/4_2019한국표준협회/4_xlsx/standard41_.xlsx')
    print('excel 빼내기 파일생성 성공!')
    worksheet = workbook.add_worksheet()
    worksheet.write('A1', '특이사항')
    worksheet.write('B1', 'ko')
    worksheet.write('C1', 'en')
    
    row_idx = 2
    
    i = 0

    # ------------------------------------------------------------------------------------
    # excel 글쓰기

    for ko_key, ko_value in ko_files.items():
        for en_key, en_value in en_files.items():
            if ko_key == en_key:
                i += 1
                print(f'{i}-{ko_key}')
                print(f'{i}-{en_key}')
                worksheet.write('A' + str(row_idx), '>'*10 + ko_key)
                row_idx += 1
                for ko, en in zip_longest(ko_value, en_value, fillvalue=' '):
                    ko_index = get_excel_index('ko', row_idx)
                    en_index = get_excel_index('en', row_idx)
                    worksheet.write(ko_index, ko)
                    worksheet.write(en_index, en)
                    row_idx += 1
          
    workbook.close()
    stop = timeit.default_timer()
    
    print('Running Time: ', stop - start)

# %%
dict_to_excel()
# Out:
# 0번, pptx 추출 시작했습니다.
# 1번, sent_tokenize했습니다.
# 1번, 대문자 예외를 처리했습니다.
# 1번, pptx 추출 시작했습니다.
# 2번, sent_tokenize했습니다.
# 2번, 대문자 예외를 처리했습니다.
# 2번, pptx 추출 시작했습니다.
# 3번, sent_tokenize했습니다.
# 3번, 대문자 예외를 처리했습니다.
# 3번, pptx 추출 시작했습니다.
# 4번, sent_tokenize했습니다.
# 4번, 대문자 예외를 처리했습니다.
# 4번, pptx 추출 시작했습니다.
# 5번, sent_tokenize했습니다.
# 5번, 대문자 예외를 처리했습니다.
# 5번, pptx 추출 시작했습니다.
# 6번, sent_tokenize했습니다.
# 6번, 대문자 예외를 처리했습니다.
# 6번, pptx 추출 시작했습니다.
# 7번, sent_tokenize했습니다.
# 7번, 대문자 예외를 처리했습니다.
# 7번, pptx 추출 시작했습니다.
# 8번, sent_tokenize했습니다.
# 8번, 대문자 예외를 처리했습니다.
# 8번, pptx 추출 시작했습니다.
# 9번, sent_tokenize했습니다.
# 9번, 대문자 예외를 처리했습니다.
# 9번, pptx 추출 시작했습니다.
# 10번, sent_tokenize했습니다.
# 10번, 대문자 예외를 처리했습니다.
# 10번, pptx 추출 시작했습니다.
# 11번, sent_tokenize했습니다.
# 11번, 대문자 예외를 처리했습니다.
# 11번, pptx 추출 시작했습니다.
# 12번, sent_tokenize했습니다.
# 12번, 대문자 예외를 처리했습니다.
# 12번, pptx 추출 시작했습니다.
# 13번, sent_tokenize했습니다.
# 13번, 대문자 예외를 처리했습니다.
# 13번, pptx 추출 시작했습니다.
# 14번, sent_tokenize했습니다.
# 14번, 대문자 예외를 처리했습니다.
# 14번, pptx 추출 시작했습니다.
# 15번, sent_tokenize했습니다.
# 15번, 대문자 예외를 처리했습니다.
# 15번, pptx 추출 시작했습니다.
# 16번, sent_tokenize했습니다.
# 16번, 대문자 예외를 처리했습니다.
# 16번, pptx 추출 시작했습니다.
# 17번, sent_tokenize했습니다.
# 17번, 대문자 예외를 처리했습니다.
# 17번, pptx 추출 시작했습니다.
# 18번, sent_tokenize했습니다.
# 18번, 대문자 예외를 처리했습니다.
# 18번, pptx 추출 시작했습니다.
# 19번, sent_tokenize했습니다.
# 19번, 대문자 예외를 처리했습니다.
# 19번, pptx 추출 시작했습니다.
# 20번, sent_tokenize했습니다.
# 20번, 대문자 예외를 처리했습니다.
# 20번, pptx 추출 시작했습니다.
# 21번, sent_tokenize했습니다.
# 21번, 대문자 예외를 처리했습니다.
# 21번, pptx 추출 시작했습니다.
# 22번, sent_tokenize했습니다.
# 22번, 대문자 예외를 처리했습니다.
# 22번, pptx 추출 시작했습니다.
# 23번, sent_tokenize했습니다.
# 23번, 대문자 예외를 처리했습니다.
# 23번, pptx 추출 시작했습니다.
# 24번, sent_tokenize했습니다.
# 24번, 대문자 예외를 처리했습니다.
# 24번, pptx 추출 시작했습니다.
# 25번, sent_tokenize했습니다.
# 25번, 대문자 예외를 처리했습니다.
# 25번, pptx 추출 시작했습니다.
# 26번, sent_tokenize했습니다.
# 26번, 대문자 예외를 처리했습니다.
# 26번, pptx 추출 시작했습니다.
# 27번, sent_tokenize했습니다.
# 27번, 대문자 예외를 처리했습니다.
# 27번, pptx 추출 시작했습니다.
# 28번, sent_tokenize했습니다.
# 28번, 대문자 예외를 처리했습니다.
# 28번, pptx 추출 시작했습니다.
# 29번, sent_tokenize했습니다.
# 29번, 대문자 예외를 처리했습니다.
# 29번, pptx 추출 시작했습니다.
# 30번, sent_tokenize했습니다.
# 30번, 대문자 예외를 처리했습니다.
# 30번, pptx 추출 시작했습니다.
# 31번, sent_tokenize했습니다.
# 31번, 대문자 예외를 처리했습니다.
# 31번, pptx 추출 시작했습니다.
# 32번, sent_tokenize했습니다.
# 32번, 대문자 예외를 처리했습니다.
# 32번, pptx 추출 시작했습니다.
# 33번, sent_tokenize했습니다.
# 33번, 대문자 예외를 처리했습니다.
# 33번, pptx 추출 시작했습니다.
# 34번, sent_tokenize했습니다.
# 34번, 대문자 예외를 처리했습니다.
# 34번, pptx 추출 시작했습니다.
# 35번, sent_tokenize했습니다.
# 35번, 대문자 예외를 처리했습니다.
# 35번, pptx 추출 시작했습니다.
# 36번, sent_tokenize했습니다.
# 36번, 대문자 예외를 처리했습니다.
# 36번, pptx 추출 시작했습니다.
# 37번, sent_tokenize했습니다.
# 37번, 대문자 예외를 처리했습니다.
# 37번, pptx 추출 시작했습니다.
# 38번, sent_tokenize했습니다.
# 38번, 대문자 예외를 처리했습니다.
# 38번, pptx 추출 시작했습니다.
# 39번, sent_tokenize했습니다.
# 39번, 대문자 예외를 처리했습니다.
# 39번, pptx 추출 시작했습니다.
# 40번, sent_tokenize했습니다.
# 40번, 대문자 예외를 처리했습니다.
# 40번, pptx 추출 시작했습니다.
# 41번, sent_tokenize했습니다.
# 41번, 대문자 예외를 처리했습니다.
# 41번, pptx 추출 시작했습니다.
# 42번, sent_tokenize했습니다.
# 42번, 대문자 예외를 처리했습니다.
# 42번, pptx 추출 시작했습니다.
# 43번, sent_tokenize했습니다.
# 43번, 대문자 예외를 처리했습니다.
# 43번, pptx 추출 시작했습니다.
# 44번, sent_tokenize했습니다.
# 44번, 대문자 예외를 처리했습니다.
# 44번, pptx 추출 시작했습니다.
# 45번, sent_tokenize했습니다.
# 45번, 대문자 예외를 처리했습니다.
# 45번, pptx 추출 시작했습니다.
# 46번, sent_tokenize했습니다.
# 46번, 대문자 예외를 처리했습니다.
# 46번, pptx 추출 시작했습니다.
# 47번, sent_tokenize했습니다.
# 47번, 대문자 예외를 처리했습니다.
# 47번, pptx 추출 시작했습니다.
# 48번, sent_tokenize했습니다.
# 48번, 대문자 예외를 처리했습니다.
# 48번, pptx 추출 시작했습니다.
# 49번, sent_tokenize했습니다.
# 49번, 대문자 예외를 처리했습니다.
# 49번, pptx 추출 시작했습니다.
# 50번, sent_tokenize했습니다.
# 50번, 대문자 예외를 처리했습니다.
# 50번, pptx 추출 시작했습니다.
# 51번, sent_tokenize했습니다.
# 51번, 대문자 예외를 처리했습니다.
# 51번, pptx 추출 시작했습니다.
# 52번, sent_tokenize했습니다.
# 52번, 대문자 예외를 처리했습니다.
# 52번, pptx 추출 시작했습니다.
# 53번, sent_tokenize했습니다.
# 53번, 대문자 예외를 처리했습니다.
# 53번, pptx 추출 시작했습니다.
# 54번, sent_tokenize했습니다.
# 54번, 대문자 예외를 처리했습니다.
# 54번, pptx 추출 시작했습니다.
# 55번, sent_tokenize했습니다.
# 55번, 대문자 예외를 처리했습니다.
# 55번, pptx 추출 시작했습니다.
# 56번, sent_tokenize했습니다.
# 56번, 대문자 예외를 처리했습니다.
# 56번, pptx 추출 시작했습니다.
# 57번, sent_tokenize했습니다.
# 57번, 대문자 예외를 처리했습니다.
# 57번, pptx 추출 시작했습니다.
# 58번, sent_tokenize했습니다.
# 58번, 대문자 예외를 처리했습니다.
# 58번, pptx 추출 시작했습니다.
# 59번, sent_tokenize했습니다.
# 59번, 대문자 예외를 처리했습니다.
# 59번, pptx 추출 시작했습니다.
# 60번, sent_tokenize했습니다.
# 60번, 대문자 예외를 처리했습니다.
# 60번, pptx 추출 시작했습니다.
# 61번, sent_tokenize했습니다.
# 61번, 대문자 예외를 처리했습니다.
# 61번, pptx 추출 시작했습니다.
# 62번, sent_tokenize했습니다.
# 62번, 대문자 예외를 처리했습니다.
# 62번, pptx 추출 시작했습니다.
# 63번, sent_tokenize했습니다.
# 63번, 대문자 예외를 처리했습니다.
# 63번, pptx 추출 시작했습니다.
# 64번, sent_tokenize했습니다.
# 64번, 대문자 예외를 처리했습니다.
# 64번, pptx 추출 시작했습니다.
# 65번, sent_tokenize했습니다.
# 65번, 대문자 예외를 처리했습니다.
# 65번, pptx 추출 시작했습니다.
# 66번, sent_tokenize했습니다.
# 66번, 대문자 예외를 처리했습니다.
# 66번, pptx 추출 시작했습니다.
# 67번, sent_tokenize했습니다.
# 67번, 대문자 예외를 처리했습니다.
# 67번, pptx 추출 시작했습니다.
# 68번, sent_tokenize했습니다.
# 68번, 대문자 예외를 처리했습니다.
# 68번, pptx 추출 시작했습니다.
# 69번, sent_tokenize했습니다.
# 69번, 대문자 예외를 처리했습니다.
# 69번, pptx 추출 시작했습니다.
# 70번, sent_tokenize했습니다.
# 70번, 대문자 예외를 처리했습니다.
# 70번, pptx 추출 시작했습니다.
# 71번, sent_tokenize했습니다.
# 71번, 대문자 예외를 처리했습니다.
# 71번, pptx 추출 시작했습니다.
# 72번, sent_tokenize했습니다.
# 72번, 대문자 예외를 처리했습니다.
# 72번, pptx 추출 시작했습니다.
# 73번, sent_tokenize했습니다.
# 73번, 대문자 예외를 처리했습니다.
# 73번, pptx 추출 시작했습니다.
# 74번, sent_tokenize했습니다.
# 74번, 대문자 예외를 처리했습니다.
# 74번, pptx 추출 시작했습니다.
# 75번, sent_tokenize했습니다.
# 75번, 대문자 예외를 처리했습니다.
# 75번, pptx 추출 시작했습니다.
# 76번, sent_tokenize했습니다.
# 76번, 대문자 예외를 처리했습니다.
# 76번, pptx 추출 시작했습니다.
# 77번, sent_tokenize했습니다.
# 77번, 대문자 예외를 처리했습니다.
# 77번, pptx 추출 시작했습니다.
# 78번, sent_tokenize했습니다.
# 78번, 대문자 예외를 처리했습니다.
# 78번, pptx 추출 시작했습니다.
# 79번, sent_tokenize했습니다.
# 79번, 대문자 예외를 처리했습니다.
# 79번, pptx 추출 시작했습니다.
# 80번, sent_tokenize했습니다.
# 80번, 대문자 예외를 처리했습니다.
# 80번, pptx 추출 시작했습니다.
# 81번, sent_tokenize했습니다.
# 81번, 대문자 예외를 처리했습니다.
# 81번, pptx 추출 시작했습니다.
# 82번, sent_tokenize했습니다.
# 82번, 대문자 예외를 처리했습니다.
# 82번, pptx 추출 시작했습니다.
# 83번, sent_tokenize했습니다.
# 83번, 대문자 예외를 처리했습니다.
# 83번, pptx 추출 시작했습니다.
# 84번, sent_tokenize했습니다.
# 84번, 대문자 예외를 처리했습니다.
# 84번, pptx 추출 시작했습니다.
# 85번, sent_tokenize했습니다.
# 85번, 대문자 예외를 처리했습니다.
# 85번, pptx 추출 시작했습니다.
# 86번, sent_tokenize했습니다.
# 86번, 대문자 예외를 처리했습니다.
# 86번, pptx 추출 시작했습니다.
# 87번, sent_tokenize했습니다.
# 87번, 대문자 예외를 처리했습니다.
# 87번, pptx 추출 시작했습니다.
# 88번, sent_tokenize했습니다.
# 88번, 대문자 예외를 처리했습니다.
# 88번, pptx 추출 시작했습니다.
# 89번, sent_tokenize했습니다.
# 89번, 대문자 예외를 처리했습니다.
# 89번, pptx 추출 시작했습니다.
# 90번, sent_tokenize했습니다.
# 90번, 대문자 예외를 처리했습니다.
# 90번, pptx 추출 시작했습니다.
# 91번, sent_tokenize했습니다.
# 91번, 대문자 예외를 처리했습니다.
# 91번, pptx 추출 시작했습니다.
# 92번, sent_tokenize했습니다.
# 92번, 대문자 예외를 처리했습니다.
# 92번, pptx 추출 시작했습니다.
# 93번, sent_tokenize했습니다.
# 93번, 대문자 예외를 처리했습니다.
# 93번, pptx 추출 시작했습니다.
# 94번, sent_tokenize했습니다.
# 94번, 대문자 예외를 처리했습니다.
# 94번, pptx 추출 시작했습니다.
# 95번, sent_tokenize했습니다.
# 95번, 대문자 예외를 처리했습니다.
# 95번, pptx 추출 시작했습니다.
# 96번, sent_tokenize했습니다.
# 96번, 대문자 예외를 처리했습니다.
# 96번, pptx 추출 시작했습니다.
# 97번, sent_tokenize했습니다.
# 97번, 대문자 예외를 처리했습니다.
# 97번, pptx 추출 시작했습니다.
# 98번, sent_tokenize했습니다.
# 98번, 대문자 예외를 처리했습니다.
# 98번, pptx 추출 시작했습니다.
# 99번, sent_tokenize했습니다.
# 99번, 대문자 예외를 처리했습니다.
# 99번, pptx 추출 시작했습니다.
# 100번, sent_tokenize했습니다.
# 100번, 대문자 예외를 처리했습니다.
# 100번, pptx 추출 시작했습니다.
# 101번, sent_tokenize했습니다.
# 101번, 대문자 예외를 처리했습니다.
# 101번, pptx 추출 시작했습니다.
# 102번, sent_tokenize했습니다.
# 102번, 대문자 예외를 처리했습니다.
# 102번, pptx 추출 시작했습니다.
# 103번, sent_tokenize했습니다.
# 103번, 대문자 예외를 처리했습니다.
# 103번, pptx 추출 시작했습니다.
# 104번, sent_tokenize했습니다.
# 104번, 대문자 예외를 처리했습니다.
# 104번, pptx 추출 시작했습니다.
# 105번, sent_tokenize했습니다.
# 105번, 대문자 예외를 처리했습니다.
# 105번, pptx 추출 시작했습니다.
# 106번, sent_tokenize했습니다.
# 106번, 대문자 예외를 처리했습니다.
# 106번, pptx 추출 시작했습니다.
# 107번, sent_tokenize했습니다.
# 107번, 대문자 예외를 처리했습니다.
# 107번, pptx 추출 시작했습니다.
# 108번, sent_tokenize했습니다.
# 108번, 대문자 예외를 처리했습니다.
# 108번, pptx 추출 시작했습니다.
# 109번, sent_tokenize했습니다.
# 109번, 대문자 예외를 처리했습니다.
# 109번, pptx 추출 시작했습니다.
# 110번, sent_tokenize했습니다.
# 110번, 대문자 예외를 처리했습니다.
# 110번, pptx 추출 시작했습니다.
# 111번, sent_tokenize했습니다.
# 111번, 대문자 예외를 처리했습니다.
# 111번, pptx 추출 시작했습니다.
# 112번, sent_tokenize했습니다.
# 112번, 대문자 예외를 처리했습니다.
# 112번, pptx 추출 시작했습니다.
# 113번, sent_tokenize했습니다.
# 113번, 대문자 예외를 처리했습니다.
# 113번, pptx 추출 시작했습니다.
# 114번, sent_tokenize했습니다.
# 114번, 대문자 예외를 처리했습니다.
# 114번, pptx 추출 시작했습니다.
# 115번, sent_tokenize했습니다.
# 115번, 대문자 예외를 처리했습니다.
# 115번, pptx 추출 시작했습니다.
# 116번, sent_tokenize했습니다.
# 116번, 대문자 예외를 처리했습니다.
# 116번, pptx 추출 시작했습니다.
# 117번, sent_tokenize했습니다.
# 117번, 대문자 예외를 처리했습니다.
# 117번, pptx 추출 시작했습니다.
# 118번, sent_tokenize했습니다.
# 118번, 대문자 예외를 처리했습니다.
# 118번, pptx 추출 시작했습니다.
# 119번, sent_tokenize했습니다.
# 119번, 대문자 예외를 처리했습니다.
# 119번, pptx 추출 시작했습니다.
# 120번, sent_tokenize했습니다.
# 120번, 대문자 예외를 처리했습니다.
# 120번, pptx 추출 시작했습니다.
# 121번, sent_tokenize했습니다.
# 121번, 대문자 예외를 처리했습니다.
# 121번, pptx 추출 시작했습니다.
# 122번, sent_tokenize했습니다.
# 122번, 대문자 예외를 처리했습니다.
# 122번, pptx 추출 시작했습니다.
# 123번, sent_tokenize했습니다.
# 123번, 대문자 예외를 처리했습니다.
# 123번, pptx 추출 시작했습니다.
# 124번, sent_tokenize했습니다.
# 124번, 대문자 예외를 처리했습니다.
# 124번, pptx 추출 시작했습니다.
# 125번, sent_tokenize했습니다.
# 125번, 대문자 예외를 처리했습니다.
# 125번, pptx 추출 시작했습니다.
# 126번, sent_tokenize했습니다.
# 126번, 대문자 예외를 처리했습니다.
# 126번, pptx 추출 시작했습니다.
# 127번, sent_tokenize했습니다.
# 127번, 대문자 예외를 처리했습니다.
# 127번, pptx 추출 시작했습니다.
# 128번, sent_tokenize했습니다.
# 128번, 대문자 예외를 처리했습니다.
# 128번, pptx 추출 시작했습니다.
# 129번, sent_tokenize했습니다.
# 129번, 대문자 예외를 처리했습니다.
# 129번, pptx 추출 시작했습니다.
# 130번, sent_tokenize했습니다.
# 130번, 대문자 예외를 처리했습니다.
# 130번, pptx 추출 시작했습니다.
# 131번, sent_tokenize했습니다.
# 131번, 대문자 예외를 처리했습니다.
# 131번, pptx 추출 시작했습니다.
# 132번, sent_tokenize했습니다.
# 132번, 대문자 예외를 처리했습니다.
# 132번, pptx 추출 시작했습니다.
# 133번, sent_tokenize했습니다.
# 133번, 대문자 예외를 처리했습니다.
# 133번, pptx 추출 시작했습니다.
# 134번, sent_tokenize했습니다.
# 134번, 대문자 예외를 처리했습니다.
# 134번, pptx 추출 시작했습니다.
# 135번, sent_tokenize했습니다.
# 135번, 대문자 예외를 처리했습니다.
# 135번, pptx 추출 시작했습니다.
# 136번, sent_tokenize했습니다.
# 136번, 대문자 예외를 처리했습니다.
# 136번, pptx 추출 시작했습니다.
# 137번, sent_tokenize했습니다.
# 137번, 대문자 예외를 처리했습니다.
# 137번, pptx 추출 시작했습니다.
# 138번, sent_tokenize했습니다.
# 138번, 대문자 예외를 처리했습니다.
# 138번, pptx 추출 시작했습니다.
# 139번, sent_tokenize했습니다.
# 139번, 대문자 예외를 처리했습니다.
# 139번, pptx 추출 시작했습니다.
# 140번, sent_tokenize했습니다.
# 140번, 대문자 예외를 처리했습니다.
# 140번, pptx 추출 시작했습니다.
# 141번, sent_tokenize했습니다.
# 141번, 대문자 예외를 처리했습니다.
# 141번, pptx 추출 시작했습니다.
# 142번, sent_tokenize했습니다.
# 142번, 대문자 예외를 처리했습니다.
# 142번, pptx 추출 시작했습니다.
# 143번, sent_tokenize했습니다.
# 143번, 대문자 예외를 처리했습니다.
# 143번, pptx 추출 시작했습니다.
# 144번, sent_tokenize했습니다.
# 144번, 대문자 예외를 처리했습니다.
# 144번, pptx 추출 시작했습니다.
# 145번, sent_tokenize했습니다.
# 145번, 대문자 예외를 처리했습니다.
# 145번, pptx 추출 시작했습니다.
# 146번, sent_tokenize했습니다.
# 146번, 대문자 예외를 처리했습니다.
# 146번, pptx 추출 시작했습니다.
# 147번, sent_tokenize했습니다.
# 147번, 대문자 예외를 처리했습니다.
# 147번, pptx 추출 시작했습니다.
# 148번, sent_tokenize했습니다.
# 148번, 대문자 예외를 처리했습니다.
# 148번, pptx 추출 시작했습니다.
# 149번, sent_tokenize했습니다.
# 149번, 대문자 예외를 처리했습니다.
# 149번, pptx 추출 시작했습니다.
# 150번, sent_tokenize했습니다.
# 150번, 대문자 예외를 처리했습니다.
# 150번, pptx 추출 시작했습니다.
# 151번, sent_tokenize했습니다.
# 151번, 대문자 예외를 처리했습니다.
# 151번, pptx 추출 시작했습니다.
# 152번, sent_tokenize했습니다.
# 152번, 대문자 예외를 처리했습니다.
# 152번, pptx 추출 시작했습니다.
# 153번, sent_tokenize했습니다.
# 153번, 대문자 예외를 처리했습니다.
# 153번, pptx 추출 시작했습니다.
# 154번, sent_tokenize했습니다.
# 154번, 대문자 예외를 처리했습니다.
# 154번, pptx 추출 시작했습니다.
# 155번, sent_tokenize했습니다.
# 155번, 대문자 예외를 처리했습니다.
# 155번, pptx 추출 시작했습니다.
# 156번, sent_tokenize했습니다.
# 156번, 대문자 예외를 처리했습니다.
# ['새로운 (e) 이륙', '항공 산업의', '글: 앤 브래디Ann Brady', '로봇기술부터 러신머닝에까지 이르는 신기술이 급격한 변화와 개발 주기를 이끌고 있다.', '항공산업이 산업 자동화와 표준, 특히 ISO/TC 184/SC 4로 취한 이득으로 좋은 결과를 내기 노력하는 한편 부드러운 항공 경로를 확보하기 위한 중요한 역할을 하고 있다.', '물론, 이들이 따라올 수 있을 경우의 일이다.', '그리스 로마 신화의 이카로스Icarus가 나무로 날개를 만들어 밀랍으로 깃털을 붙여 하늘을 날았던 그 순간부터 인류는 중력을 거스르고 자유롭게 날기 위한 기계와 장치를 설계하고 만들어왔다.', '이카로스는 태양의 뜨거운 열기와 함께 휴브리스Hubris를 겪고 추락했지만, 오늘날은 스페이스 XSpace X의 고안자이자 테슬라Tesla의 창업자인 엘론 머스크Elon Musk와 아마존닷컴Amazon. com과 블루 오리진Blue Origin의 창립자인 제프 베조스Jeff Bezos처럼 자신의 비전과 모험심으로 움직이고 4차 산업혁명의 신기술로 동력을 얻는 사람들이 하늘에 새로운 길을 개척하고 있다.', '현대판 이카로스들은 크게 생각할 능력이 있고, 자신들의 성공과 새로운 길을 밝히려는 노력과 목표를 매체 전역 흩뿌리고 있다.', '물론, 항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', '4년, 첫 번째 상용 비행기가 탄생한 때부터 항공 여행 수요는 기하급수적으로 늘었다.', '그 결과, 항공 업계는 더 안전하고, 빠르고, 가벼우며 연료 효율이 높은 항공기를 설계할 방법을 찾게 되었다.', '세기에 들어 환경에 대한 인식이 최고조에 다다르자, 업계 또한 항공기의 탄소 배출을 줄이고 지속 가능한 탄소 발자국을 유지하기 위한 방법을 찾게 되었다.', "당시는 다른 무엇보다도 가격이 중요한 이지젯EasyJet 시대'였던 만큼, 굉장히 어려운 일이었다.", '빠르게, 유연하게', '이러한 난제를 해결하는 데는 비용 효율적이고도 빠르며 유연한 새로운 생산 공정이 필요하다.', '고급 로봇 공학, 인공 지능, 머신 러닝, 클라우드 컴퓨팅 및 사물 인터넷과 같은 기술은 이러한 공정에 큰 역할을 하며 우리 삶을 조용히 변화시키고 있으며, 특히 항공 산업에 큰 변화를 불러왔다.', '우리는 비행기에 올라 자리에 앉을 때마다 자동화에 우리 자신을 어느 정도 맡기는 셈이다.', 'ISO포커스_1315', '비행이 무서운 사람에게 그다지 반가운 예시는 아니지만, 우리는 비행기의 서로 다른 부품을 엮어주는 수천 개의 구멍과 그 구멍이 어떻게 뚫어졌는지에 대해 생각해 보지 않는다.', '고도의 정밀함과 시간이 필요한 작업임에도 말이다.', '셰필드 대학교Sheffield University 내 첨단 제조 연구센터Advanced Manufacturing Research Center의 통합 제조 그룹 책임자인 벤 모건Ben Morgan은 디 엔지니어The Engineer에 기고한 기사에서 자동화 제조는 사람보다 로봇에게 적합한 작업이라고 지적하며 "자동화 시스템은 정밀도를 더 높일 수 있고, 지루함이나 피곤함을 느끼지도 않는다.', '우주 항공 산업 재료 및 다양한 재료를 겹친 재료는 숙련된 직원이 다루기에도 부피가 크고 무겁고 어려움을 겪을 수 있다.', '"라고 말했다.', '비행기 이용자에게 좋은 소식인 셈이다.', '만 개의 부품이 반드시 모두 조립되어야만 하는 보잉 747을 생각해보자.', '자동화 제조가 새 항공기를 제작하는 데 큰 역할을 해낸다는 것이 분명해지지 않는가?', '그러나, 항공 산업에 난제가 없는 것은 아니다.', '급속도로 발전하는 신기술을 따라가야 할 뿐만 아니라 설계, 조달, 제조, 생산 및 배달, 지원, 유지보수, 제품의 폐기와 기타 관련 서비스 등 자동화 시스템 분야의 표준도 잘 알아두어야 한다.', '이러한 두 가지 과제에 독특한 시각을 가진 사람이 있다.', '보잉의 사업 역량 통합부서의 수석 관리자이자, 기술 위원회 ISO/TC 184, 항공 시스템과 통합, 분과위원회 SC4, 산업 자료의 의장인 케니 스워프Kenny Swope이다.', '스워프Swope는 고도로 복잡한 시스템을 통해 제조를 해야 하는 보잉과 같은 회사는 업계에서 전반적인 성공을 거두기 위해 표준이 매우 중요하며, 회사의 “제품, 공급 체인과 서비스 제안 등이 무수히 많은 갈래로” 엮여 있다고 말한다.', '표준의 주요 역할', '스워프Swope에 따르면, ISO 10303, 산업 자동화 시스템과 통합 – 상품 데이터 표현 및 교환, 즉 STEP은 디지털 상품 설계의 적용에 가장 성공적인 표준 중 하나이다.', 'ISO 10303은 산업 데이터에 대한 ISO/TC 184/SC 4에 속하는 표준이다.', 'STEP은 회사 내부는 물론, 글로벌 공급 체인 사이에서 컴퓨터 이용 설계(CAD) 시스템을 이용한 상품 설계 데이터 교환에서 가장 흔하게 쓰이는 표준으로 발달했다.', '그는 “설계와 공학에서 제조에 이르는 제품의 핵심으로, 제품 설계와 결합된 공학 요구사항과 제조 정보 등 3차원 표현은 디지털 트윈의 핵심을 이룬다.”라고 말한다.', '상세한 가상 표현을 위한 집합적 데이터에는 분명한 이점이 있다.', '스워프는 “보잉의 제품 설계는 구성 요소와 조립 수준에서 내외부 이해당사자에게 분배되며, 이 표준은 이러한 망에 대단히 중요하다.”고 덧붙였다.', '전반적인 설명, 교육 문서 작업에 대한 제품 디자인의 복합 디자인을 제공하는 것은 또 다른 과제이다.', '여기, 스워프는 ISO/TC 184/SC 4에서 다루는 또 다른 표준인 ISO 14306, 산업 자동화 시스템과 통합 – 3D 구상을 위한 JT 파일 형식 사양을 강조한다.', '그는 복잡한 데이터 구조의 “경량 버전”을 제공하는 이 표준이 매우 귀중한 것이라고 말한다.', '즉, 제조, 서비스 및 지원을 위한 제품의 구상이 “공학 문서와 온라인 서비스 매뉴얼 및 제조 공장에 유용”하다는 것이다.', '세 번째 표준은 ISO 32000, 문서 관리 – 휴대 가능한 문서 형식이다.', '스워프에 따르면 이는 “ISO 10303과 ISO 14306 모두의 강력한 파트너”이다.', '이 표준은 PDF 표준으로도 잘 알려져 있는데, 제품 설계에 필요한 범용 운송 수단과 관련 정보를 제공하기 때문에 디지털 미래의 매끄러운 운용에 필수적이다.', '마지막으로, ISO 8000, 데이터 품질과 ISO 22745, 산업 자동화 시스템과 통합 – 오픈 기술 사전과 마스터 데이터에 대한 사전의 적용은 스마트 제조를 가능하게 하는 중요한 요소이다.', '즉, ISO 9000은 제조 품질을, ISO 8000은 데이터를 담당하는 것이다.', '스마트 제조에는 결함이 없는 데이터가 필요하고, 상용 부품의 데이터 정의를 공개적으로 공유할 수 있어야 한다.', 'ISO 22745는 공급 체인 전역에 걸쳐 사용되는 상용 부품의 정의를 공유하기 위한 다중 산업 솔루션을 제공한다.', '항공우주산업과 항공 산업은 지난 수년간 그들의 경계를 넓혀왔다.', 'ISO포커스_131', 'ISO포커스_1317', '자동화와 효율', '스스로를 멀티 CAD 데이터 교환 최적화 플랫폼이라고 소개하는 소프트웨어 회사 엘리시움Elysium의 기술 업무부 책임자인 애너리즈 스즈키Annalise Suzuki 또한 표준의 이점과 산업 자동화의 확대 경향에 맞추어 표준이 수행하는 핵심 역할을 극찬했다.', '그녀는 “효율을 위해 자동화를 추구하는 조직은 반드시 새로운 기술을 적용하는 것과 표준을 통해 안정성을 올리는 것 사이에서 균형을 찾아야 한다.”라고 말했다.', '스즈키Suzuki는 스워프와 같이 표준의 영향력이 지나치게 복잡한 과정을 거치지 않고 조직의 수단과 방법을 빠르게 조화시킬 수 있도록 도와준다고 믿는다.', '그녀는 “이 표준은 어떻게’를 먼저 생각하지 않고 행동가들이 바로 행동에 돌입할 수 있도록 만들어준다.”고 말했다.', '그녀는 표준이 오늘날 사람들 간의 협업을 도와주는 동시에, 표준이 “머신 투 머신 의사소통에 대한 잠재력으로 자동화를 이끌 핵심 가능자가 될 것이고, 4차 산업혁명을 달성하는 기초가 될 것” ...
# ['인공지능의\x0b새로운 장', 'ISOfocus_13117', '기사작성자: 로버트 바트람(Robert Bartram)', '인공지능(AI)은 이제 더 이상 공상과학 영화의 테마가 아닌 우리 실생활의 일부다.', '공장에서, 지능형교통체계에서, 심지어 의료분야에서도 우리는 AI 활용 사례를 볼 수 있다.', '하지만 정확히 인공지능은 무엇인가?', '성큼 도래한 유비쿼터스 AI\xa0세상에서 국제표준은 왜 필요한가?', '또한 AI 표준화는 어떤 분야를 대상으로 하는가?', '맥킨지 글로벌 연구소1)가 발표한 최근 보고서에 의하면 인공지능에 대한 투자가 빠른 속도로 증가하고 있다.', '맥킨지는 구글과 같은 디지털 혁신 선도기업은 "2016 회계연도에 20~30억 달러를 AI에 투자했으며, 그 중 90%는 R&D 및 AI 배치에, 나머지 10%는 AI 구입에 사용한 것으로 분석한다.', 'ICT산업 전문 시장조사기관 IDC(International Data Corporation)2)에 따르면, 2019년까지 디지털 변혁 이니셔티브의 40%가 다양한 AI를 배치하고, 2021년까지 엔터프라이즈 응용프로그램의 75%가 AI를 사용할 계획이며 총 지출 규모는 522억 달러로 증가할 전망이다.', '개념에서 현실로', '하지만 정확히 AI가 무엇인가?', "ISO/IEC JTC 1, '정보기술(Information technology)'의 분과위원회인 SC 42, 인공지능(Artificial intelligence)의 와엘 윌리엄 디아브(Wael William Diab) 의장에 따르면, AI 분야는 매우 다양한 기술로 구성된다.", '이 신설 위원회는 AI의 개념과 용어(ISO/IEC 22989)를 규정하는 기본 표준의 개발에 착수했다.', '디아브 의장은 AI에 대한 관심이 고조되면서 데이터 과학자, 디지털 전문가, 규제기관 등 매우 다양한 종류의 이해관계자가 이 분야에 참여 중이라고 말한다.', '그는 또 오늘날 AI의 현황과 AI에 대한 인식 사이에 다소 괴리가 있다고 지적한다.', '“사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '내가 보기에 AI는 지능을 갖춘 기계를 효과적으로 구현하는 기술의 집합체다.”', '그는 또 흔히 사람들이 AI를 하나의 완전 자율 시스템 그룹, 즉 움직이는 로봇인 것처럼 생각하지만, 실제로는 많은 AI가 반자율 시스템에 속한다고 설명한다.', '일반적으로 AI 시스템에서 상당 부분의 데이터는 미리 준비가 완료되고, 그 후 특정 형태의 기계학습 능력이 있는 핵심부품에 탑재되며 결국 이런 부품이 우리에게 갖가지 통찰력을 제공한다.', '이처럼 기술 집합체를 구성하는 요소에는 빅데이터, 분석법이 포함되며 반드시 그에 국한하지는 않는다.', '기술의 우산', '현재 화웨이테크놀로지(Huawei Technologies)의 전무로 재직 중인 디아브씨가 ISO/IEC 분과위원회 의장으로 선출된 데는 그만한 이유가 있다.', '맥킨지 글로벌 연구소, 인공지능: 차세대 디지털 프론티어(Artificial Intelligence: The Next Digital Frontier )?', 'IDC, 20182021년 미국 정부기관용 인지컴퓨팅 및 인공지능 솔루션 시장 전망(US Government Cognitive and Artificial Intelligence Forecast 20182021)', 'ISOfocus_131', 'ISOfocus_13119', '스탠퍼드 대학교와 와튼 스쿨에서 전기공학, 경제 및 경영학 학위를 받은 디아브 의장은 경영, 기술전략 부문에서 직무경력을 쌓았다.', '다국적기업인 시스코와 브로드컴에서 근무한 바 있고 사물인터넷(IoT) 전문 컨설턴트로 활동했으며 최근에는 산업인터넷컨소시엄 운영위원회 간사를 역임했다.', '또한 850건 이상의 특허를 출원하여 그 중 400건 가까이 등록되었고 나머지는 심사 중에 있다.', '이는 테슬라가 생전에 출원했던 특허건수보다 더 많은 숫자다.', '더욱이 디아브 의장이 출원한 특허는 단 한 건도 거절결정을 받지 않았다.', '디아브 의장의 진정한 장점은 폭넓은 전문지식에 있는데, 그의 전공분야는 기술 아이디어의 초기 인큐베이션부터 전략적 사업추진에 이르기까지 다양한 영역을 망라한다.', '그가 표준화에 큰 관심을 갖는 것은 산업 전체의 건전한 성장을 위해서는 표준이 완벽한 도구라고 믿기 때문이다.', '디아브 의장은 오늘을 살아가는 우리는 여러 가지 이유로 AI 표준이 필요하다고 역설한다.', '첫째, 현대 사회의 IT는 그 복잡성이 갈수록 심화된다.', '따라서 일반적인 스마트폰 한 대의 용량이 아폴로 우주선의 미션을 모두 합친 용량보다 더 크다.', '둘째, IT가 모든 분야에 점점 더 깊숙이 스며들고 있다.', 'IT 기기들은 출시 초창기인 1970~80년대에는 다소 느린 발전을 보였다.', '하지만 이제 사람들은 단지 효율성 향상 차원에서 IT 시스템을 필요로 하는 것이 아니라 더 큰 효율을 발휘하고 운영적, 전략적 통찰력을 얻기 위해 이를 필요로 하기에 이르렀다.', '끝으로 IT는 어느덧 우리의 삶과 혼연일치가 되었다.', '재무에서부터 제조, 의료, 교통, 로봇에 이르기까지 IT에 의존하지 않는 분야가 없다.', '대책의 일환', '그것이 바로 국제표준이 작동하기 시작하는 지점이다.', 'ISO와 국제전기기술위원회(IEC)간 공동기술위원회 JTC 1 산하의 분과위원회인 SC 42는 AI 생태계를 취급하는 유일한 기술위원회다.', '디아브 의장은 AI 기술이 널리 보급되려면 이 기술의 모든 측면을 종합적으로 고려할 필요가 있으며, 그것이야말로 자신과 SC 42가 지향하는 인식의 출발점이라고 강조한다.', '“우리는 사용자들이 AI가 어떻게 의사결정을 내리는지에 대해 우려 섞인 관심을 나타내고 있으며 따라서 AI의 투명성이 시스템에 포함되어야 한다는 사실을 잘 알고 있습니다.', '따라서 기술 채택을 위해서는 포괄적인 표준화가 필수적입니다,”라고 그는 강조한다.', '그간 AI 생태계는 기술, 사회 및 윤리적 고려사항이라는 몇 가지 핵심 분야로 세분화되었으며 이는 개괄적으로 다음과 같은 범주를 포함한다.', '사람들은 AI를 자율 로봇 또는 체스 챔피언을 이기는 컴퓨터쯤으로 여기는 경향이 있다.', '기본 표준', '매우 다양한 이해관계자로 구성된 SC 42는 일차적인 출발점을 기본 표준에 대한 작업으로 정했다.', '이 작업은 AI의 여러 측면 가운데 공통 용어, 분류체계 및 정의가 요구되는 분야를 검토한다.', '궁극적으로 기본 표준은 현장실무자나 규제담당자가 동일한 언어로 말하고 양 당사자 모두 기술전문가로서 한 목소리를 낼 수 있음을 의미한다.', 'ISOfocus_131', 'ISOfocus_13121', '연산 방법과 기법', 'AI의 핵심은 인공지능 시스템의 연산방법 및 특성의 평가다.', '여기에는 AI의 연산방법, 아키텍처 및 특성을 파악하기 위한 기존의 전문 AI 시스템에 대한 연구는 물론 AI 시스템이 사용하는 다양한 기술(예: ML 알고리즘, 추론, 등)과 특성에 대한 연구도 포함된다.', '이 연구그룹은 AI 분야에서 일어나고 있는 현황을 보고하면서 표준화가 요구되는 분야를 제안할 것이다.', '신뢰도', "산업계의 가장 어려운 주제 가운데 하나가 '신뢰도'이며, 이것이 AI 생태계의 핵심 고려사항 가운데 세 번째다.", '신뢰도는 AI를 둘러싼 여러 우려사항 가운데 중심 위치에 있다.', '이 연구그룹은 AI 시스템의 보안, 프라이버시에서부터 시스템 강건성, 투명성 및 편견에 이르기까지 모든 부분을 샅샅이 검토 중이다.', '이미 AI에는 의사결정을 내리거나 사람들에게 결정을 요하는 사안에 관한 정보를 제공하는 시스템이 있다.', '따라서 불필요한 편견이 없음을 확신하기 위해서는 투명성에 대한 인식과 합의가 가장 중요하다.', '이 연구그룹은 표준화 프로젝트에 관한 일련의 권고안을 마련할 것으로 보인다.', '상기 권고안은 AI 분야의 우려를 사전에 차단할 수 있는 도구를 제공할 것이다.', '“AI 생태계는 이러한 문제를 내포하고 있습니다.', '따라서 표준이  ...
# done, pptx_contents_dict : is 156
# pptx는 156개 가져왔어요
# 0번, docx 추출 시작했습니다.
# 1번, sent_tokenize했습니다.
# 1번, docx 추출 시작했습니다.
# 2번, sent_tokenize했습니다.
# 2번, docx 추출 시작했습니다.
# 3번, sent_tokenize했습니다.
# 3번, docx 추출 시작했습니다.
# 4번, sent_tokenize했습니다.
# 4번, docx 추출 시작했습니다.
# 5번, sent_tokenize했습니다.
# 5번, docx 추출 시작했습니다.
# 6번, sent_tokenize했습니다.
# 6번, docx 추출 시작했습니다.
# 7번, sent_tokenize했습니다.
# 7번, docx 추출 시작했습니다.
# 8번, sent_tokenize했습니다.
# 8번, docx 추출 시작했습니다.
# 9번, sent_tokenize했습니다.
# 9번, docx 추출 시작했습니다.
# 10번, sent_tokenize했습니다.
# 10번, docx 추출 시작했습니다.
# 11번, sent_tokenize했습니다.
# 11번, docx 추출 시작했습니다.
# 12번, sent_tokenize했습니다.
# 12번, docx 추출 시작했습니다.
# 13번, sent_tokenize했습니다.
# 13번, docx 추출 시작했습니다.
# 14번, sent_tokenize했습니다.
# 14번, docx 추출 시작했습니다.
# 15번, sent_tokenize했습니다.
# 15번, docx 추출 시작했습니다.
# 16번, sent_tokenize했습니다.
# 16번, docx 추출 시작했습니다.
# 17번, sent_tokenize했습니다.
# 17번, docx 추출 시작했습니다.
# 18번, sent_tokenize했습니다.
# 18번, docx 추출 시작했습니다.
# 19번, sent_tokenize했습니다.
# 19번, docx 추출 시작했습니다.
# 20번, sent_tokenize했습니다.
# 20번, docx 추출 시작했습니다.
# 21번, sent_tokenize했습니다.
# 21번, docx 추출 시작했습니다.
# 22번, sent_tokenize했습니다.
# 22번, docx 추출 시작했습니다.
# 23번, sent_tokenize했습니다.
# 23번, docx 추출 시작했습니다.
# 24번, sent_tokenize했습니다.
# 24번, docx 추출 시작했습니다.
# 25번, sent_tokenize했습니다.
# 25번, docx 추출 시작했습니다.
# 26번, sent_tokenize했습니다.
# 26번, docx 추출 시작했습니다.
# 27번, sent_tokenize했습니다.
# 27번, docx 추출 시작했습니다.
# 28번, sent_tokenize했습니다.
# 28번, docx 추출 시작했습니다.
# 29번, sent_tokenize했습니다.
# 29번, docx 추출 시작했습니다.
# 30번, sent_tokenize했습니다.
# 30번, docx 추출 시작했습니다.
# 31번, sent_tokenize했습니다.
# 31번, docx 추출 시작했습니다.
# 32번, sent_tokenize했습니다.
# 32번, docx 추출 시작했습니다.
# 33번, sent_tokenize했습니다.
# 33번, docx 추출 시작했습니다.
# 34번, sent_tokenize했습니다.
# 34번, docx 추출 시작했습니다.
# 35번, sent_tokenize했습니다.
# 35번, docx 추출 시작했습니다.
# 36번, sent_tokenize했습니다.
# 36번, docx 추출 시작했습니다.
# 37번, sent_tokenize했습니다.
# 37번, docx 추출 시작했습니다.
# 38번, sent_tokenize했습니다.
# 38번, docx 추출 시작했습니다.
# 39번, sent_tokenize했습니다.
# 39번, docx 추출 시작했습니다.
# 40번, sent_tokenize했습니다.
# 40번, docx 추출 시작했습니다.
# 41번, sent_tokenize했습니다.
# 41번, docx 추출 시작했습니다.
# 42번, sent_tokenize했습니다.
# 42번, docx 추출 시작했습니다.
# 43번, sent_tokenize했습니다.
# 43번, docx 추출 시작했습니다.
# 44번, sent_tokenize했습니다.
# 44번, docx 추출 시작했습니다.
# 45번, sent_tokenize했습니다.
# 45번, docx 추출 시작했습니다.
# 46번, sent_tokenize했습니다.
# 46번, docx 추출 시작했습니다.
# 47번, sent_tokenize했습니다.
# 47번, docx 추출 시작했습니다.
# 48번, sent_tokenize했습니다.
# 48번, docx 추출 시작했습니다.
# 49번, sent_tokenize했습니다.
# 49번, docx 추출 시작했습니다.
# 50번, sent_tokenize했습니다.
# 50번, docx 추출 시작했습니다.
# 51번, sent_tokenize했습니다.
# 51번, docx 추출 시작했습니다.
# 52번, sent_tokenize했습니다.
# 52번, docx 추출 시작했습니다.
# 53번, sent_tokenize했습니다.
# 53번, docx 추출 시작했습니다.
# 54번, sent_tokenize했습니다.
# 54번, docx 추출 시작했습니다.
# 55번, sent_tokenize했습니다.
# 55번, docx 추출 시작했습니다.
# 56번, sent_tokenize했습니다.
# 56번, docx 추출 시작했습니다.
# 57번, sent_tokenize했습니다.
# 57번, docx 추출 시작했습니다.
# 58번, sent_tokenize했습니다.
# 58번, docx 추출 시작했습니다.
# 59번, sent_tokenize했습니다.
# 59번, docx 추출 시작했습니다.
# 60번, sent_tokenize했습니다.
# 60번, docx 추출 시작했습니다.
# 61번, sent_tokenize했습니다.
# 61번, docx 추출 시작했습니다.
# 62번, sent_tokenize했습니다.
# 62번, docx 추출 시작했습니다.
# 63번, sent_tokenize했습니다.
# 63번, docx 추출 시작했습니다.
# 64번, sent_tokenize했습니다.
# 64번, docx 추출 시작했습니다.
# 65번, sent_tokenize했습니다.
# 65번, docx 추출 시작했습니다.
# 66번, sent_tokenize했습니다.
# 66번, docx 추출 시작했습니다.
# 67번, sent_tokenize했습니다.
# 67번, docx 추출 시작했습니다.
# 68번, sent_tokenize했습니다.
# 68번, docx 추출 시작했습니다.
# 69번, sent_tokenize했습니다.
# 69번, docx 추출 시작했습니다.
# 70번, sent_tokenize했습니다.
# 70번, docx 추출 시작했습니다.
# 71번, sent_tokenize했습니다.
# 71번, docx 추출 시작했습니다.
# 72번, sent_tokenize했습니다.
# 72번, docx 추출 시작했습니다.
# 73번, sent_tokenize했습니다.
# 73번, docx 추출 시작했습니다.
# 74번, sent_tokenize했습니다.
# 74번, docx 추출 시작했습니다.
# 75번, sent_tokenize했습니다.
# 75번, docx 추출 시작했습니다.
# 76번, sent_tokenize했습니다.
# 76번, docx 추출 시작했습니다.
# 77번, sent_tokenize했습니다.
# 77번, docx 추출 시작했습니다.
# 78번, sent_tokenize했습니다.
# 78번, docx 추출 시작했습니다.
# 79번, sent_tokenize했습니다.
# 79번, docx 추출 시작했습니다.
# 80번, sent_tokenize했습니다.
# 80번, docx 추출 시작했습니다.
# 81번, sent_tokenize했습니다.
# 81번, docx 추출 시작했습니다.
# 82번, sent_tokenize했습니다.
# 82번, docx 추출 시작했습니다.
# 83번, sent_tokenize했습니다.
# 83번, docx 추출 시작했습니다.
# 84번, sent_tokenize했습니다.
# 84번, docx 추출 시작했습니다.
# 85번, sent_tokenize했습니다.
# 85번, docx 추출 시작했습니다.
# 86번, sent_tokenize했습니다.
# 86번, docx 추출 시작했습니다.
# 87번, sent_tokenize했습니다.
# 87번, docx 추출 시작했습니다.
# 88번, sent_tokenize했습니다.
# 88번, docx 추출 시작했습니다.
# 89번, sent_tokenize했습니다.
# 89번, docx 추출 시작했습니다.
# 90번, sent_tokenize했습니다.
# 90번, docx 추출 시작했습니다.
# 91번, sent_tokenize했습니다.
# 91번, docx 추출 시작했습니다.
# 92번, sent_tokenize했습니다.
# 92번, docx 추출 시작했습니다.
# 93번, sent_tokenize했습니다.
# 93번, docx 추출 시작했습니다.
# 94번, sent_tokenize했습니다.
# 94번, docx 추출 시작했습니다.
# 95번, sent_tokenize했습니다.
# 95번, docx 추출 시작했습니다.
# 96번, sent_tokenize했습니다.
# 96번, docx 추출 시작했습니다.
# 97번, sent_tokenize했습니다.
# 97번, docx 추출 시작했습니다.
# 98번, sent_tokenize했습니다.
# 98번, docx 추출 시작했습니다.
# 99번, sent_tokenize했습니다.
# 99번, docx 추출 시작했습니다.
# 100번, sent_tokenize했습니다.
# 100번, docx 추출 시작했습니다.
# 101번, sent_tokenize했습니다.
# 101번, docx 추출 시작했습니다.
# 102번, sent_tokenize했습니다.
# 102번, docx 추출 시작했습니다.
# 103번, sent_tokenize했습니다.
# 103번, docx 추출 시작했습니다.
# 104번, sent_tokenize했습니다.
# 104번, docx 추출 시작했습니다.
# 105번, sent_tokenize했습니다.
# 105번, docx 추출 시작했습니다.
# 106번, sent_tokenize했습니다.
# 106번, docx 추출 시작했습니다.
# 107번, sent_tokenize했습니다.
# 107번, docx 추출 시작했습니다.
# 108번, sent_tokenize했습니다.
# 108번, docx 추출 시작했습니다.
# 109번, sent_tokenize했습니다.
# 109번, docx 추출 시작했습니다.
# 110번, sent_tokenize했습니다.
# 110번, docx 추출 시작했습니다.
# 111번, sent_tokenize했습니다.
# 111번, docx 추출 시작했습니다.
# 112번, sent_tokenize했습니다.
# 112번, docx 추출 시작했습니다.
# 113번, sent_tokenize했습니다.
# 113번, docx 추출 시작했습니다.
# 114번, sent_tokenize했습니다.
# 114번, docx 추출 시작했습니다.
# 115번, sent_tokenize했습니다.
# 115번, docx 추출 시작했습니다.
# 116번, sent_tokenize했습니다.
# 116번, docx 추출 시작했습니다.
# 117번, sent_tokenize했습니다.
# 117번, docx 추출 시작했습니다.
# 118번, sent_tokenize했습니다.
# 118번, docx 추출 시작했습니다.
# 119번, sent_tokenize했습니다.
# 119번, docx 추출 시작했습니다.
# 120번, sent_tokenize했습니다.
# 120번, docx 추출 시작했습니다.
# 121번, sent_tokenize했습니다.
# ['DEVCO Chair’s Advisory Group(DEVCO CAG)32nd meetingCape Town, South AfricaMonday 16 September 2019Working documentsITEM 1Opening of the meeting – CAG membership 2019There are currently two open positions on the DEVCO CAG, one for SouthEast or South Asia and one for South America as Fadilah Baharin completed her 2nd term (extended till March 2019), and César Díaz Guevara left INEN (Ecuador) in August 20', 'Chair/termPosition/NSBISO regionEmailCHAIRLena Dargham2nd term 20192020Director General LIBNOR (Lebanon)lena. dargham@libnor. orgVICECHAIRTatjana Bojanić2nd term 20192020DirectorISS (Serbia)tatjana. bojanic@iss. rsMember/termPosition/NSBISO regionSTATUSCamilla Åberg1st term 20182019Manager, International Relations, SIS (Sweden)Developed countrycamilla. aberg@sis. seAlex Dodoo1st term 20192020Executive Director GSA (Ghana)Central and Western Africaadodoo@gsa. gov. ghEve Gadzikwaterm extended (2019)Director General SAZ (Zimbabwe)Eastern and Southern Africaevegadzikwa@gmail. com or directorgeneral@zol. co. zwSangme HAN1st term 20192020Director, International Standards Division KATS (Republic of Korea)Developed countrystandard@korea. krPascale Mienville2nd term 20192020Director, International Affairs AFNOR (France)Developed countrypascale. mienville@afnor. orgNadita Ramachala1st term 20182019Head of Standardization TTBS (Trinidad and Tobago)Caribbean and Central Americanadita. ramachala@ttbs. org. t tAbderrahim Taibi2nd term 20192020Director General IMANOR (Morocco)Arab regionimanor@imanor. gov. maISO Central SecretariatErich KieckDirector, Capacity Buildingkieck@iso. orgSari RajakoskiDEVCO Secretaryrajakoski@iso. orgNoelia Garcia NebraProgamme Manager, Capacity Buildinggarcianebra@iso. orgITEM 2ADOPTION OF THE AGENDA32ND DEVCO CAG MEETING, MONDAY 16 SEPTEMBER 2019, CAPE TOWN, SOUTH AFRICA (CTICC ROOM 3 LEVEL ONE) STARTING AT 14:30TimeAgenda itemByDocument14:30Opening of the meetingChair01/201914:35Adoption of the agendaChair02/201914:40Action items from 31st CAG meeting, including meeting minutesSecretary03/201914:50Review of the 53rd DEVCO meeting draft resolutionsALL04/201915:10Preliminary results from the external evaluation of the Action Plan 20162020 and MENA STAR programme 20132018Erich Kieck05/201915:20Monitoring of the ISO Action Plan for developing countries 20162020, incl.', 'survey of member needs for the 2020 work planErich KieckNoelia Garcia Nebra06/201915:40Financing of capacity building activitiesChair07/201916:00Coffee break16:15ISO Action Plan for developing countries 2021 – 2023 planning milestonesSecretary08/201916:25DEVCO work programme for 2020Chair09/201916:45', 'Implementation of the Leadership and Management Development (LMD) programmeErich Kieck10/201917:00', 'DEVCO AwardChair11/201917:20', 'Date and place of the next meetingSecretary12/201917:25', 'Any other businessALL13/2019ITEM 03Action items from 31st CAG meeting, including meeting minutesAction items from 31st CAG meeting, 2122 March 2019The action items from the March meeting listed below were reviewed and approved by the CAG at the end of meeting.', 'The text of the minutes is included in annex.', 'Item ', 'Matters arisingItems to be discussed at the next DEVCO CAG meeting:Discuss the regional engagement as part of ISO strategyWays of supporting twinning arrangementsRevision of DEVCO CAG TORsDEVCO AwardDEVCO CAG agrees to develop the modalities and criteria for launching a DEVCO Award to recognize successful partnerships between NSBs and different stakeholders in standards development and use – proposal to be submitted by the DEVCO Secretariat by midJulyTo be announced at DEVCO meeting in Cape Town 2019First award to be presented at DEVCO meeting in 2020Item ', 'RBM and Monitoring systemDEVCO CAG to provide inputs and comments on the reviewed results framework and on the monitoring system within a month (end of April 2019)Need to clarify the link between the reviewed framework and the APDCReflect on role of DEVCO CAG in the monitoring system do ...
# ['8 September 2019, Cape Town, South Africa53rd DEVCO MeetingWorking documentsINTRODUCTIONITEM 1Opening of the meetingThe DEVCO Chair Lena Dargham, appointed by Council for the term 20192020, will call the meeting to order and invite the ISO President John Walter, to give his opening address.', 'INTRODUCTIONITEM 2Welcome by the ISO PresidentThe ISO President John Walter, will welcome the participants at the 53rd DEVCO meeting and deliver his opening address.', 'Fiftythird meeting of the ISO Committee on developing countrymatters (DEVCO), 1718 September 2019, Cape Town (South Africa)DRAFT AGENDA – TUESDAY 17 SEPTEMBER – STARTING AT 09:00Agenda ItemDocumentPageINTRODUCTIONOpening of the meeting01/20193Welcome by the ISO President02/20195Adoption of the agenda03/20197Approval of the minutes of the 52nd DEVCO meeting04/20199Matters arising from the minutes of the previous meeting05/201919Progress report by the Chair06/201923DEVELOPING COUNTRIES IN 2030Outlook on the challenges ahead – panel session07/201925COFFEE BREAKPOLICY DEVELOPMENTDEVCO input to the ISO Strategy 203008/201927Joint DEVCO/TMB panel session on enhancing developing country participation in ISO technical work09/201937Presentation of the breakout group topics10/201939LUNCH BREAKBREAKOUT GROUPS (14:0017:30)Group 1 – Future trends in conformity assessment43Group 2 – Standards in support of SDG 5 on gender equality51Group 3 – How to make use of the new twinning concept to enhance participation in ISO55DRAFT AGENDA – WEDNESDAY 18 SEPTEMBER – STARTING AT 09:00Agenda ItemDocumentPageCAPACITY BUILDINGISO Action Plan for developing countries 2016202011/201957Report on the implementation and monitoring of the Action Plan 2016202059Applying good standardization practice (GSP) in standards development – A case studyPreliminary results from the evaluation of the ISO Action Plan for developing countries 20162020 and MENA STAR programme 20132018COFFEE BREAKONGOING TECHNICAL WORKPanel session on international standards development work of interest to developing countries12/201989REPORTING FROM BREAKOUT GROUPSBrief reports on the outcome of the discussions13/201991CLOSUREResolutions14/201993Date and place of the next meeting15/201995Any other business16/201997Closing remarks by the ISO SecretaryGeneral17/201999LUNCH BREAKINTRODUCTIONITEM 4Approval of the minutes of the 52nd meeting held in Geneva(Switzerland) on 2526 September 2018The minutes of the 52nd DEVCO meeting held in Geneva (Switzerland) on 2526 September 2018, were circulated to the members in April 20', 'The Secretariat did not receive any requests to amend the text of the minutes included in Annex.', 'DEVCO ACTIONIt is proposed to approve the minutes of the 52nd DEVCO meeting as presented.', 'UNCONFIRMED MINUTES OF THE FIFTYSECOND MEETING OF THE ISO COMMITTEE ON DEVELOPING COUNTRY MATTERS (DEVCO)GENEVA, SWITZERLAND, 2525 SEPTEMBER 2018ITEM 1Opening of the meetingMrs Lena Dargham, DEVCO Chair, called the meeting to order and invited the ISO President to deliver his welcome address.', 'ITEM 2Welcome by the ISO PresidentMr John Walter, ISO President, opened the 52nd DEVCO meeting at 09:00, on Tuesday 25 September 2018, at the Geneva International Conference Centre (CICG), Switzerland.', 'Mr Walter congratulated the DEVCO Chair on her reappointment by Council for the term 20192020 and thanked her for the many initiatives in advancing the developing country agenda in ISO.', 'Mr Walter also noted the progress with the implementation of the ISO Action Plan for developing countries 20162020 and thanked the Swedish International Development Cooperation Agenda (Sida) for their continued support.', 'Mr Walter highlighted the importance for members and partners to work together on defining challenges, identifying solutions, and emphasizing the value that standards bring to the international community under the overall theme of the 2018 ISO Week “International Standards Advancing the Global Agenda”.', 'The Chair thanked Mr Walter f ...
# done, docx_contents_dict : is 121
# docx는 121개 가져왔어요
# total length is : 277
# ['습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호_첨단(기사 1)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외)-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2)-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en (기사 2)-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 1)-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-standards education in Korea University-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-annual_report_2018_en-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_247호_기사1-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en 2019(기사 1)-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_2-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEC_Case_studies-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_3-영', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-China Standardization 3-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-China Standardization 2-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-DAY2_KOREA-한', '습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표ᄌ ...
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 2), 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Architecting a connected future_ISOfocus_132-Inside EN-4, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-how-to-write-standards-2018, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 1), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_4, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한국의 RnD 표준화 연계 제도 [PERU] 190823, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_1, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준리더십 컨퍼런스_4차 산업혁명 표준화 성과 및 방향(1), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)ICT_2, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_1, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호_첨단(기사 1)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호_첨단(기사 1)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호_첨단(기사 1), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호_첨단(기사 1), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2018_AnnualReport_web, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_3, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)환경_2, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외)-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ASTM-AnnualReport-2018 (30p_31p 제외), 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_2, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_1, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-标准化能力识别与cjlu的做法0516, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ieee-annualreport2018-7.9-print-version (42p_66p 제외), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_5, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_4, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/BI-한국표준협회-iso_action_plan_2016-2020_en_ld, 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-표준전문가 경력맵_브로셔190730_최종, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2)-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사2), 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_245호 (기사 1), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en (기사 2)-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en (기사 2)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en (기사 2), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en (기사 2), 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 1)-한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 1)
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 1), 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 1), 한
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-standards education in Korea University-영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-standards education in Korea University
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-standards education in Korea University, 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-standards education in Korea University, 영
# 습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-annual_report_2018_en-영
# ...
# 58-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-IEC Academy 2019-05
# 58-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-IEC Academy 2019-05
# 59-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 2)
# 59-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_259호 (기사 2)
# 60-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-asme-annual-report-2017-2018 (19p_34p 제외)
# 60-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-asme-annual-report-2017-2018 (19p_34p 제외)
# 61-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_2
# 61-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)바이오_2
# 62-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)헬스_1
# 62-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)헬스_1
# 63-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-KSA 2019 Education RSM
# 63-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-KSA 2019 Education RSM
# 64-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 1)
# 64-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_131_en (기사 1)
# 65-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_2
# 65-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)녹색산업_2
# 66-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_1
# 66-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)에너지_1
# 67-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 2)
# 67-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_249호 (기사 2)
# 68-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사1)
# 68-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_257호 (기사1)
# 69-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_2
# 69-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_2
# 70-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_3
# 70-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)보안_3
# 71-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_247호_기사2
# 71-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_247호_기사2
# 72-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_1
# 72-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)신기술_1
# 73-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_132_en (기사 2)
# 73-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_132_en (기사 2)
# 74-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)제조_2
# 74-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-(사례)제조_2
# 75-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en 2019(기사 2)
# 75-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISOfocus_135_en 2019(기사 2)
# 76-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사계획서1906-01l
# 76-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사계획서1906-01l
# 77-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 표준올림피아드 본선대회 안내책자(학생용)(한글)_V1_번역용
# 77-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 표준올림피아드 본선대회 안내책자(학생용)(한글)_V1_번역용
# 78-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-E-TECH
# 78-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-E-TECH
# 79-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-242호_IEC Just Published_2018-12
# 79-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-242호_IEC Just Published_2018-12
# 80-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3692 (작업용)
# 80-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3692 (작업용)
# 81-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한-아세안표준화공동연구센터 TOR 초안 (국문)_(20190904)_1.1
# 81-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한-아세안표준화공동연구센터 TOR 초안 (국문)_(20190904)_1.1
# 82-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N662 KEY FINDINGS FROM PASC 42 AGM BREAKOUT DISCUSSION ON PASC  STRATEG
# 82-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N662 KEY FINDINGS FROM PASC 42 AGM BREAKOUT DISCUSSION ON PASC  STRATEG
# 83-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-01_newsdetails
# 83-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-01_newsdetails
# 84-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사보고서1906-01REV02
# 84-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사보고서1906-01REV02
# 85-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-19694-1_CD_번역요청(편집용)
# 85-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-19694-1_CD_번역요청(편집용)
# 86-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-CAB_1840e_DC.pdf (발췌)
# 86-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-CAB_1840e_DC.pdf (발췌)
# 87-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-“ARSO 회원국 초청교육프로그램” 소개문구 초안_KSA-급수정
# 87-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/SO-한국표준협회-“ARSO 회원국 초청교육프로그램” 소개문구 초안_KSA-급수정
# 88-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019_Strategy_Implementation_-_Q3_Report
# 88-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019_Strategy_Implementation_-_Q3_Report
# 89-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-(주)S&TC_품질인증 2019 개선의 기회
# 89-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-(주)S&TC_품질인증 2019 개선의 기회
# 90-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ballot-process-flowchart(SAE)
# 90-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ballot-process-flowchart(SAE)
# 91-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEEE SA operations manuals
# 91-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEEE SA operations manuals
# 92-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-190825베트남최종보고서
# 92-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-190825베트남최종보고서
# 93-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N663 ISO Strategy 2030 - Draft PASC Survey Response_Final
# 93-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N663 ISO Strategy 2030 - Draft PASC Survey Response_Final
# 94-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-C_2206e_DV_SalesPolicy
# 94-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-C_2206e_DV_SalesPolicy
# 95-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-31st DEVCO CAG working documents
# 95-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-31st DEVCO CAG working documents
# 96-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISO-DEVCO_N0225_For_printing_SET_DEVCO_working_documents
# 96-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISO-DEVCO_N0225_For_printing_SET_DEVCO_working_documents
# 97-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 표준의날_리플릿 메시지
# 97-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 표준의날_리플릿 메시지
# 98-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3705 (작업용)
# 98-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3705 (작업용)
# 99-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제51차AEM-ROK회의-논페이퍼
# 99-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제51차AEM-ROK회의-논페이퍼
# 100-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-160 publications since 2019
# 100-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-160 publications since 2019
# 101-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-bluebook_FormStyle
# 101-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-bluebook_FormStyle
# 102-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3706 (작업용)
# 102-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3706 (작업용)
# 103-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2017 영문번역용 원안 (작업용)
# 103-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2017 영문번역용 원안 (작업용)
# 104-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT_유럽이 지원하는 연구 프로젝트에서 혁신에 대한 표준화 기여에 관한 연구
# 104-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT_유럽이 지원하는 연구 프로젝트에서 혁신에 대한 표준화 기여에 관한 연구
# 105-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사계획서1906-02
# 105-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사계획서1906-02
# 106-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-03_APTIR2019_Conclusion
# 106-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-03_APTIR2019_Conclusion
# 107-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEC General Secretary’s Activity Report July 2018-June 2019
# 107-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEC General Secretary’s Activity Report July 2018-June 2019
# 108-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/LW-한국표준협회-ISCP 2019 심층협력 프로젝트 간이보고서_라오스
# 108-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/LW-한국표준협회-ISCP 2019 심층협력 프로젝트 간이보고서_라오스
# 109-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N660 First Draft PASC Strategic Plan 2021 - 2025
# 109-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-EC_N660 First Draft PASC Strategic Plan 2021 - 2025
# 110-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISO-COUNCIL_N0877_Set_of_Council_working_documents_-_printer-friendly_version
# 110-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-ISO-COUNCIL_N0877_Set_of_Council_working_documents_-_printer-friendly_version
# 111-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사보고서1906-02REV01
# 111-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-한화큐셀앤드첨단소재 주식회사(0000057358)_TS_세종사업장_심사보고서1906-02REV01
# 112-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEC_WP_Semantic interoperability_LR
# 112-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-IEC_WP_Semantic interoperability_LR
# 113-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_개회사_국표원장님
# 113-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_개회사_국표원장님
# 114-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_환영사_표준협회장님_수정2
# 114-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_환영사_표준협회장님_수정2
# 115-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Draft of ISO Strategy 2030
# 115-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Draft of ISO Strategy 2030
# 116-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-혁신과 표준화의 이점에 관한 연구
# 116-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-BRIDGIT-혁신과 표준화의 이점에 관한 연구
# 117-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/LW-한국표준협회-한국과 라오스의 제품안전 법 체계 비교_라오스 Q마크 제도 관련
# 117-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/LW-한국표준협회-한국과 라오스의 제품안전 법 체계 비교_라오스 Q마크 제도 관련
# 118-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_폐회사_국표원장님
# 118-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 국제표준올림피아드_폐회사_국표원장님
# 119-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3702 (작업용)
# 119-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3702 (작업용)
# 120-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 동남아표준인증협력포럼 개회사(국문)
# 120-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 동남아표준인증협력포럼 개회사(국문)
# 121-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3534 (작업용)
# 121-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D 3534 (작업용)
# 122-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-02_APTIR2019_ExecutiveSummary_English
# 122-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-02_APTIR2019_ExecutiveSummary_English
# 123-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-B6386(2018) 원안
# 123-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-B6386(2018) 원안
# 124-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Batch 1 Working Documents Cape Town 16 September 2019
# 124-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-Batch 1 Working Documents Cape Town 16 September 2019
# 125-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 APEC SCSC 2차회의 발표 스크립트
# 125-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-2019 APEC SCSC 2차회의 발표 스크립트
# 126-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 대회 본선대회 과제안내(KSA이민규수석)
# 126-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-제14회 대회 본선대회 과제안내(KSA이민규수석)
# 127-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-(주)S&TC_품질인증 2019 심사보고서
# 127-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-(주)S&TC_품질인증 2019 심사보고서
# 128-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-04_APTIR2019_Introduction
# 128-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-04_APTIR2019_Introduction
# 129-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-회장님 말씀자료_ARSO 만찬
# 129-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-회장님 말씀자료_ARSO 만찬
# 130-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-포장상품관리고시개정의견(윤병수)
# 130-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-포장상품관리고시개정의견(윤병수)
# 131-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D_3504_2019 영문번역판
# 131-습 DB 구축 채널/1. 원본DB(렉스코드)/4.2019한국표준협회/TE-한국표준협회-D_3504_2019 영문번역판
# Running Time:  103.31459541699996
